# %%
import random
import json
from datetime import datetime, timedelta
from faker import Faker

# %%
# Data pools for randomization
first_names = [
    "Ade", "Chinedu", "Funke", "Grace", "Ibrahim", "Kemi", "Olu", "Tunde", 
    "Ngozi", "Chika", "Emeka", "Bola", "Yusuf", "Amina", "Eze", "Fatima",
    "Obinna", "Zainab", "Segun", "Halima", "Chukwu", "Adanna", "Mohammed", "Temitope",
    "Kunle", "Amara", "Sani", "Ifeoma", "Okonkwo", "Zara", "Jide", "Deborah",
    "Musa", "Chidinma", "Wale", "Patience", "Abdul", "Chioma", "Femi", "Blessing"
]

last_names = [
    "Adebayo", "Chukwu", "Eze", "Okafor", "Sule", "Yusuf", "Balogun", "Okoro",
    "Mohammed", "Ogunleye", "Ibrahim", "Nwosu", "Adeyemi", "Bello", "Okafor",
    "Mustapha", "Obi", "Aliyu", "Akintola", "Onyema", "Salami", "Umar", "Olu",
    "Bakare", "Okeke", "Adewale", "Ojo", "Adeleke", "Oladipo", "Akinwande",
    "Onyeka", "Alade", "Okonkwo", "Onyeama", "Afolayan", "Okorie", "Onyia", "Uche",
    "Okoh", "Ogbonna"
]

cities = [
    {"city": "Lagos", "zip": "100001"},
    {"city": "Abuja", "zip": "900001"},
    {"city": "Kano", "zip": "700001"},
    {"city": "Ibadan", "zip": "200001"},
    {"city": "Port Harcourt", "zip": "500001"},
    {"city": "Benin City", "zip": "300001"},
    {"city": "Kaduna", "zip": "800001"},
    {"city": "Aba", "zip": "450001"},
    {"city": "Maiduguri", "zip": "600001"},
    {"city": "Zaria", "zip": "810001"},
    {"city": "Abeokuta", "zip": "110001"},
    {"city": "Enugu", "zip": "400001"},
    {"city": "Warri", "zip": "330001"},
    {"city": "Onitsha", "zip": "430001"},
    {"city": "Calabar", "zip": "540001"}
]

streets = [
    "Allen Avenue", "Marina Road", "Adetokunbo Ademola", "Ahmadu Bello Way", 
    "Awolowo Road", "Nnamdi Azikiwe", "Olusegun Obasanjo", "Yakubu Gowon",
    "Herbert Macaulay", "Samuel Ladoke Akintola", "Ibrahim Taiwo", "Murtala Mohammed",
    "Obafemi Awolowo", "Anthony Enahoro", "Michael Okpara", "Adekunle Fajuyi",
    "Aminu Kano", "Oduduwa", "Sultan Abubakar", "Emeka Anyaoku"
]

categories = [
    "Electronics", "Books", "Fashion", "Home & Garden", 
    "Beauty", "Sports", "Toys", "Food"
]

# Generate 200 records
records = []
used_emails = set()

for _ in range(200):
    # Generate unique name and email
    while True:
        first = random.choice(first_names)
        last = random.choice(last_names)
        name = f"{first} {last}"
        email = f"{first.lower()}.{last.lower()}{random.randint(1, 999)}@example.com"
        if email not in used_emails:
            used_emails.add(email)
            break
    
    # Generate phone number
    phone = "+23480" + "".join(random.choices("0123456789", k=8))
    
    # Generate address
    city_data = random.choice(cities)
    address = {
        "street": f"{random.randint(1, 199)} {random.choice(streets)}",
        "city": city_data["city"],
        "zip": city_data["zip"]
    }
    
    # Generate preferences
    marketing_opt_in = random.choice([True, False])
    selected_categories = random.sample(categories, random.randint(1, 3))
    preferences = {
        "marketing_opt_in": marketing_opt_in,
        "categories": selected_categories
    }
    
    # Format record
    records.append(
        f"('{name}', '{email}', '{phone}', "
        f"'{json.dumps(address)}', "
        f"'{json.dumps(preferences)}')"
    )

# Generate SQL
sql = "INSERT INTO customers (name, email, phone, address, preferences)\nVALUES\n"
sql += ",\n".join(records) + ";"

print(sql)

# %% [markdown]
# ## subquerries
#
# breakdown compex queries into managable part
#
# ## types os subqueries
#
# scalar subqueries --> returns a single value
# row  subqueries --> returns a single row
# table subqueries --> returns set of roles

# %%
--SELECT customer_id, name
FROM customers
WHERE customer_id IN (
  SELECT customer_id 
  FROM orders 
  WHERE total_amount > 500
);
# Out:
#   Cell In[4], line 1
#     SELECT customer_id, name
#            ^
# SyntaxError: invalid syntax

# %%
fake = Faker()

# Product categories with attribute templates
categories = {
    "Electronics": {
        "attributes": [
            lambda: {"color": random.choice(["Black", "Silver", "White", "Blue"]),
                     "battery_life": f"{random.randint(5, 48)}h",
                     "weight": f"{random.randint(50, 1000)}g"},
            lambda: {"RAM": f"{random.choice([4,8,16,32])}GB",
                     "storage": f"{random.choice([128,256,512,1000])}GB {random.choice(['SSD','HDD'])}",
                     "screen_size": f"{random.choice([13.3,15.6,17.3])} inch"},
            lambda: {"resolution": f"{random.choice(['4K','FHD','HD'])}",
                     "connectivity": random.choice(["Bluetooth 5.0", "Wi-Fi 6", "USB-C"]),
                     "processor": random.choice(["Intel i5", "AMD Ryzen 7", "Apple M1"])}
        ],
        "products": [
            "Wireless Headphones", "Bluetooth Earbuds", "Smart Watch", 
            "Fitness Tracker", "Tablet", "E-Reader", "Portable Speaker",
            "Gaming Mouse", "Mechanical Keyboard", "External SSD"
        ]
    },
    "Footwear": {
        "attributes": [
            lambda: {"size": str(random.randint(36, 48)),
                     "color": random.choice(["Black", "White", "Blue", "Red", "Gray"]),
                     "material": random.choice(["Leather", "Mesh", "Canvas", "Synthetic"])},
            lambda: {"closure": random.choice(["Lace-up", "Velcro", "Slip-on"]),
                     "sole_material": random.choice(["Rubber", "EVA", "PU"]),
                     "waterproof": random.choice([True, False])}
        ],
        "products": [
            "Running Shoes", "Casual Sneakers", "Hiking Boots", 
            "Formal Oxfords", "Basketball Shoes", "Training Shoes",
            "Sandals", "Flip Flops", "Dress Shoes"
        ]
    },
    "Books": {
        "attributes": [
            lambda: {"author": fake.name(),
                     "pages": random.randint(150, 800),
                     "publisher": fake.company(),
                     "language": "English"},
            lambda: {"format": random.choice(["Hardcover", "Paperback", "e-Book"]),
                     "ISBN": fake.isbn13(),
                     "genre": random.choice(["Fiction", "Non-Fiction"])}
        ],
        "products": [
            "Science Fiction Novel", "Biography", "Self-Help Guide",
            "Cookbook", "History Book", "Programming Textbook",
            "Children's Book", "Poetry Collection", "Business Strategy"
        ]
    },
    "Fashion": {
        "attributes": [
            lambda: {"size": random.choice(["S", "M", "L", "XL"]),
                     "color": fake.safe_color_name(),
                     "material": random.choice(["Cotton", "Polyester", "Silk", "Wool"])},
            lambda: {"care_instructions": random.choice(["Machine Wash", "Dry Clean Only"]),
                     "style": random.choice(["Casual", "Formal", "Vintage", "Modern"])}
        ],
        "products": [
            "T-Shirt", "Jeans", "Dress Shirt", 
            "Summer Dress", "Jacket", "Sweater",
            "Skirt", "Shorts", "Blazer"
        ]
    },
    "Home & Garden": {
        "attributes": [
            lambda: {"dimensions": f"{random.randint(10,200)}x{random.randint(10,200)}cm",
                     "color": fake.safe_color_name(),
                     "material": random.choice(["Wood", "Metal", "Plastic", "Ceramic"])},
            lambda: {"assembly_required": random.choice([True, False]),
                     "weight_capacity": f"{random.randint(5,500)}kg"}
        ],
        "products": [
            "Desk Lamp", "Coffee Table", "Garden Chair", 
            "Storage Cabinet", "Cookware Set", "Bedding Set",
            "Wall Clock", "Decorative Vase", "Tool Kit"
        ]
    },
    "Beauty": {
        "attributes": [
            lambda: {"skin_type": random.choice(["All", "Oily", "Dry", "Sensitive"]),
                     "volume": f"{random.randint(30,500)}ml",
                     "fragrance": random.choice(["Unscented", "Floral", "Citrus", "Woody"])},
            lambda: {"organic": random.choice([True, False]),
                     "cruelty_free": random.choice([True, False])}
        ],
        "products": [
            "Moisturizer", "Shampoo", "Perfume", 
            "Makeup Kit", "Sunscreen", "Face Serum",
            "Lipstick", "Hair Conditioner", "Body Lotion"
        ]
    }
}

# Generate 200 product records
records = []

for _ in range(200):
    # Select random category
    category = random.choice(list(categories.keys()))
    cat_data = categories[category]
    
    # Generate product name
    product_name = f"{random.choice(cat_data['products'])}"
    
    # Add descriptor 30% of the time
    if random.random() < 0.3:
        descriptors = ["Premium", "Pro", "Luxury", "Eco-Friendly", "Wireless", "Smart", "Advanced"]
        product_name = f"{random.choice(descriptors)} {product_name}"
    
    # Generate price (50% between 1-100, 30% 100-500, 15% 500-1000, 5% 1000-2000)
    rand = random.random()
    if rand < 0.5:
        price = round(random.uniform(1, 100), 2)
    elif rand < 0.8:
        price = round(random.uniform(100, 500), 2)
    elif rand < 0.95:
        price = round(random.uniform(500, 1000), 2)
    else:
        price = round(random.uniform(1000, 2000), 2)
    
    # Generate stock quantity (most items 10-500, some 500-1000)
    stock_quantity = random.randint(10, 500) if random.random() < 0.7 else random.randint(500, 1000)
    
    # Generate attributes
    attributes = random.choice(cat_data["attributes"])()
    
    # Format record
    records.append(
        f"('{product_name}', {price}, '{category}', {stock_quantity}, "
        f"'{json.dumps(attributes)}')"
    )

# Generate SQL
sql = "INSERT INTO products (product_name, price, category, stock_quantity, attributes)\nVALUES\n"
sql += ",\n".join(records) + ";"

print(sql)

# %%
# Data pools for randomization
cities = [
    {"city": "Lagos", "zip": "100001"},
    {"city": "Abuja", "zip": "900001"},
    {"city": "Kano", "zip": "700001"},
    {"city": "Ibadan", "zip": "200001"},
    {"city": "Port Harcourt", "zip": "500001"},
    {"city": "Benin City", "zip": "300001"},
    {"city": "Kaduna", "zip": "800001"},
    {"city": "Aba", "zip": "450001"},
    {"city": "Maiduguri", "zip": "600001"},
    {"city": "Zaria", "zip": "810001"}
]

streets = [
    "Allen Avenue", "Marina Road", "Adetokunbo Ademola", "Ahmadu Bello Way", 
    "Awolowo Road", "Nnamdi Azikiwe", "Olusegun Obasanjo", "Yakubu Gowon",
    "Herbert Macaulay", "Samuel Ladoke Akintola", "Ibrahim Taiwo", "Murtala Mohammed",
    "Obafemi Awolowo", "Anthony Enahoro", "Michael Okpara", "Adekunle Fajuyi",
    "Aminu Kano", "Oduduwa", "Sultan Abubakar", "Emeka Anyaoku"
]

coupons = ["SUMMER20", "WELCOME10", "FREESHIP", "SAVE15", "NEWUSER25", "WINTER30", None]
sources = ["mobile", "desktop", "tablet"]
statuses = ["Pending", "Processing", "Shipped", "Delivered", "Cancelled"]

# Generate 200 records
records = []
start_date = datetime(2025, 1, 1)
end_date = datetime(2025, 7, 5)

for i in range(1, 201):
    # Random customer ID (assuming 200 customers exist)
    customer_id = random.randint(1, 200)
    
    # Random date between Jan 1, 2025 and today
    days_diff = (end_date - start_date).days
    random_days = random.randint(0, days_diff)
    order_date = (start_date + timedelta(days=random_days)).strftime("%Y-%m-%d")
    
    # Random total amount (50% < ₦10k, 30% ₦10k-₦50k, 15% ₦50k-₦100k, 5% > ₦100k)
    rand = random.random()
    if rand < 0.5:
        total_amount = round(random.uniform(1000, 10000), 2)
    elif rand < 0.8:
        total_amount = round(random.uniform(10000, 50000), 2)
    elif rand < 0.95:
        total_amount = round(random.uniform(50000, 100000), 2)
    else:
        total_amount = round(random.uniform(100000, 250000), 2)
    
    # Random status with realistic distribution
    status_weights = [0.15, 0.25, 0.35, 0.2, 0.05]  # More shipped/delivered, fewer cancelled
    status = random.choices(statuses, weights=status_weights, k=1)[0]
    
    # Generate shipping address
    city_data = random.choice(cities)
    address = {
        "street": f"{random.randint(1, 199)} {random.choice(streets)}",
        "city": city_data["city"],
        "zip": city_data["zip"]
    }
    
    # Generate metadata
    metadata = {}
    metadata["source"] = random.choice(sources)
    
    # Gift wrap 20% of orders
    if random.random() < 0.2:
        metadata["gift_wrap"] = True
    
    # Coupon 30% of orders
    coupon = random.choice(coupons)
    if coupon:
        metadata["coupon"] = coupon
    
    # Add notes for 10% of orders
    if random.random() < 0.1:
        notes = [
            "Handle with care", "Fragile package", "Leave at front desk",
            "Gift for anniversary", "Birthday present", "Signature required",
            "Don't ring doorbell", "Call before delivery"
        ]
        metadata["notes"] = random.choice(notes)
    
    # Format record with proper escaping
    address_str = json.dumps(address).replace("'", "''")
    metadata_str = json.dumps(metadata).replace("'", "''")
    
    records.append(
        f"({customer_id}, '{order_date}', {total_amount}, '{status}', "
        f"'{address_str}', '{metadata_str}')"
    )

# Generate SQL
sql = "INSERT INTO orders (customer_id, order_date, total_amount, status, shipping_address, metadata)\nVALUES\n"
sql += ",\n".join(records) + ";"

print(sql)

# %%
# Generate between 200 and 1000 order items (1-5 items per order)
num_orders = 200
records = []
order_item_counts = [random.randint(1, 5) for _ in range(num_orders)]
total_items = sum(order_item_counts)

# Used to track products per order to avoid duplicates
order_products = {}

for order_id in range(1, num_orders + 1):
    # Determine how many items in this order
    num_items = order_item_counts[order_id - 1]
    
    # Select distinct products for this order
    product_ids = random.sample(range(1, 201), num_items)
    order_products[order_id] = product_ids
    
    for product_id in product_ids:
        # Generate quantity (mostly 1-3, occasionally more)
        quantity = random.randint(1, 3) if random.random() < 0.8 else random.randint(4, 10)
        
        # Generate realistic price (based on product category ranges)
        category_based_price = {
            "Electronics": random.uniform(5000, 150000),
            "Footwear": random.uniform(2000, 30000),
            "Books": random.uniform(500, 10000),
            "Fashion": random.uniform(1500, 25000),
            "Home & Garden": random.uniform(1000, 50000),
            "Beauty": random.uniform(800, 20000)
        }
        price = round(random.choice(list(category_based_price.values())), 2)
        
        # Generate discount (70% no discount, 20% small discount, 10% large discount)
        if random.random() < 0.7:
            discount = 0.00
        elif random.random() < 0.9:
            discount = round(price * random.uniform(0.05, 0.2), 2)
        else:
            discount = round(price * random.uniform(0.25, 0.5), 2)
        
        # Generate item attributes
        attributes = {}
        
        # Common attributes
        if random.random() < 0.4:
            attributes["warranty"] = random.choice(["6 months", "1 year", "2 years"])
        if random.random() < 0.3:
            attributes["bundle_offer"] = True
        
        # Size-based attributes
        if random.random() < 0.3:
            attributes["size"] = random.choice(["S", "M", "L", "XL"])
        
        # Color attributes
        if random.random() < 0.25:
            attributes["color"] = random.choice(["Black", "White", "Red", "Blue", "Green"])
        
        # Special attributes
        if random.random() < 0.15:
            special_attrs = {
                "RAM_upgrade": random.choice(["16GB", "32GB", "64GB"]),
                "storage_upgrade": random.choice(["512GB SSD", "1TB SSD", "2TB HDD"]),
                "gift_wrap": True,
                "engraving": random.choice(["Initials", "Message", "Date"]),
                "installation": random.choice(["Basic", "Premium", "Professional"])
            }
            # Fix: add a single random special attribute key-value pair
            key, value = random.choice(list(special_attrs.items()))
            attributes[key] = value
        
        # Escape single quotes in JSON
        attr_str = json.dumps(attributes).replace("'", "''")
        
        records.append(
            f"({order_id}, {product_id}, {quantity}, {price}, {discount}, '{attr_str}')"
        )

# Generate SQL
sql = "INSERT INTO order_items (order_id, product_id, quantity, price, discount, item_attributes)\nVALUES\n"
sql += ",\n".join(records) + ";"

print(sql)

# %%
# Department data with realistic Nigerian context
departments = [
    {
        "name": "Sales",
        "locations": ["Lagos HQ", "Abuja Office", "Port Harcourt Branch", "Kano Regional Office"],
        "metadata": {
            "budget": lambda: f"₦{random.randint(50, 200)}M",
            "target_market": "Nigeria",
            "sales_quota": lambda: f"₦{random.randint(20, 100)}M/month"
        }
    },
    {
        "name": "IT",
        "locations": ["Lagos Tech Hub", "Abuja Data Center", "Port Harcourt Support Office"],
        "metadata": {
            "budget": lambda: f"₦{random.randint(30, 100)}M",
            "projects": lambda: random.sample([
                "E-commerce Platform", "Internal Tools", "Mobile App Development",
                "Network Infrastructure", "Cybersecurity Upgrade", "Data Migration",
                "Cloud Migration", "ERP Implementation"
            ], random.randint(2, 4)),
            "tech_stack": lambda: random.sample([
                "Python", "Java", "Node.js", "React", "Angular", "AWS", "Azure",
                "Docker", "Kubernetes", "MySQL", "MongoDB"
            ], random.randint(3, 5))
        }
    },
    {
        "name": "Marketing",
        "locations": ["Lagos Creative Center", "Abuja Strategy Office"],
        "metadata": {
            "budget": lambda: f"₦{random.randint(20, 80)}M",
            "channels": lambda: random.sample([
                "Social Media", "TV", "Radio", "Influencers", "Events",
                "Email", "Search Ads", "Content Marketing"
            ], random.randint(3, 5)),
            "target_demographic": random.choice([
                "Youth (18-25)", "Professionals (25-40)", "Families", "Business Owners"
            ])
        }
    },
    {
        "name": "Finance",
        "locations": ["Lagos HQ", "Abuja Regional Office"],
        "metadata": {
            "budget": lambda: f"₦{random.randint(100, 500)}M",
            "responsibilities": [
                "Accounts Payable", "Accounts Receivable", "Payroll",
                "Financial Reporting", "Tax Compliance", "Auditing"
            ],
            "reporting_frequency": "Monthly"
        }
    },
    {
        "name": "Operations",
        "locations": ["Lagos Logistics Hub", "Port Harcourt Warehouse", "Kano Distribution Center"],
        "metadata": {
            "budget": lambda: f"₦{random.randint(40, 120)}M",
            "facilities": lambda: random.sample([
                "Main Warehouse", "Regional Distribution Centers", "Fleet Management",
                "Inventory Control", "Quality Assurance"
            ], random.randint(2, 4)),
            "coverage": "National"
        }
    },
    {
        "name": "Human Resources",
        "locations": ["Lagos HQ", "Abuja Regional HR"],
        "metadata": {
            "budget": lambda: f"₦{random.randint(15, 50)}M",
            "functions": [
                "Recruitment", "Training & Development", "Compensation & Benefits",
                "Employee Relations", "Performance Management"
            ],
            "employee_count": lambda: random.randint(50, 500)
        }
    },
    {
        "name": "Customer Service",
        "locations": ["Lagos Call Center", "Port Harcourt Support Office", "Abuja Helpdesk"],
        "metadata": {
            "budget": lambda: f"₦{random.randint(10, 40)}M",
            "channels": ["Phone", "Email", "Chat", "Social Media"],
            "sla": "24-hour response time"
        }
    }
]

# Generate 10-15 departments
num_departments = random.randint(10, 15)
records = []
used_names = set()

for _ in range(num_departments):
    # Select random department template
    dept_template = random.choice(departments)
    
    # Ensure unique department names
    base_name = dept_template["name"]
    name = base_name
    suffix_count = 1
    
    while name in used_names:
        suffix_count += 1
        name = f"{base_name} {suffix_count}"
    
    used_names.add(name)
    
    # Select location
    location = random.choice(dept_template["locations"])
    
    # Generate metadata with dynamic values
    metadata = {}
    for key, value in dept_template["metadata"].items():
        if callable(value):
            metadata[key] = value()
        else:
            metadata[key] = value
    
    # Properly escape single quotes in JSON
    metadata_str = json.dumps(metadata).replace("'", "''")
    
    # Escape department names with single quotes
    escaped_name = name.replace("'", "''")
    
    records.append(
        f"('{escaped_name}', '{location}', '{metadata_str}')"
    )

# Generate SQL
sql = "INSERT INTO departments (name, location, metadata)\nVALUES\n"
sql += ",\n".join(records) + ";"

print(sql)

# %%
fake = Faker()

# Department types and roles mapping
base_departments = {
    1: "Sales", 2: "IT", 3: "Marketing", 
    4: "Finance", 5: "Operations", 
    6: "Human Resources", 7: "Customer Service"
}

department_roles = {
    "Sales": {
        "manager": ["Sales Manager", "Head of Sales", "Sales Director", "Regional Sales Lead"],
        "staff": ["Sales Associate", "Account Executive", "Sales Representative", "Business Development"]
    },
    "IT": {
        "manager": ["IT Manager", "CTO", "Tech Lead", "Systems Architect", "DevOps Manager"],
        "staff": ["Software Engineer", "System Admin", "Network Engineer", "IT Support", "Data Analyst"]
    },
    "Marketing": {
        "manager": ["Marketing Director", "Brand Manager", "Digital Marketing Lead"],
        "staff": ["Marketing Specialist", "Content Creator", "SEO Analyst", "Social Media Manager"]
    },
    "Finance": {
        "manager": ["Finance Manager", "CFO", "Accounting Lead", "Financial Controller"],
        "staff": ["Accountant", "Financial Analyst", "Auditor", "Payroll Specialist"]
    },
    "Operations": {
        "manager": ["Operations Manager", "Logistics Director", "Supply Chain Lead"],
        "staff": ["Operations Coordinator", "Inventory Specialist", "Quality Assurance", "Facilities Manager"]
    },
    "Human Resources": {
        "manager": ["HR Manager", "Talent Acquisition Lead", "HR Director"],
        "staff": ["HR Associate", "Recruiter", "Training Coordinator", "Compensation Analyst"]
    },
    "Customer Service": {
        "manager": ["Customer Service Manager", "Support Lead", "Client Success Director"],
        "staff": ["Customer Support", "Client Success Agent", "Helpdesk Technician", "Service Coordinator"]
    }
}

# Nigerian names
first_names = [
    "Chinedu", "Ngozi", "Oluwaseun", "Aisha", "Emeka", "Fatima", "Chukwu", "Amina", 
    "Tunde", "Zainab", "Okonkwo", "Chiamaka", "Musa", "Ebere", "Obinna", "Ifeoma",
    "Kunle", "Adanna", "Sani", "Chioma", "Wale", "Deborah", "Abdul", "Amara", 
    "Jide", "Nneka", "Yusuf", "Funke", "Femi", "Yewande"
]

last_names = [
    "Adeyemi", "Okoro", "Mohammed", "Okafor", "Ibrahim", "Nwosu", "Sule", "Chukwu",
    "Bello", "Ogunleye", "Balogun", "Aliyu", "Akintola", "Onyema", "Bakare", "Umar",
    "Oladipo", "Akinwande", "Alade", "Okonkwo", "Onyeka", "Ogbonna", "Eze", "Adewale",
    "Ojo", "Adeleke", "Onyia", "Uche", "Okoh", "Onyeama"
]

# Skills by department
skills_mapping = {
    "Sales": {
        "manager": {
            "sales_skills": ["Strategic Planning", "Key Account Management", "CRM Systems", "Sales Forecasting"],
            "soft_skills": ["Leadership", "Negotiation", "Presentation", "Decision Making"]
        },
        "staff": {
            "sales_skills": ["Prospecting", "Customer Engagement", "Product Knowledge", "Sales Presentations"],
            "soft_skills": ["Communication", "Active Listening", "Persuasion", "Resilience"]
        }
    },
    "IT": {
        "manager": {
            "technical_skills": ["System Architecture", "Cloud Infrastructure", "DevOps", "Security"],
            "management_skills": ["Project Management", "Team Leadership", "Budgeting", "Vendor Management"]
        },
        "staff": {
            "technical_skills": ["Programming", "Database Management", "Networking", "Troubleshooting"],
            "certifications": ["AWS Certified", "Cisco Certified", "Microsoft Certified", "CompTIA"]
        }
    },
    "Marketing": {
        "manager": {
            "marketing_skills": ["Brand Strategy", "Campaign Management", "Market Research", "Digital Marketing"],
            "analytical_skills": ["ROI Analysis", "KPI Tracking", "Customer Segmentation", "Budget Management"]
        },
        "staff": {
            "marketing_skills": ["Content Creation", "Social Media", "SEO/SEM", "Email Marketing"],
            "creative_skills": ["Graphic Design", "Copywriting", "Video Production", "UX/UI"]
        }
    },
    "Finance": {
        "manager": {
            "finance_skills": ["Financial Planning", "Risk Management", "Investment Analysis", "Compliance"],
            "certifications": ["CFA", "CPA", "ACCA", "FRM"]
        },
        "staff": {
            "finance_skills": ["Bookkeeping", "Financial Reporting", "Tax Preparation", "Payroll Processing"],
            "software_skills": ["QuickBooks", "SAP", "Excel", "Oracle Financials"]
        }
    },
    "Operations": {
        "manager": {
            "operations_skills": ["Supply Chain Management", "Logistics", "Process Optimization", "Quality Control"],
            "management_skills": ["Team Leadership", "Budget Management", "Vendor Negotiation", "Strategic Planning"]
        },
        "staff": {
            "operations_skills": ["Inventory Management", "Order Fulfillment", "Facility Management", "Documentation"],
            "technical_skills": ["ERP Systems", "Warehouse Management", "Six Sigma", "Safety Compliance"]
        }
    },
    "Human Resources": {
        "manager": {
            "hr_skills": ["Talent Acquisition", "Compensation & Benefits", "Employee Relations", "Performance Management"],
            "certifications": ["PHR", "SPHR", "SHRM-CP", "HRCI"]
        },
        "staff": {
            "hr_skills": ["Recruitment", "Onboarding", "HR Administration", "Training Coordination"],
            "soft_skills": ["Conflict Resolution", "Communication", "Empathy", "Discretion"]
        }
    },
    "Customer Service": {
        "manager": {
            "service_skills": ["Customer Experience", "Complaint Resolution", "Service Strategy", "Quality Assurance"],
            "management_skills": ["Team Leadership", "Performance Metrics", "Training Development", "Process Improvement"]
        },
        "staff": {
            "service_skills": ["Phone Etiquette", "Ticket Management", "Product Knowledge", "Customer Retention"],
            "soft_skills": ["Patience", "Empathy", "Communication", "Problem Solving"]
        }
    }
}

# Generate 200 employees
records = []
manager_ids_by_dept = {dept_id: [] for dept_id in range(1, 16)}
employee_counter = 1

for dept_id in range(1, 16):
    # Determine department type
    base_type = base_departments.get((dept_id - 1) % 7 + 1, "Operations")
    
    # Determine number of employees in this department (weighted distribution)
    weights = [5, 4, 4, 3, 3, 3, 2, 2, 2, 2, 1, 1, 1, 1, 1]
    dept_size = max(3, int(200 * weights[dept_id-1] / sum(weights)))
    
    # Determine number of managers (1-3)
    num_managers = min(3, max(1, dept_size // 5))
    
    # Generate managers first
    for i in range(num_managers):
        # Name
        first = random.choice(first_names)
        last = random.choice(last_names)
        name = f"{first} {last}"
        
        # Department ID
        dept = dept_id
        
        # Manager ID (NULL for managers)
        manager_id = "NULL"
        
        # Role
        role = random.choice(department_roles[base_type]["manager"])
        
        # Hire date (earlier for managers)
        hire_date = fake.date_between(start_date=datetime(2015, 1, 1), 
                                     end_date=datetime(2020, 12, 31)).strftime("%Y-%m-%d")
        
        # Salary (higher for managers)
        salary = round(random.uniform(3500, 10000), 2)
        
        # Contact info
        email = f"{first.lower()}.{last.lower()}{random.randint(1, 999)}@company.com"
        phone = "+23480" + "".join(random.choices("0123456789", k=8))
        contact_info = {"email": email, "phone": phone}
        
        # Skills
        skills = {}
        for category, items in skills_mapping[base_type]["manager"].items():
            skills[category] = random.sample(items, min(len(items), random.randint(1, 3)))
        
        # Add to manager tracking
        manager_ids_by_dept[dept_id].append(employee_counter)
        
        # Format record
        records.append((
            name, dept, manager_id, role, hire_date, salary, 
            json.dumps(contact_info), json.dumps(skills)
        ))
        employee_counter += 1
    
    # Generate non-manager staff
    for i in range(num_managers, dept_size):
        # Name
        first = random.choice(first_names)
        last = random.choice(last_names)
        name = f"{first} {last}"
        
        # Department ID
        dept = dept_id
        
        # Manager ID (random from department's managers)
        manager_id = random.choice(manager_ids_by_dept[dept_id])
        
        # Role
        role = random.choice(department_roles[base_type]["staff"])
        
        # Hire date (more recent)
        hire_date = fake.date_between(start_date=datetime(2018, 1, 1), 
                                     end_date=datetime(2025, 7, 5)).strftime("%Y-%m-%d")
        
        # Salary (lower range)
        salary = round(random.uniform(1500, 5000), 2)
        
        # Contact info
        email = f"{first.lower()}.{last.lower()}{random.randint(1, 999)}@company.com"
        phone = "+23480" + "".join(random.choices("0123456789", k=8))
        contact_info = {"email": email, "phone": phone}
        
        # Skills
        skills = {}
        for category, items in skills_mapping[base_type]["staff"].items():
            skills[category] = random.sample(items, min(len(items), random.randint(1, 3)))
        
        # Format record
        records.append((
            name, dept, manager_id, role, hire_date, salary, 
            json.dumps(contact_info), json.dumps(skills)
        ))
        employee_counter += 1

# Format SQL with proper escaping
sql_records = []
for record in records:
    name, dept_id, manager_id, role, hire_date, salary, contact_info, skills = record
    
    # Escape single quotes
    escaped_name = name.replace("'", "''")
    escaped_role = role.replace("'", "''")
    escaped_contact = contact_info.replace("'", "''")
    escaped_skills = skills.replace("'", "''")
    
    sql_records.append(
        f"('{escaped_name}', {dept_id}, {manager_id}, '{escaped_role}', "
        f"'{hire_date}', {salary}, '{escaped_contact}', '{escaped_skills}')"
    )

# Generate SQL
sql = "INSERT INTO employees (name, department_id, manager_id, role, hire_date, salary, contact_info, skills)\nVALUES\n"
sql += ",\n".join(sql_records) + ";"

print(sql)

# %%
-- Find customers who have placed orders over $1000.
-- (Query: Get names and emails of customers with orders over $1000)
SELECT name, email
FROM customers c
WHERE customer_id IN (
    SELECT customer_id
    FROM orders
    WHERE total_amount > 1000
);

-- Find all products above the average product price
SELECT product_id, product_name, price
FROM products p
WHERE price > (
    SELECT AVG(price) FROM products
);

-- (Optional: Get the average product price)
-- SELECT AVG(price) FROM products;



-- Get the total number of orders per customer, but only for customers who have made at least 2 orders
SELECT customer_id, total_orders
FROM (
    SELECT customer_id, COUNT(*) AS total_orders
    FROM orders o
    GROUP BY customer_id
) AS customer_order_counts
WHERE total_orders >= 2;


-- Example of a Common Table Expression (CTE)
-- (Template)
-- WITH cte_name AS (
--     SELECT ...
-- )
-- SELECT ... FROM cte_name;

-- Find products priced above the average product price using a CTE
WITH avg_price AS (
    SELECT AVG(price) AS avg_price
    FROM products
)
SELECT product_id, product_name, price
FROM products p, avg_price a
WHERE p.price > a.avg_price;

-- Find top 3 customers by total spending using CTEs
WITH customer_spending AS (
    SELECT customer_id, SUM(total_amount) AS total_spent
    FROM orders
    GROUP BY customer_id
),
top_customers AS (
    SELECT customer_id, total_spent
    FROM customer_spending
    ORDER BY total_spent DESC
    LIMIT 3
)
SELECT c.name, tc.total_spent
FROM customers c
JOIN top_customers tc ON c.customer_id = tc.customer_id
ORDER BY total_spent DESC;

# %% [markdown]
# # Assignment
#
# 1. Find employees whose salary is above the average salary for their department
# 2. Retrieve the customer details for all the customer ids returned in the query above.
# 3. Also, find orders where the total amount is greater than the average order total for that customer,
#    and that customer's total spending is above the global average customer spending.
# 4. Find orders where the total amount is greater than the average order total for that customer, and that customer’s total spending is above the global average customer spending.
#
# find link to codefile here for table schema definition here: https://codefile.io/f/B3IkAGd2eQ#

# %% [markdown]
# ## Submission requirements
#
# - complete the SQL queries in the provided template, and write a brief explanation of the reasoning behind each query.
# - create all necessary tables and insert sample data into them.
# - run the queries in your workbench and provide the screenshot of the query and results.
# - submit the SQL queries, sample data, and screenshots as a single zip file or upload file to your github repository and share the link.
#
# :. submission link: https://forms.gle/2dkSDW2BQuB6VRcD7

# %%
create table customers (
    customer_id SERIAL PRIMARY KEY,
    name VARCHAR(100),
    email VARCHAR(150),
    phone VARCHAR(20),
    address JSONB, -- store address as JSON: street, city, zip
    preferences JSONB, -- store flexible preferences: marketing_opt_in, categories
    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);



CREATE TABLE products (
   product_id SERIAL PRIMARY KEY,
   product_name VARCHAR(150),
   price DECIMAL(10,2),
   category VARCHAR(50),
   stock_quantity INT,
   attributes JSONB, -- flexible product details: size, color, specs
   is_active BOOLEAN DEFAULT TRUE,
   created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
 );

CREATE TABLE orders (
   order_id SERIAL PRIMARY KEY,
   customer_id INT,
   order_date DATE,
   total_amount DECIMAL(10,2),
   status VARCHAR(50), -- e.g. Pending, Shipped, Delivered
   shipping_address JSONB, -- store shipping details
   metadata JSONB, -- flexible: coupon used, source, device
   created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
 );


CREATE TABLE order_items (
   order_item_id SERIAL PRIMARY KEY,
   order_id INT,
   product_id INT,
   quantity INT,
   price DECIMAL(10,2),
   discount DECIMAL(10,2),
   item_attributes JSONB -- store variations: size, color
 );


CREATE TABLE departments (
   department_id SERIAL PRIMARY KEY,
   name VARCHAR(50),
   location VARCHAR(100),
   metadata JSONB -- any extra info: budget, policies
 );


CREATE TABLE employees (
   employee_id SERIAL PRIMARY KEY,
   name VARCHAR(100),
   department_id INT,
   manager_id INT,
   role VARCHAR(50),
   hire_date DATE,
   salary DECIMAL(10,2),
  contact_info JSONB, -- email, phone, emergency contacts
   skills JSONB -- flexible list of skills, trainings, certifications
 );



insert into customers (name, email, phone, address, preferences)
VALUES
('Funke Alade', 'funke.alade354@example.com', '+2348092357392', '{"street": "134 Emeka Anyaoku", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": false, "categories": ["Books", "Food"]}'),
('Amina Ojo', 'amina.ojo47@example.com', '+2348054403255', '{"street": "10 Sultan Abubakar", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Blessing Onyema', 'blessing.onyema543@example.com', '+2348046420792', '{"street": "96 Ibrahim Taiwo", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Fashion", "Food"]}'),
('Chidinma Akintola', 'chidinma.akintola725@example.com', '+2348022958022', '{"street": "157 Nnamdi Azikiwe", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden"]}'),
('Grace Adeyemi', 'grace.adeyemi834@example.com', '+2348027028635', '{"street": "100 Marina Road", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Books", "Sports", "Electronics"]}'),
('Deborah Onyia', 'deborah.onyia857@example.com', '+2348082509708', '{"street": "62 Anthony Enahoro", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": false, "categories": ["Electronics"]}'),
('Mohammed Mustapha', 'mohammed.mustapha555@example.com', '+2348004348116', '{"street": "97 Adekunle Fajuyi", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": false, "categories": ["Toys", "Home & Garden"]}'),
('Yusuf Oladipo', 'yusuf.oladipo298@example.com', '+2348040396357', '{"street": "136 Allen Avenue", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Food", "Books"]}'),
('Jide Bello', 'jide.bello282@example.com', '+2348002068180', '{"street": "167 Emeka Anyaoku", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": false, "categories": ["Books"]}'),
('Chukwu Ojo', 'chukwu.ojo218@example.com', '+2348081424701', '{"street": "36 Nnamdi Azikiwe", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Food", "Fashion", "Sports"]}'),
('Sani Akintola', 'sani.akintola155@example.com', '+2348008014686', '{"street": "21 Yakubu Gowon", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": false, "categories": ["Beauty"]}'),
('Abdul Akinwande', 'abdul.akinwande585@example.com', '+2348084749052', '{"street": "152 Obafemi Awolowo", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": true, "categories": ["Toys"]}'),
('Chinedu Bello', 'chinedu.bello130@example.com', '+2348004930382', '{"street": "61 Michael Okpara", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Food", "Books"]}'),
('Fatima Ojo', 'fatima.ojo669@example.com', '+2348036619609', '{"street": "152 Samuel Ladoke Akintola", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden"]}'),
('Okonkwo Okorie', 'okonkwo.okorie175@example.com', '+2348084723934', '{"street": "105 Adetokunbo Ademola", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Sports"]}'),
('Chika Balogun', 'chika.balogun586@example.com', '+2348070191151', '{"street": "94 Michael Okpara", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": false, "categories": ["Books", "Home & Garden"]}'),
('Ade Okafor', 'ade.okafor35@example.com', '+2348074042753', '{"street": "126 Samuel Ladoke Akintola", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Sports"]}'),
('Sani Akintola', 'sani.akintola823@example.com', '+2348086648720', '{"street": "86 Marina Road", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Books", "Home & Garden", "Electronics"]}'),
('Chukwu Okoh', 'chukwu.okoh11@example.com', '+2348081076429', '{"street": "63 Ibrahim Taiwo", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden", "Books"]}'),
('Zara Balogun', 'zara.balogun209@example.com', '+2348070156137', '{"street": "143 Sultan Abubakar", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Sports"]}'),
('Bola Okafor', 'bola.okafor282@example.com', '+2348009311947', '{"street": "97 Olusegun Obasanjo", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Electronics"]}'),
('Olu Okafor', 'olu.okafor994@example.com', '+2348080719108', '{"street": "15 Emeka Anyaoku", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden"]}'),
('Amara Ogbonna', 'amara.ogbonna816@example.com', '+2348054211410', '{"street": "34 Samuel Ladoke Akintola", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": true, "categories": ["Sports"]}'),
('Zainab Ogunleye', 'zainab.ogunleye746@example.com', '+2348077759825', '{"street": "83 Herbert Macaulay", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Home & Garden"]}'),
('Ibrahim Olu', 'ibrahim.olu423@example.com', '+2348005311153', '{"street": "118 Olusegun Obasanjo", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": true, "categories": ["Beauty"]}'),
('Chidinma Ibrahim', 'chidinma.ibrahim29@example.com', '+2348087440523', '{"street": "47 Emeka Anyaoku", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Toys"]}'),
('Ifeoma Eze', 'ifeoma.eze930@example.com', '+2348019120842', '{"street": "167 Michael Okpara", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Food", "Books"]}'),
('Jide Onyeka', 'jide.onyeka287@example.com', '+2348042287488', '{"street": "177 Yakubu Gowon", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Food", "Fashion"]}'),
('Chioma Nwosu', 'chioma.nwosu494@example.com', '+2348048599499', '{"street": "178 Emeka Anyaoku", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Beauty", "Fashion"]}'),
('Emeka Bakare', 'emeka.bakare88@example.com', '+2348056808769', '{"street": "108 Adekunle Fajuyi", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Books"]}'),
('Amara Adeyemi', 'amara.adeyemi207@example.com', '+2348052201007', '{"street": "110 Emeka Anyaoku", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Fashion", "Toys"]}'),
('Musa Okoh', 'musa.okoh433@example.com', '+2348009480404', '{"street": "61 Awolowo Road", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Toys"]}'),
('Blessing Afolayan', 'blessing.afolayan369@example.com', '+2348038868945', '{"street": "74 Adetokunbo Ademola", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Toys", "Home & Garden"]}'),
('Wale Onyeka', 'wale.onyeka919@example.com', '+2348071760903', '{"street": "48 Marina Road", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Beauty", "Fashion"]}'),
('Chioma Adeleke', 'chioma.adeleke560@example.com', '+2348042490199', '{"street": "1 Nnamdi Azikiwe", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": false, "categories": ["Books"]}'),
('Segun Yusuf', 'segun.yusuf972@example.com', '+2348007614967', '{"street": "153 Michael Okpara", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Sports"]}'),
('Temitope Balogun', 'temitope.balogun146@example.com', '+2348082778447', '{"street": "22 Aminu Kano", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": true, "categories": ["Food", "Fashion", "Home & Garden"]}'),
('Okonkwo Ojo', 'okonkwo.ojo500@example.com', '+2348073070301', '{"street": "135 Aminu Kano", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": true, "categories": ["Food"]}'),
('Eze Okorie', 'eze.okorie46@example.com', '+2348016350721', '{"street": "95 Emeka Anyaoku", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Food", "Beauty", "Books"]}'),
('Eze Eze', 'eze.eze531@example.com', '+2348058719335', '{"street": "61 Obafemi Awolowo", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Toys"]}'),
('Musa Adeleke', 'musa.adeleke602@example.com', '+2348080943038', '{"street": "145 Oduduwa", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Home & Garden"]}'),
('Emeka Onyeama', 'emeka.onyeama284@example.com', '+2348098931905', '{"street": "11 Adetokunbo Ademola", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Food", "Electronics"]}'),
('Amara Nwosu', 'amara.nwosu134@example.com', '+2348007740614', '{"street": "160 Samuel Ladoke Akintola", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Fashion"]}'),
('Zara Adeyemi', 'zara.adeyemi241@example.com', '+2348000035440', '{"street": "140 Oduduwa", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden"]}'),
('Ifeoma Okorie', 'ifeoma.okorie385@example.com', '+2348078777396', '{"street": "198 Nnamdi Azikiwe", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": false, "categories": ["Beauty"]}'),
('Segun Balogun', 'segun.balogun419@example.com', '+2348088762181', '{"street": "153 Michael Okpara", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Fashion"]}'),
('Okonkwo Alade', 'okonkwo.alade829@example.com', '+2348072218884', '{"street": "127 Anthony Enahoro", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Electronics", "Food"]}'),
('Kemi Ibrahim', 'kemi.ibrahim15@example.com', '+2348046805030', '{"street": "192 Aminu Kano", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Beauty", "Toys", "Food"]}'),
('Obinna Chukwu', 'obinna.chukwu954@example.com', '+2348068278782', '{"street": "163 Anthony Enahoro", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": false, "categories": ["Food", "Electronics", "Fashion"]}'),
('Wale Okafor', 'wale.okafor458@example.com', '+2348030337470', '{"street": "93 Ibrahim Taiwo", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": false, "categories": ["Books", "Sports", "Food"]}'),
('Adanna Umar', 'adanna.umar549@example.com', '+2348017276605', '{"street": "152 Murtala Mohammed", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Home & Garden", "Food"]}'),
('Fatima Ogbonna', 'fatima.ogbonna603@example.com', '+2348040931023', '{"street": "112 Awolowo Road", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Food", "Books", "Beauty"]}'),
('Halima Adewale', 'halima.adewale61@example.com', '+2348022548824', '{"street": "197 Michael Okpara", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Food", "Electronics", "Home & Garden"]}'),
('Kemi Mustapha', 'kemi.mustapha913@example.com', '+2348090771278', '{"street": "97 Ahmadu Bello Way", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Beauty", "Electronics"]}'),
('Musa Onyia', 'musa.onyia941@example.com', '+2348040577188', '{"street": "152 Allen Avenue", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Books", "Home & Garden", "Sports"]}'),
('Grace Okonkwo', 'grace.okonkwo773@example.com', '+2348017568261', '{"street": "53 Samuel Ladoke Akintola", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Home & Garden", "Food"]}'),
('Femi Okonkwo', 'femi.okonkwo556@example.com', '+2348026727392', '{"street": "43 Herbert Macaulay", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Kunle Onyeama', 'kunle.onyeama826@example.com', '+2348034438968', '{"street": "167 Oduduwa", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Home & Garden", "Beauty"]}'),
('Segun Bello', 'segun.bello13@example.com', '+2348038742243', '{"street": "83 Michael Okpara", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Home & Garden", "Fashion"]}'),
('Musa Akinwande', 'musa.akinwande961@example.com', '+2348063424259', '{"street": "57 Herbert Macaulay", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Food", "Beauty"]}'),
('Kunle Umar', 'kunle.umar239@example.com', '+2348086474138', '{"street": "9 Michael Okpara", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Fashion"]}'),
('Adanna Adebayo', 'adanna.adebayo705@example.com', '+2348099342851', '{"street": "17 Ahmadu Bello Way", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Food"]}'),
('Jide Okoh', 'jide.okoh77@example.com', '+2348042395546', '{"street": "56 Yakubu Gowon", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Food"]}'),
('Patience Chukwu', 'patience.chukwu788@example.com', '+2348034021023', '{"street": "83 Michael Okpara", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Beauty", "Home & Garden"]}'),
('Chinedu Mustapha', 'chinedu.mustapha158@example.com', '+2348062702107', '{"street": "183 Allen Avenue", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Home & Garden", "Food"]}'),
('Amina Balogun', 'amina.balogun27@example.com', '+2348035759238', '{"street": "182 Aminu Kano", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Books", "Electronics", "Toys"]}'),
('Okonkwo Okeke', 'okonkwo.okeke640@example.com', '+2348010140712', '{"street": "24 Michael Okpara", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Books"]}'),
('Segun Mustapha', 'segun.mustapha272@example.com', '+2348016567262', '{"street": "108 Awolowo Road", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": false, "categories": ["Sports"]}'),
('Funke Ogunleye', 'funke.ogunleye482@example.com', '+2348084763550', '{"street": "96 Sultan Abubakar", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Toys", "Sports"]}'),
('Abdul Okoh', 'abdul.okoh205@example.com', '+2348053438207', '{"street": "9 Murtala Mohammed", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden"]}'),
('Okonkwo Alade', 'okonkwo.alade465@example.com', '+2348067859078', '{"street": "47 Olusegun Obasanjo", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Home & Garden", "Food"]}'),
('Deborah Akintola', 'deborah.akintola998@example.com', '+2348062930165', '{"street": "97 Adetokunbo Ademola", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Electronics"]}'),
('Fatima Mohammed', 'fatima.mohammed623@example.com', '+2348068939635', '{"street": "32 Michael Okpara", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Fashion", "Toys"]}'),
('Deborah Uche', 'deborah.uche971@example.com', '+2348099614292', '{"street": "114 Oduduwa", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Fashion", "Electronics"]}'),
('Abdul Olu', 'abdul.olu140@example.com', '+2348081145264', '{"street": "86 Adekunle Fajuyi", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Toys"]}'),
('Tunde Okorie', 'tunde.okorie892@example.com', '+2348075984354', '{"street": "1 Murtala Mohammed", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Electronics"]}'),
('Ifeoma Akinwande', 'ifeoma.akinwande556@example.com', '+2348015334315', '{"street": "189 Nnamdi Azikiwe", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Electronics"]}'),
('Amara Eze', 'amara.eze297@example.com', '+2348033956543', '{"street": "17 Samuel Ladoke Akintola", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Home & Garden", "Beauty"]}'),
('Mohammed Obi', 'mohammed.obi48@example.com', '+2348069050345', '{"street": "174 Yakubu Gowon", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Beauty"]}'),
('Zara Obi', 'zara.obi283@example.com', '+2348077058684', '{"street": "23 Samuel Ladoke Akintola", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Beauty"]}'),
('Tunde Adeleke', 'tunde.adeleke313@example.com', '+2348085069055', '{"street": "19 Marina Road", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": false, "categories": ["Toys", "Food"]}'),
('Temitope Onyema', 'temitope.onyema372@example.com', '+2348009639273', '{"street": "32 Anthony Enahoro", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Electronics"]}'),
('Wale Onyia', 'wale.onyia215@example.com', '+2348021127114', '{"street": "103 Murtala Mohammed", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": false, "categories": ["Beauty"]}'),
('Ifeoma Akinwande', 'ifeoma.akinwande502@example.com', '+2348026869322', '{"street": "87 Anthony Enahoro", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden"]}'),
('Chioma Nwosu', 'chioma.nwosu244@example.com', '+2348082993273', '{"street": "25 Obafemi Awolowo", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": true, "categories": ["Books", "Home & Garden", "Fashion"]}'),
('Obinna Okorie', 'obinna.okorie645@example.com', '+2348054272525', '{"street": "150 Adetokunbo Ademola", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Toys", "Food"]}'),
('Segun Nwosu', 'segun.nwosu734@example.com', '+2348091959999', '{"street": "45 Nnamdi Azikiwe", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Books", "Sports", "Electronics"]}'),
('Patience Obi', 'patience.obi132@example.com', '+2348085416311', '{"street": "175 Marina Road", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Jide Adewale', 'jide.adewale896@example.com', '+2348019740943', '{"street": "79 Samuel Ladoke Akintola", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Fashion", "Sports"]}'),
('Deborah Ogbonna', 'deborah.ogbonna534@example.com', '+2348010595256', '{"street": "87 Awolowo Road", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": true, "categories": ["Books", "Home & Garden"]}'),
('Obinna Oladipo', 'obinna.oladipo941@example.com', '+2348058255721', '{"street": "148 Awolowo Road", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": false, "categories": ["Fashion"]}'),
('Emeka Okafor', 'emeka.okafor70@example.com', '+2348004787503', '{"street": "71 Yakubu Gowon", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Electronics", "Books"]}'),
('Eze Olu', 'eze.olu332@example.com', '+2348006716337', '{"street": "196 Yakubu Gowon", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Books"]}'),
('Temitope Aliyu', 'temitope.aliyu858@example.com', '+2348020323224', '{"street": "191 Murtala Mohammed", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Sports"]}'),
('Ifeoma Akintola', 'ifeoma.akintola966@example.com', '+2348068971502', '{"street": "108 Nnamdi Azikiwe", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Food", "Beauty"]}'),
('Emeka Onyema', 'emeka.onyema746@example.com', '+2348084165145', '{"street": "199 Olusegun Obasanjo", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Electronics"]}'),
('Obinna Oladipo', 'obinna.oladipo334@example.com', '+2348032438302', '{"street": "66 Emeka Anyaoku", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Books"]}'),
('Kemi Yusuf', 'kemi.yusuf237@example.com', '+2348048781259', '{"street": "174 Sultan Abubakar", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Food", "Fashion"]}'),
('Amina Okafor', 'amina.okafor680@example.com', '+2348092454665', '{"street": "4 Oduduwa", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": false, "categories": ["Fashion"]}'),
('Yusuf Onyia', 'yusuf.onyia860@example.com', '+2348099837235', '{"street": "110 Anthony Enahoro", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Beauty", "Electronics"]}'),
('Wale Akinwande', 'wale.akinwande780@example.com', '+2348056504991', '{"street": "75 Awolowo Road", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Books", "Electronics"]}'),
('Funke Akinwande', 'funke.akinwande256@example.com', '+2348040308890', '{"street": "185 Allen Avenue", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Beauty"]}'),
('Kemi Bakare', 'kemi.bakare949@example.com', '+2348031516522', '{"street": "185 Murtala Mohammed", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Books"]}'),
('Chukwu Chukwu', 'chukwu.chukwu937@example.com', '+2348058320387', '{"street": "90 Marina Road", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Toys", "Sports"]}'),
('Tunde Okonkwo', 'tunde.okonkwo2@example.com', '+2348047385387', '{"street": "117 Emeka Anyaoku", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Food", "Sports"]}'),
('Jide Salami', 'jide.salami369@example.com', '+2348027564342', '{"street": "113 Sultan Abubakar", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Fashion"]}'),
('Zara Oladipo', 'zara.oladipo434@example.com', '+2348043816139', '{"street": "151 Yakubu Gowon", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Fashion"]}'),
('Obinna Onyeama', 'obinna.onyeama274@example.com', '+2348048962032', '{"street": "117 Adetokunbo Ademola", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Books", "Home & Garden"]}'),
('Chinedu Afolayan', 'chinedu.afolayan387@example.com', '+2348034710396', '{"street": "73 Adetokunbo Ademola", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden", "Electronics", "Books"]}'),
('Temitope Chukwu', 'temitope.chukwu459@example.com', '+2348062692863', '{"street": "140 Oduduwa", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Books", "Food"]}'),
('Chukwu Okorie', 'chukwu.okorie505@example.com', '+2348045237871', '{"street": "175 Ibrahim Taiwo", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Okonkwo Oladipo', 'okonkwo.oladipo821@example.com', '+2348049793148', '{"street": "75 Anthony Enahoro", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Beauty", "Home & Garden"]}'),
('Kemi Akintola', 'kemi.akintola3@example.com', '+2348055814498', '{"street": "138 Adekunle Fajuyi", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Books", "Fashion", "Beauty"]}'),
('Patience Ogunleye', 'patience.ogunleye542@example.com', '+2348074657065', '{"street": "10 Adekunle Fajuyi", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": true, "categories": ["Sports"]}'),
('Ngozi Salami', 'ngozi.salami926@example.com', '+2348007180495', '{"street": "98 Samuel Ladoke Akintola", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Toys"]}'),
('Deborah Adebayo', 'deborah.adebayo984@example.com', '+2348080532754', '{"street": "107 Marina Road", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": false, "categories": ["Food", "Sports", "Beauty"]}'),
('Tunde Okoro', 'tunde.okoro12@example.com', '+2348077417532', '{"street": "163 Anthony Enahoro", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Toys", "Food"]}'),
('Kunle Mohammed', 'kunle.mohammed533@example.com', '+2348003307193', '{"street": "150 Oduduwa", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Toys", "Books"]}'),
('Wale Nwosu', 'wale.nwosu435@example.com', '+2348023059602', '{"street": "168 Nnamdi Azikiwe", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Sports", "Fashion"]}'),
('Chukwu Yusuf', 'chukwu.yusuf394@example.com', '+2348070034127', '{"street": "89 Herbert Macaulay", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden", "Fashion"]}'),
('Amina Aliyu', 'amina.aliyu239@example.com', '+2348048647281', '{"street": "35 Adetokunbo Ademola", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden"]}'),
('Funke Yusuf', 'funke.yusuf938@example.com', '+2348077166456', '{"street": "62 Herbert Macaulay", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden", "Toys", "Food"]}'),
('Ade Umar', 'ade.umar290@example.com', '+2348040344002', '{"street": "126 Oduduwa", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": false, "categories": ["Toys", "Food", "Home & Garden"]}'),
('Amina Okafor', 'amina.okafor277@example.com', '+2348090761117', '{"street": "132 Samuel Ladoke Akintola", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Books"]}'),
('Ade Okoh', 'ade.okoh286@example.com', '+2348091200439', '{"street": "3 Murtala Mohammed", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Sports"]}'),
('Ade Umar', 'ade.umar299@example.com', '+2348008709918', '{"street": "58 Adetokunbo Ademola", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Sports"]}'),
('Ngozi Bello', 'ngozi.bello338@example.com', '+2348061146332', '{"street": "143 Michael Okpara", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": false, "categories": ["Toys"]}'),
('Yusuf Umar', 'yusuf.umar550@example.com', '+2348054402503', '{"street": "194 Ahmadu Bello Way", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": false, "categories": ["Books", "Food", "Beauty"]}'),
('Patience Obi', 'patience.obi860@example.com', '+2348017042938', '{"street": "97 Herbert Macaulay", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden"]}'),
('Zara Okeke', 'zara.okeke371@example.com', '+2348089405761', '{"street": "121 Oduduwa", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Books", "Food"]}'),
('Chioma Ibrahim', 'chioma.ibrahim325@example.com', '+2348003480840', '{"street": "122 Yakubu Gowon", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Home & Garden"]}'),
('Adanna Salami', 'adanna.salami932@example.com', '+2348057147439', '{"street": "37 Oduduwa", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": true, "categories": ["Electronics"]}'),
('Jide Onyeama', 'jide.onyeama850@example.com', '+2348088095191', '{"street": "192 Emeka Anyaoku", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Beauty"]}'),
('Patience Bello', 'patience.bello41@example.com', '+2348069601360', '{"street": "103 Marina Road", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Books", "Home & Garden", "Toys"]}'),
('Okonkwo Balogun', 'okonkwo.balogun104@example.com', '+2348074949527', '{"street": "45 Anthony Enahoro", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Toys", "Electronics"]}'),
('Segun Okafor', 'segun.okafor55@example.com', '+2348001194799', '{"street": "122 Yakubu Gowon", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": true, "categories": ["Beauty"]}'),
('Zara Yusuf', 'zara.yusuf172@example.com', '+2348016423561', '{"street": "149 Olusegun Obasanjo", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Food"]}'),
('Chidinma Onyia', 'chidinma.onyia731@example.com', '+2348013112891', '{"street": "103 Ahmadu Bello Way", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Fashion", "Home & Garden"]}'),
('Olu Onyeka', 'olu.onyeka753@example.com', '+2348020879321', '{"street": "169 Olusegun Obasanjo", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": true, "categories": ["Electronics"]}'),
('Chidinma Adewale', 'chidinma.adewale423@example.com', '+2348004510354', '{"street": "164 Aminu Kano", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": false, "categories": ["Electronics"]}'),
('Zainab Bello', 'zainab.bello612@example.com', '+2348008463031', '{"street": "130 Herbert Macaulay", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": false, "categories": ["Food"]}'),
('Okonkwo Akinwande', 'okonkwo.akinwande524@example.com', '+2348094966623', '{"street": "77 Olusegun Obasanjo", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": true, "categories": ["Beauty"]}'),
('Olu Okoro', 'olu.okoro948@example.com', '+2348052576213', '{"street": "120 Obafemi Awolowo", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Toys", "Electronics"]}'),
('Wale Eze', 'wale.eze396@example.com', '+2348082678469', '{"street": "167 Awolowo Road", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Chioma Oladipo', 'chioma.oladipo546@example.com', '+2348094010702', '{"street": "112 Herbert Macaulay", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Electronics", "Beauty"]}'),
('Amina Oladipo', 'amina.oladipo809@example.com', '+2348025663879', '{"street": "20 Yakubu Gowon", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Beauty"]}'),
('Emeka Onyia', 'emeka.onyia534@example.com', '+2348055826584', '{"street": "164 Marina Road", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Books", "Toys"]}'),
('Obinna Umar', 'obinna.umar466@example.com', '+2348014100861', '{"street": "65 Anthony Enahoro", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Sports", "Electronics"]}'),
('Segun Umar', 'segun.umar287@example.com', '+2348024202299', '{"street": "7 Marina Road", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": false, "categories": ["Books", "Home & Garden"]}'),
('Musa Eze', 'musa.eze377@example.com', '+2348004194480', '{"street": "153 Michael Okpara", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Sports", "Food"]}'),
('Musa Adeleke', 'musa.adeleke520@example.com', '+2348078158810', '{"street": "141 Aminu Kano", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": true, "categories": ["Toys"]}'),
('Temitope Adebayo', 'temitope.adebayo256@example.com', '+2348089056248', '{"street": "160 Adekunle Fajuyi", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": true, "categories": ["Beauty", "Sports"]}'),
('Zara Umar', 'zara.umar412@example.com', '+2348016966198', '{"street": "180 Yakubu Gowon", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": true, "categories": ["Books", "Home & Garden", "Food"]}'),
('Emeka Nwosu', 'emeka.nwosu756@example.com', '+2348090679298', '{"street": "164 Herbert Macaulay", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Home & Garden"]}'),
('Femi Ogunleye', 'femi.ogunleye334@example.com', '+2348078359974', '{"street": "170 Awolowo Road", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Fashion", "Food"]}'),
('Sani Chukwu', 'sani.chukwu456@example.com', '+2348074359482', '{"street": "73 Yakubu Gowon", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": true, "categories": ["Food", "Books", "Toys"]}'),
('Olu Eze', 'olu.eze400@example.com', '+2348054688639', '{"street": "97 Ibrahim Taiwo", "city": "Kano", "zip": "700001"}', '{"marketing_opt_in": false, "categories": ["Sports"]}'),
('Fatima Okoh', 'fatima.okoh838@example.com', '+2348068613820', '{"street": "94 Murtala Mohammed", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": true, "categories": ["Beauty", "Fashion"]}'),
('Ade Okafor', 'ade.okafor949@example.com', '+2348022822416', '{"street": "24 Awolowo Road", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Beauty", "Electronics"]}'),
('Ngozi Akinwande', 'ngozi.akinwande292@example.com', '+2348090235937', '{"street": "88 Adetokunbo Ademola", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Electronics", "Books"]}'),
('Ngozi Bello', 'ngozi.bello636@example.com', '+2348084778834', '{"street": "162 Herbert Macaulay", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Food"]}'),
('Segun Alade', 'segun.alade646@example.com', '+2348088354687', '{"street": "115 Murtala Mohammed", "city": "Kaduna", "zip": "800001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Femi Ojo', 'femi.ojo182@example.com', '+2348009008968', '{"street": "31 Allen Avenue", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Food", "Books", "Beauty"]}'),
('Eze Ibrahim', 'eze.ibrahim23@example.com', '+2348033475723', '{"street": "70 Obafemi Awolowo", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Toys"]}'),
('Chioma Okafor', 'chioma.okafor322@example.com', '+2348034237848', '{"street": "15 Ibrahim Taiwo", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Ngozi Okorie', 'ngozi.okorie973@example.com', '+2348021031542', '{"street": "186 Olusegun Obasanjo", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": true, "categories": ["Beauty", "Fashion", "Food"]}'),
('Obinna Obi', 'obinna.obi245@example.com', '+2348046362032', '{"street": "141 Emeka Anyaoku", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Home & Garden"]}'),
('Amina Ibrahim', 'amina.ibrahim786@example.com', '+2348089761369', '{"street": "134 Marina Road", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Toys", "Books"]}'),
('Mohammed Alade', 'mohammed.alade790@example.com', '+2348017497690', '{"street": "118 Murtala Mohammed", "city": "Zaria", "zip": "810001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Toys"]}'),
('Eze Adewale', 'eze.adewale311@example.com', '+2348026387557', '{"street": "178 Obafemi Awolowo", "city": "Abeokuta", "zip": "110001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Beauty"]}'),
('Adanna Onyia', 'adanna.onyia366@example.com', '+2348033148114', '{"street": "87 Adekunle Fajuyi", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Books", "Beauty"]}'),
('Wale Adeleke', 'wale.adeleke180@example.com', '+2348005656768', '{"street": "140 Ibrahim Taiwo", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": true, "categories": ["Beauty", "Toys"]}'),
('Eze Adewale', 'eze.adewale158@example.com', '+2348057883091', '{"street": "52 Herbert Macaulay", "city": "Benin City", "zip": "300001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Books"]}'),
('Funke Oladipo', 'funke.oladipo987@example.com', '+2348083576067', '{"street": "143 Ibrahim Taiwo", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Books", "Home & Garden"]}'),
('Obinna Sule', 'obinna.sule203@example.com', '+2348054102706', '{"street": "194 Yakubu Gowon", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Food"]}'),
('Femi Adeyemi', 'femi.adeyemi618@example.com', '+2348032978503', '{"street": "170 Sultan Abubakar", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Home & Garden", "Books", "Toys"]}'),
('Olu Okafor', 'olu.okafor468@example.com', '+2348006073592', '{"street": "17 Aminu Kano", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Sports", "Electronics"]}'),
('Mohammed Akinwande', 'mohammed.akinwande744@example.com', '+2348024020038', '{"street": "181 Samuel Ladoke Akintola", "city": "Aba", "zip": "450001"}', '{"marketing_opt_in": false, "categories": ["Beauty", "Fashion", "Books"]}'),
('Jide Ibrahim', 'jide.ibrahim287@example.com', '+2348085951987', '{"street": "43 Ahmadu Bello Way", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": false, "categories": ["Fashion"]}'),
('Eze Ibrahim', 'eze.ibrahim653@example.com', '+2348040316486', '{"street": "17 Oduduwa", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Home & Garden", "Beauty"]}'),
('Ibrahim Chukwu', 'ibrahim.chukwu674@example.com', '+2348098255727', '{"street": "49 Yakubu Gowon", "city": "Enugu", "zip": "400001"}', '{"marketing_opt_in": true, "categories": ["Books", "Food", "Electronics"]}'),
('Ifeoma Sule', 'ifeoma.sule200@example.com', '+2348068255032', '{"street": "62 Marina Road", "city": "Onitsha", "zip": "430001"}', '{"marketing_opt_in": true, "categories": ["Food"]}'),
('Wale Nwosu', 'wale.nwosu822@example.com', '+2348077385106', '{"street": "1 Murtala Mohammed", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Toys", "Food", "Books"]}'),
('Patience Okafor', 'patience.okafor273@example.com', '+2348094261746', '{"street": "42 Adekunle Fajuyi", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Food", "Beauty"]}'),
('Adanna Okeke', 'adanna.okeke150@example.com', '+2348067568300', '{"street": "116 Ibrahim Taiwo", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": true, "categories": ["Books"]}'),
('Halima Adeyemi', 'halima.adeyemi207@example.com', '+2348012904553', '{"street": "142 Adekunle Fajuyi", "city": "Warri", "zip": "330001"}', '{"marketing_opt_in": false, "categories": ["Books"]}'),
('Emeka Akintola', 'emeka.akintola578@example.com', '+2348088095884', '{"street": "127 Sultan Abubakar", "city": "Calabar", "zip": "540001"}', '{"marketing_opt_in": false, "categories": ["Toys", "Beauty"]}'),
('Chika Sule', 'chika.sule638@example.com', '+2348025105015', '{"street": "17 Yakubu Gowon", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Books", "Home & Garden"]}'),
('Grace Aliyu', 'grace.aliyu174@example.com', '+2348099964231', '{"street": "110 Adetokunbo Ademola", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": false, "categories": ["Sports"]}'),
('Ibrahim Bello', 'ibrahim.bello344@example.com', '+2348027263139', '{"street": "1 Sultan Abubakar", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Food", "Beauty"]}'),
('Amina Akintola', 'amina.akintola108@example.com', '+2348040681379', '{"street": "81 Aminu Kano", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Home & Garden", "Fashion"]}'),
('Wale Olu', 'wale.olu479@example.com', '+2348066661026', '{"street": "176 Anthony Enahoro", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": false, "categories": ["Food", "Beauty"]}'),
('Olu Okoro', 'olu.okoro656@example.com', '+2348050405477', '{"street": "166 Nnamdi Azikiwe", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Beauty", "Toys"]}'),
('Ifeoma Okeke', 'ifeoma.okeke524@example.com', '+2348098116809', '{"street": "117 Emeka Anyaoku", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Sports"]}'),
('Amina Alade', 'amina.alade800@example.com', '+2348040497866', '{"street": "189 Marina Road", "city": "Ibadan", "zip": "200001"}', '{"marketing_opt_in": true, "categories": ["Books", "Beauty", "Home & Garden"]}'),
('Abdul Adewale', 'abdul.adewale174@example.com', '+2348034592341', '{"street": "67 Adekunle Fajuyi", "city": "Abuja", "zip": "900001"}', '{"marketing_opt_in": false, "categories": ["Electronics", "Sports"]}'),
('Jide Ojo', 'jide.ojo360@example.com', '+2348033939981', '{"street": "29 Adekunle Fajuyi", "city": "Maiduguri", "zip": "600001"}', '{"marketing_opt_in": true, "categories": ["Sports", "Fashion"]}'),
('Amina Salami', 'amina.salami257@example.com', '+2348074296770', '{"street": "104 Ibrahim Taiwo", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Electronics", "Sports"]}'),
('Abdul Akintola', 'abdul.akintola331@example.com', '+2348093240099', '{"street": "50 Awolowo Road", "city": "Port Harcourt", "zip": "500001"}', '{"marketing_opt_in": false, "categories": ["Fashion", "Books", "Toys"]}'),
('Ibrahim Oladipo', 'ibrahim.oladipo592@example.com', '+2348017621578', '{"street": "3 Ahmadu Bello Way", "city": "Lagos", "zip": "100001"}', '{"marketing_opt_in": true, "categories": ["Fashion", "Books"]}');

);


INSERT INTO orders (customer_id, order_date, total_amount, status, shipping_address, metadata)
VALUES
(10, '2025-03-07', 2613.7, 'Processing', '{"street": "13 Murtala Mohammed", "city": "Kano", "zip": "700001"}', '{"source": "desktop", "coupon": "SUMMER20", "notes": "Don''t ring doorbell"}'),
(161, '2025-02-06', 8406.91, 'Delivered', '{"street": "34 Allen Avenue", "city": "Maiduguri", "zip": "600001"}', '{"source": "tablet", "coupon": "SUMMER20", "notes": "Leave at front desk"}'),
(18, '2025-03-05', 69150.67, 'Shipped', '{"street": "197 Marina Road", "city": "Kano", "zip": "700001"}', '{"source": "tablet", "coupon": "FREESHIP"}'),
(48, '2025-03-20', 3753.76, 'Delivered', '{"street": "74 Michael Okpara", "city": "Aba", "zip": "450001"}', '{"source": "desktop", "coupon": "SAVE15"}'),
(189, '2025-06-26', 92489.38, 'Delivered', '{"street": "49 Ahmadu Bello Way", "city": "Abuja", "zip": "900001"}', '{"source": "mobile"}'),
(141, '2025-06-08', 4364.72, 'Shipped', '{"street": "68 Ibrahim Taiwo", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(166, '2025-01-25', 2169.2, 'Pending', '{"street": "110 Ibrahim Taiwo", "city": "Maiduguri", "zip": "600001"}', '{"source": "tablet", "coupon": "FREESHIP"}'),
(16, '2025-04-19', 1735.17, 'Processing', '{"street": "166 Adetokunbo Ademola", "city": "Zaria", "zip": "810001"}', '{"source": "mobile"}'),
(186, '2025-02-03', 34245.94, 'Shipped', '{"street": "96 Ahmadu Bello Way", "city": "Abuja", "zip": "900001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(10, '2025-06-11', 1932.28, 'Shipped', '{"street": "29 Aminu Kano", "city": "Zaria", "zip": "810001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(66, '2025-03-24', 48644.78, 'Shipped', '{"street": "65 Adetokunbo Ademola", "city": "Kano", "zip": "700001"}', '{"source": "tablet"}'),
(46, '2025-02-24', 3425.22, 'Cancelled', '{"street": "162 Awolowo Road", "city": "Zaria", "zip": "810001"}', '{"source": "desktop"}'),
(111, '2025-05-31', 5981.81, 'Processing', '{"street": "97 Yakubu Gowon", "city": "Kaduna", "zip": "800001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "FREESHIP"}'),
(189, '2025-06-17', 89071.28, 'Delivered', '{"street": "3 Nnamdi Azikiwe", "city": "Port Harcourt", "zip": "500001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(166, '2025-03-27', 26235.56, 'Processing', '{"street": "108 Sultan Abubakar", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "NEWUSER25", "notes": "Signature required"}'),
(25, '2025-06-02', 13876.61, 'Pending', '{"street": "36 Oduduwa", "city": "Abuja", "zip": "900001"}', '{"source": "tablet", "coupon": "SUMMER20"}'),
(70, '2025-01-05', 14903.88, 'Delivered', '{"street": "192 Samuel Ladoke Akintola", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "notes": "Handle with care"}'),
(41, '2025-03-07', 30454.56, 'Shipped', '{"street": "199 Emeka Anyaoku", "city": "Kano", "zip": "700001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(127, '2025-03-17', 5982.75, 'Shipped', '{"street": "123 Ibrahim Taiwo", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(17, '2025-01-29', 3970.71, 'Processing', '{"street": "80 Adetokunbo Ademola", "city": "Abuja", "zip": "900001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(121, '2025-06-05', 5560.69, 'Pending', '{"street": "191 Adekunle Fajuyi", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "FREESHIP"}'),
(71, '2025-04-21', 22700.85, 'Pending', '{"street": "13 Emeka Anyaoku", "city": "Lagos", "zip": "100001"}', '{"source": "mobile", "coupon": "WELCOME10"}'),
(124, '2025-03-04', 43730.35, 'Processing', '{"street": "5 Samuel Ladoke Akintola", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(76, '2025-01-26', 5099.29, 'Shipped', '{"street": "32 Nnamdi Azikiwe", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(115, '2025-01-06', 17954.31, 'Shipped', '{"street": "79 Oduduwa", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "NEWUSER25"}'),
(78, '2025-06-23', 3954.26, 'Processing', '{"street": "142 Olusegun Obasanjo", "city": "Abuja", "zip": "900001"}', '{"source": "tablet"}'),
(11, '2025-06-24', 2969.25, 'Shipped', '{"street": "85 Michael Okpara", "city": "Ibadan", "zip": "200001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "SUMMER20"}'),
(155, '2025-06-24', 40828.97, 'Shipped', '{"street": "98 Marina Road", "city": "Aba", "zip": "450001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(183, '2025-05-31', 41242.71, 'Delivered', '{"street": "120 Aminu Kano", "city": "Lagos", "zip": "100001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "WELCOME10"}'),
(133, '2025-06-10', 1880.11, 'Shipped', '{"street": "60 Michael Okpara", "city": "Aba", "zip": "450001"}', '{"source": "desktop"}'),
(54, '2025-04-16', 7560.47, 'Shipped', '{"street": "50 Oduduwa", "city": "Abuja", "zip": "900001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "SAVE15"}'),
(83, '2025-04-17', 6964.48, 'Shipped', '{"street": "108 Ibrahim Taiwo", "city": "Lagos", "zip": "100001"}', '{"source": "mobile", "coupon": "NEWUSER25"}'),
(147, '2025-06-11', 38668.44, 'Pending', '{"street": "74 Sultan Abubakar", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(8, '2025-05-26', 2126.74, 'Cancelled', '{"street": "150 Obafemi Awolowo", "city": "Abuja", "zip": "900001"}', '{"source": "tablet", "coupon": "SUMMER20"}'),
(48, '2025-01-01', 9545.13, 'Processing', '{"street": "153 Herbert Macaulay", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "SUMMER20"}'),
(11, '2025-04-25', 31667.89, 'Processing', '{"street": "148 Oduduwa", "city": "Zaria", "zip": "810001"}', '{"source": "mobile", "coupon": "WINTER30"}'),
(197, '2025-01-14', 42193.61, 'Shipped', '{"street": "89 Sultan Abubakar", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(76, '2025-01-30', 13569.3, 'Shipped', '{"street": "53 Sultan Abubakar", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "coupon": "WELCOME10"}'),
(177, '2025-04-21', 3145.31, 'Shipped', '{"street": "131 Murtala Mohammed", "city": "Port Harcourt", "zip": "500001"}', '{"source": "mobile", "coupon": "SAVE15"}'),
(190, '2025-05-04', 12300.48, 'Delivered', '{"street": "96 Marina Road", "city": "Aba", "zip": "450001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "NEWUSER25"}'),
(5, '2025-06-25', 43096.48, 'Delivered', '{"street": "66 Obafemi Awolowo", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(121, '2025-01-19', 1387.34, 'Shipped', '{"street": "90 Adekunle Fajuyi", "city": "Ibadan", "zip": "200001"}', '{"source": "tablet", "coupon": "FREESHIP"}'),
(138, '2025-02-24', 53316.89, 'Shipped', '{"street": "197 Anthony Enahoro", "city": "Lagos", "zip": "100001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(113, '2025-02-23', 9066.94, 'Processing', '{"street": "79 Aminu Kano", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile"}'),
(71, '2025-01-10', 27508.97, 'Processing', '{"street": "141 Herbert Macaulay", "city": "Kano", "zip": "700001"}', '{"source": "tablet", "coupon": "WINTER30"}'),
(39, '2025-02-02', 16585.5, 'Delivered', '{"street": "187 Allen Avenue", "city": "Kano", "zip": "700001"}', '{"source": "tablet"}'),
(84, '2025-02-21', 95365.11, 'Processing', '{"street": "76 Nnamdi Azikiwe", "city": "Zaria", "zip": "810001"}', '{"source": "tablet"}'),
(185, '2025-05-15', 215366.88, 'Pending', '{"street": "31 Herbert Macaulay", "city": "Maiduguri", "zip": "600001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "SAVE15"}'),
(101, '2025-04-25', 43651.71, 'Shipped', '{"street": "59 Sultan Abubakar", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(15, '2025-02-19', 4098.65, 'Shipped', '{"street": "60 Yakubu Gowon", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "WINTER30"}'),
(177, '2025-07-05', 14907.35, 'Pending', '{"street": "157 Yakubu Gowon", "city": "Ibadan", "zip": "200001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "WELCOME10"}'),
(16, '2025-07-03', 12564.4, 'Pending', '{"street": "107 Marina Road", "city": "Zaria", "zip": "810001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(83, '2025-01-06', 14937.99, 'Shipped', '{"street": "32 Anthony Enahoro", "city": "Abuja", "zip": "900001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(138, '2025-01-13', 20166.41, 'Processing', '{"street": "192 Obafemi Awolowo", "city": "Aba", "zip": "450001"}', '{"source": "tablet"}'),
(7, '2025-05-23', 68480.09, 'Pending', '{"street": "66 Aminu Kano", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "WINTER30"}'),
(193, '2025-04-03', 7955.21, 'Processing', '{"street": "169 Anthony Enahoro", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "gift_wrap": true, "coupon": "FREESHIP"}'),
(114, '2025-03-18', 75905.25, 'Delivered', '{"street": "20 Ahmadu Bello Way", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(4, '2025-06-28', 1963.02, 'Processing', '{"street": "146 Ibrahim Taiwo", "city": "Zaria", "zip": "810001"}', '{"source": "mobile", "coupon": "NEWUSER25"}'),
(133, '2025-04-04', 7098.91, 'Pending', '{"street": "24 Anthony Enahoro", "city": "Kano", "zip": "700001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(106, '2025-02-08', 232337.57, 'Processing', '{"street": "139 Allen Avenue", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(69, '2025-01-11', 5927.8, 'Pending', '{"street": "192 Marina Road", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "coupon": "FREESHIP"}'),
(105, '2025-06-10', 187887.68, 'Processing', '{"street": "108 Aminu Kano", "city": "Kano", "zip": "700001"}', '{"source": "mobile"}'),
(184, '2025-05-21', 8889.39, 'Delivered', '{"street": "20 Samuel Ladoke Akintola", "city": "Lagos", "zip": "100001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(29, '2025-06-12', 55434.04, 'Shipped', '{"street": "29 Nnamdi Azikiwe", "city": "Port Harcourt", "zip": "500001"}', '{"source": "desktop", "gift_wrap": true, "coupon": "SAVE15"}'),
(48, '2025-03-21', 76606.15, 'Delivered', '{"street": "12 Allen Avenue", "city": "Abuja", "zip": "900001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "FREESHIP"}'),
(54, '2025-01-22', 2753.05, 'Processing', '{"street": "136 Samuel Ladoke Akintola", "city": "Port Harcourt", "zip": "500001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(110, '2025-05-26', 7513.92, 'Shipped', '{"street": "93 Awolowo Road", "city": "Zaria", "zip": "810001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(114, '2025-04-04', 163371.31, 'Shipped', '{"street": "173 Marina Road", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "coupon": "FREESHIP"}'),
(129, '2025-04-29', 12161.86, 'Processing', '{"street": "66 Awolowo Road", "city": "Lagos", "zip": "100001"}', '{"source": "tablet", "coupon": "NEWUSER25"}'),
(86, '2025-01-30', 7175.99, 'Shipped', '{"street": "29 Sultan Abubakar", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "WELCOME10"}'),
(105, '2025-03-11', 34977.77, 'Processing', '{"street": "114 Obafemi Awolowo", "city": "Kaduna", "zip": "800001"}', '{"source": "tablet", "coupon": "SUMMER20"}'),
(156, '2025-01-30', 1246.41, 'Delivered', '{"street": "65 Ahmadu Bello Way", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(181, '2025-04-16', 237187.45, 'Shipped', '{"street": "17 Emeka Anyaoku", "city": "Maiduguri", "zip": "600001"}', '{"source": "desktop", "coupon": "WELCOME10", "notes": "Call before delivery"}'),
(12, '2025-01-07', 4948.51, 'Pending', '{"street": "2 Olusegun Obasanjo", "city": "Port Harcourt", "zip": "500001"}', '{"source": "mobile"}'),
(169, '2025-01-15', 6589.63, 'Shipped', '{"street": "193 Awolowo Road", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(82, '2025-01-29', 26003.06, 'Shipped', '{"street": "188 Marina Road", "city": "Aba", "zip": "450001"}', '{"source": "tablet", "coupon": "NEWUSER25"}'),
(121, '2025-03-06', 43095.32, 'Delivered', '{"street": "83 Ibrahim Taiwo", "city": "Maiduguri", "zip": "600001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(162, '2025-03-12', 39537.27, 'Shipped', '{"street": "12 Yakubu Gowon", "city": "Abuja", "zip": "900001"}', '{"source": "tablet", "coupon": "FREESHIP"}'),
(65, '2025-01-11', 18980.95, 'Pending', '{"street": "21 Emeka Anyaoku", "city": "Port Harcourt", "zip": "500001"}', '{"source": "tablet", "coupon": "FREESHIP"}'),
(61, '2025-02-22', 24697.12, 'Shipped', '{"street": "59 Ahmadu Bello Way", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(1, '2025-04-23', 88971.95, 'Delivered', '{"street": "183 Adetokunbo Ademola", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "coupon": "WELCOME10"}'),
(1, '2025-06-19', 87312.07, 'Shipped', '{"street": "7 Ahmadu Bello Way", "city": "Maiduguri", "zip": "600001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(19, '2025-05-31', 28250.57, 'Delivered', '{"street": "99 Samuel Ladoke Akintola", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "coupon": "NEWUSER25"}'),
(171, '2025-05-14', 9158.58, 'Pending', '{"street": "19 Sultan Abubakar", "city": "Port Harcourt", "zip": "500001"}', '{"source": "tablet", "coupon": "SUMMER20"}'),
(28, '2025-01-19', 74211.31, 'Delivered', '{"street": "119 Olusegun Obasanjo", "city": "Maiduguri", "zip": "600001"}', '{"source": "tablet", "coupon": "WELCOME10", "notes": "Fragile package"}'),
(200, '2025-01-09', 88394.13, 'Delivered', '{"street": "82 Marina Road", "city": "Aba", "zip": "450001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(174, '2025-04-08', 4454.07, 'Shipped', '{"street": "5 Murtala Mohammed", "city": "Port Harcourt", "zip": "500001"}', '{"source": "desktop", "gift_wrap": true, "coupon": "SAVE15"}'),
(42, '2025-04-11', 9598.78, 'Delivered', '{"street": "109 Adekunle Fajuyi", "city": "Abuja", "zip": "900001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(47, '2025-04-08', 3733.54, 'Pending', '{"street": "32 Samuel Ladoke Akintola", "city": "Aba", "zip": "450001"}', '{"source": "mobile", "coupon": "WELCOME10"}'),
(172, '2025-03-28', 154109.71, 'Shipped', '{"street": "72 Marina Road", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(118, '2025-06-27', 4741.41, 'Pending', '{"street": "143 Marina Road", "city": "Maiduguri", "zip": "600001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(83, '2025-03-21', 7857.03, 'Processing', '{"street": "142 Olusegun Obasanjo", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "notes": "Gift for anniversary"}'),
(55, '2025-05-06', 42008.04, 'Shipped', '{"street": "87 Marina Road", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "WELCOME10", "notes": "Leave at front desk"}'),
(122, '2025-01-12', 3447.93, 'Delivered', '{"street": "156 Allen Avenue", "city": "Port Harcourt", "zip": "500001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(14, '2025-05-15', 81803.18, 'Shipped', '{"street": "19 Aminu Kano", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "coupon": "SAVE15"}'),
(49, '2025-05-06', 108450.88, 'Processing', '{"street": "8 Adetokunbo Ademola", "city": "Ibadan", "zip": "200001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(31, '2025-02-25', 4226.68, 'Shipped', '{"street": "56 Sultan Abubakar", "city": "Kaduna", "zip": "800001"}', '{"source": "tablet", "coupon": "FREESHIP"}'),
(44, '2025-04-25', 4390.74, 'Processing', '{"street": "42 Nnamdi Azikiwe", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "coupon": "WELCOME10", "notes": "Leave at front desk"}'),
(36, '2025-05-25', 94415.68, 'Shipped', '{"street": "139 Awolowo Road", "city": "Ibadan", "zip": "200001"}', '{"source": "mobile", "coupon": "WINTER30"}'),
(165, '2025-02-26', 4850.4, 'Shipped', '{"street": "111 Olusegun Obasanjo", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(106, '2025-06-15', 6081.6, 'Delivered', '{"street": "58 Ibrahim Taiwo", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(11, '2025-06-25', 2037.38, 'Processing', '{"street": "22 Sultan Abubakar", "city": "Aba", "zip": "450001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "WELCOME10"}'),
(86, '2025-03-22', 3871.93, 'Shipped', '{"street": "185 Nnamdi Azikiwe", "city": "Abuja", "zip": "900001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(81, '2025-01-25', 9385.17, 'Shipped', '{"street": "102 Oduduwa", "city": "Maiduguri", "zip": "600001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(168, '2025-03-06', 7518.69, 'Processing', '{"street": "190 Ibrahim Taiwo", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "coupon": "FREESHIP"}'),
(167, '2025-01-30', 5764.34, 'Delivered', '{"street": "103 Samuel Ladoke Akintola", "city": "Port Harcourt", "zip": "500001"}', '{"source": "mobile", "coupon": "WELCOME10"}'),
(46, '2025-03-12', 2587.77, 'Pending', '{"street": "33 Adekunle Fajuyi", "city": "Kano", "zip": "700001"}', '{"source": "desktop", "coupon": "SAVE15"}'),
(23, '2025-04-16', 4124.46, 'Pending', '{"street": "95 Sultan Abubakar", "city": "Kano", "zip": "700001"}', '{"source": "desktop"}'),
(50, '2025-03-22', 5625.71, 'Shipped', '{"street": "73 Oduduwa", "city": "Aba", "zip": "450001"}', '{"source": "tablet"}'),
(19, '2025-02-15', 25205.38, 'Processing', '{"street": "198 Murtala Mohammed", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(10, '2025-03-09', 5276.29, 'Pending', '{"street": "138 Yakubu Gowon", "city": "Ibadan", "zip": "200001"}', '{"source": "tablet", "coupon": "WINTER30", "notes": "Don''t ring doorbell"}'),
(37, '2025-01-08', 240315.39, 'Processing', '{"street": "126 Aminu Kano", "city": "Zaria", "zip": "810001"}', '{"source": "mobile"}'),
(162, '2025-02-27', 73918.27, 'Pending', '{"street": "61 Awolowo Road", "city": "Port Harcourt", "zip": "500001"}', '{"source": "tablet", "coupon": "NEWUSER25"}'),
(137, '2025-03-24', 42882.32, 'Shipped', '{"street": "185 Marina Road", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "WINTER30"}'),
(180, '2025-05-22', 19181.25, 'Pending', '{"street": "81 Samuel Ladoke Akintola", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "NEWUSER25"}'),
(39, '2025-04-01', 13905.19, 'Delivered', '{"street": "173 Yakubu Gowon", "city": "Lagos", "zip": "100001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(154, '2025-04-01', 99384.75, 'Pending', '{"street": "179 Adetokunbo Ademola", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "coupon": "SAVE15"}'),
(100, '2025-01-31', 39153.84, 'Processing', '{"street": "85 Nnamdi Azikiwe", "city": "Ibadan", "zip": "200001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "WELCOME10"}'),
(6, '2025-01-11', 8723.74, 'Processing', '{"street": "32 Oduduwa", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop"}'),
(28, '2025-03-25', 154370.11, 'Shipped', '{"street": "8 Anthony Enahoro", "city": "Maiduguri", "zip": "600001"}', '{"source": "mobile", "coupon": "WELCOME10"}'),
(113, '2025-01-30', 5732.05, 'Shipped', '{"street": "121 Marina Road", "city": "Ibadan", "zip": "200001"}', '{"source": "tablet", "coupon": "NEWUSER25"}'),
(174, '2025-01-03', 4350.68, 'Cancelled', '{"street": "147 Michael Okpara", "city": "Aba", "zip": "450001"}', '{"source": "desktop", "coupon": "SAVE15"}'),
(137, '2025-03-31', 90950.24, 'Shipped', '{"street": "72 Marina Road", "city": "Lagos", "zip": "100001"}', '{"source": "tablet", "coupon": "WINTER30"}'),
(150, '2025-01-18', 2331.17, 'Shipped', '{"street": "62 Ahmadu Bello Way", "city": "Port Harcourt", "zip": "500001"}', '{"source": "mobile", "coupon": "WELCOME10"}'),
(121, '2025-05-31', 28735.78, 'Processing', '{"street": "3 Adekunle Fajuyi", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(146, '2025-05-24', 23026.4, 'Processing', '{"street": "118 Ibrahim Taiwo", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(123, '2025-03-23', 90794.84, 'Shipped', '{"street": "168 Ahmadu Bello Way", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(161, '2025-01-18', 36654.12, 'Shipped', '{"street": "185 Allen Avenue", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "gift_wrap": true, "notes": "Signature required"}'),
(9, '2025-04-15', 24949.4, 'Shipped', '{"street": "130 Allen Avenue", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "coupon": "WELCOME10", "notes": "Gift for anniversary"}'),
(191, '2025-07-02', 20222.59, 'Delivered', '{"street": "64 Yakubu Gowon", "city": "Port Harcourt", "zip": "500001"}', '{"source": "desktop", "coupon": "WELCOME10"}'),
(72, '2025-01-24', 5761.1, 'Shipped', '{"street": "137 Ibrahim Taiwo", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "NEWUSER25"}'),
(114, '2025-02-17', 5479.43, 'Shipped', '{"street": "12 Yakubu Gowon", "city": "Kaduna", "zip": "800001"}', '{"source": "tablet"}'),
(125, '2025-03-16', 2843.12, 'Shipped', '{"street": "164 Herbert Macaulay", "city": "Port Harcourt", "zip": "500001"}', '{"source": "tablet", "coupon": "NEWUSER25"}'),
(128, '2025-01-29', 9037.11, 'Shipped', '{"street": "133 Oduduwa", "city": "Zaria", "zip": "810001"}', '{"source": "tablet", "coupon": "WINTER30"}'),
(121, '2025-01-10', 8796.33, 'Shipped', '{"street": "102 Murtala Mohammed", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop"}'),
(16, '2025-02-11', 37231.66, 'Pending', '{"street": "83 Murtala Mohammed", "city": "Aba", "zip": "450001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "NEWUSER25"}'),
(186, '2025-02-21', 5605.51, 'Processing', '{"street": "174 Yakubu Gowon", "city": "Maiduguri", "zip": "600001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(101, '2025-01-21', 1911.41, 'Cancelled', '{"street": "148 Adetokunbo Ademola", "city": "Maiduguri", "zip": "600001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "NEWUSER25"}'),
(145, '2025-04-01', 20859.42, 'Shipped', '{"street": "110 Aminu Kano", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "NEWUSER25"}'),
(120, '2025-02-02', 9453.08, 'Pending', '{"street": "178 Herbert Macaulay", "city": "Aba", "zip": "450001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "FREESHIP"}'),
(65, '2025-06-14', 6874.56, 'Pending', '{"street": "118 Samuel Ladoke Akintola", "city": "Abuja", "zip": "900001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "NEWUSER25", "notes": "Leave at front desk"}'),
(118, '2025-04-06', 3880.26, 'Shipped', '{"street": "168 Oduduwa", "city": "Kano", "zip": "700001"}', '{"source": "mobile"}'),
(6, '2025-01-02', 3000.92, 'Pending', '{"street": "39 Sultan Abubakar", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop"}'),
(151, '2025-01-16', 6421.38, 'Shipped', '{"street": "197 Adetokunbo Ademola", "city": "Ibadan", "zip": "200001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(170, '2025-06-16', 1494.96, 'Processing', '{"street": "42 Anthony Enahoro", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "coupon": "FREESHIP"}'),
(36, '2025-03-18', 21118.36, 'Shipped', '{"street": "13 Ibrahim Taiwo", "city": "Benin City", "zip": "300001"}', '{"source": "desktop", "coupon": "WINTER30"}'),
(184, '2025-06-17', 11189.1, 'Processing', '{"street": "64 Awolowo Road", "city": "Kano", "zip": "700001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "WELCOME10"}'),
(118, '2025-02-13', 24787.13, 'Delivered', '{"street": "194 Herbert Macaulay", "city": "Benin City", "zip": "300001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(179, '2025-05-23', 17396.66, 'Shipped', '{"street": "164 Nnamdi Azikiwe", "city": "Zaria", "zip": "810001"}', '{"source": "desktop"}'),
(144, '2025-03-24', 247573.73, 'Delivered', '{"street": "36 Adekunle Fajuyi", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "coupon": "NEWUSER25", "notes": "Signature required"}'),
(146, '2025-03-17', 6034.59, 'Processing', '{"street": "168 Awolowo Road", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(149, '2025-04-06', 38799.23, 'Processing', '{"street": "182 Samuel Ladoke Akintola", "city": "Kaduna", "zip": "800001"}', '{"source": "tablet", "coupon": "FREESHIP"}'),
(106, '2025-06-26', 2217.5, 'Processing', '{"street": "57 Sultan Abubakar", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "coupon": "SAVE15"}'),
(147, '2025-06-06', 1363.01, 'Pending', '{"street": "24 Murtala Mohammed", "city": "Aba", "zip": "450001"}', '{"source": "desktop"}'),
(190, '2025-03-26', 15477.84, 'Delivered', '{"street": "32 Olusegun Obasanjo", "city": "Zaria", "zip": "810001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(195, '2025-02-20', 7686.4, 'Delivered', '{"street": "135 Adekunle Fajuyi", "city": "Lagos", "zip": "100001"}', '{"source": "desktop", "coupon": "SAVE15", "notes": "Fragile package"}'),
(93, '2025-01-05', 9194.91, 'Processing', '{"street": "141 Samuel Ladoke Akintola", "city": "Port Harcourt", "zip": "500001"}', '{"source": "desktop", "gift_wrap": true, "coupon": "FREESHIP", "notes": "Call before delivery"}'),
(165, '2025-02-03', 1902.07, 'Pending', '{"street": "79 Herbert Macaulay", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "gift_wrap": true}'),
(198, '2025-05-10', 29890.78, 'Pending', '{"street": "73 Obafemi Awolowo", "city": "Zaria", "zip": "810001"}', '{"source": "tablet", "coupon": "SUMMER20"}'),
(121, '2025-01-27', 9836.08, 'Shipped', '{"street": "5 Awolowo Road", "city": "Benin City", "zip": "300001"}', '{"source": "tablet", "coupon": "WINTER30"}'),
(35, '2025-06-23', 8282.4, 'Processing', '{"street": "113 Allen Avenue", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(199, '2025-06-26', 61990.33, 'Shipped', '{"street": "152 Olusegun Obasanjo", "city": "Ibadan", "zip": "200001"}', '{"source": "tablet", "coupon": "WINTER30"}'),
(14, '2025-06-28', 8722.8, 'Shipped', '{"street": "167 Emeka Anyaoku", "city": "Ibadan", "zip": "200001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(90, '2025-03-02', 1097.12, 'Shipped', '{"street": "53 Oduduwa", "city": "Kano", "zip": "700001"}', '{"source": "desktop", "gift_wrap": true, "coupon": "WINTER30"}'),
(29, '2025-03-15', 15167.31, 'Cancelled', '{"street": "64 Samuel Ladoke Akintola", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "SAVE15"}'),
(80, '2025-02-15', 6700.0, 'Processing', '{"street": "29 Emeka Anyaoku", "city": "Kano", "zip": "700001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "FREESHIP"}'),
(113, '2025-07-02', 79277.99, 'Pending', '{"street": "26 Yakubu Gowon", "city": "Abuja", "zip": "900001"}', '{"source": "desktop", "gift_wrap": true, "coupon": "NEWUSER25"}'),
(52, '2025-05-13', 5902.75, 'Processing', '{"street": "121 Michael Okpara", "city": "Kano", "zip": "700001"}', '{"source": "desktop", "coupon": "SAVE15"}'),
(113, '2025-05-06', 30926.27, 'Processing', '{"street": "126 Nnamdi Azikiwe", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(188, '2025-05-05', 7971.72, 'Shipped', '{"street": "128 Herbert Macaulay", "city": "Ibadan", "zip": "200001"}', '{"source": "mobile", "coupon": "SUMMER20"}'),
(7, '2025-02-03', 2237.64, 'Shipped', '{"street": "190 Ahmadu Bello Way", "city": "Port Harcourt", "zip": "500001"}', '{"source": "tablet", "notes": "Gift for anniversary"}'),
(107, '2025-01-29', 35051.93, 'Shipped', '{"street": "26 Emeka Anyaoku", "city": "Kano", "zip": "700001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(176, '2025-05-18', 4413.28, 'Shipped', '{"street": "9 Ahmadu Bello Way", "city": "Maiduguri", "zip": "600001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(126, '2025-05-10', 7227.98, 'Shipped', '{"street": "107 Herbert Macaulay", "city": "Abuja", "zip": "900001"}', '{"source": "mobile", "coupon": "WINTER30"}'),
(105, '2025-04-13', 7756.64, 'Shipped', '{"street": "4 Aminu Kano", "city": "Port Harcourt", "zip": "500001"}', '{"source": "desktop", "coupon": "FREESHIP"}'),
(53, '2025-07-03', 105554.19, 'Processing', '{"street": "104 Emeka Anyaoku", "city": "Lagos", "zip": "100001"}', '{"source": "tablet", "coupon": "WELCOME10"}'),
(177, '2025-02-14', 3052.45, 'Shipped', '{"street": "30 Allen Avenue", "city": "Aba", "zip": "450001"}', '{"source": "desktop", "coupon": "SUMMER20"}'),
(189, '2025-06-21', 2319.99, 'Processing', '{"street": "56 Adekunle Fajuyi", "city": "Aba", "zip": "450001"}', '{"source": "tablet", "coupon": "SAVE15"}'),
(5, '2025-05-26', 2081.13, 'Delivered', '{"street": "147 Samuel Ladoke Akintola", "city": "Kaduna", "zip": "800001"}', '{"source": "desktop", "coupon": "WELCOME10", "notes": "Birthday present"}'),
(186, '2025-02-23', 5218.85, 'Shipped', '{"street": "58 Michael Okpara", "city": "Port Harcourt", "zip": "500001"}', '{"source": "desktop", "coupon": "FREESHIP"}'),
(35, '2025-01-10', 33941.95, 'Processing', '{"street": "171 Allen Avenue", "city": "Aba", "zip": "450001"}', '{"source": "desktop", "coupon": "FREESHIP"}'),
(43, '2025-05-05', 3733.32, 'Pending', '{"street": "88 Michael Okpara", "city": "Port Harcourt", "zip": "500001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "NEWUSER25"}'),
(175, '2025-06-23', 6948.33, 'Pending', '{"street": "133 Herbert Macaulay", "city": "Benin City", "zip": "300001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "SAVE15"}'),
(148, '2025-04-13', 6394.29, 'Pending', '{"street": "81 Anthony Enahoro", "city": "Zaria", "zip": "810001"}', '{"source": "tablet", "coupon": "SUMMER20"}'),
(44, '2025-03-14', 53938.77, 'Processing', '{"street": "40 Adekunle Fajuyi", "city": "Lagos", "zip": "100001"}', '{"source": "mobile", "gift_wrap": true, "coupon": "SUMMER20", "notes": "Leave at front desk"}'),
(159, '2025-02-19', 90457.81, 'Processing', '{"street": "123 Ahmadu Bello Way", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "coupon": "WELCOME10"}'),
(175, '2025-02-28', 8168.67, 'Delivered', '{"street": "173 Allen Avenue", "city": "Benin City", "zip": "300001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(83, '2025-03-01', 9242.89, 'Shipped', '{"street": "180 Ahmadu Bello Way", "city": "Lagos", "zip": "100001"}', '{"source": "mobile", "coupon": "FREESHIP", "notes": "Birthday present"}'),
(61, '2025-06-22', 13316.31, 'Delivered', '{"street": "108 Ahmadu Bello Way", "city": "Aba", "zip": "450001"}', '{"source": "desktop"}'),
(32, '2025-01-01', 10313.84, 'Delivered', '{"street": "52 Ibrahim Taiwo", "city": "Kaduna", "zip": "800001"}', '{"source": "tablet", "gift_wrap": true, "coupon": "SUMMER20"}'),
(22, '2025-05-30', 39685.99, 'Pending', '{"street": "114 Ahmadu Bello Way", "city": "Kano", "zip": "700001"}', '{"source": "tablet", "coupon": "NEWUSER25"}'),
(102, '2025-06-27', 55501.93, 'Shipped', '{"street": "106 Olusegun Obasanjo", "city": "Aba", "zip": "450001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(13, '2025-05-22', 74260.09, 'Shipped', '{"street": "47 Marina Road", "city": "Zaria", "zip": "810001"}', '{"source": "desktop", "coupon": "NEWUSER25"}'),
(175, '2025-02-15', 12009.45, 'Delivered', '{"street": "61 Adetokunbo Ademola", "city": "Abuja", "zip": "900001"}', '{"source": "mobile", "coupon": "SAVE15"}'),
(96, '2025-01-03', 8286.22, 'Delivered', '{"street": "62 Oduduwa", "city": "Ibadan", "zip": "200001"}', '{"source": "desktop", "coupon": "WELCOME10", "notes": "Signature required"}'),
(82, '2025-07-01', 100777.8, 'Processing', '{"street": "125 Aminu Kano", "city": "Aba", "zip": "450001"}', '{"source": "desktop", "coupon": "WINTER30", "notes": "Birthday present"}'),
(72, '2025-03-01', 38435.56, 'Shipped', '{"street": "180 Nnamdi Azikiwe", "city": "Kano", "zip": "700001"}', '{"source": "mobile", "coupon": "FREESHIP"}'),
(123, '2025-05-17', 2684.37, 'Shipped', '{"street": "7 Aminu Kano", "city": "Maiduguri", "zip": "600001"}', '{"source": "tablet"}'),
(77, '2025-03-27', 87779.23, 'Shipped', '{"street": "89 Adetokunbo Ademola", "city": "Kaduna", "zip": "800001"}', '{"source": "mobile", "coupon": "WINTER30"}'),
(71, '2025-04-25', 171369.04, 'Pending', '{"street": "35 Oduduwa", "city": "Lagos", "zip": "100001"}', '{"source": "mobile"}');



INSERT INTO order_items (order_id, product_id, quantity, price, discount, item_attributes)
VALUES
(1, 5, 3, 23535.54, 0.0, '{"bundle_offer": true, "installation": "Premium"}'),
(1, 89, 2, 6020.04, 0.0, '{}'),
(1, 22, 1, 14182.41, 1248.09, '{"warranty": "1 year", "bundle_offer": true}'),
(1, 59, 2, 80944.84, 0.0, '{"size": "XL", "color": "Blue"}'),
(1, 145, 6, 15319.54, 0.0, '{"warranty": "2 years", "bundle_offer": true}'),
(2, 133, 2, 3811.54, 0.0, '{"bundle_offer": true}'),
(3, 156, 8, 90503.76, 0.0, '{"warranty": "2 years", "size": "M"}'),
(3, 114, 1, 49509.01, 6532.24, '{}'),
(3, 28, 3, 14239.62, 2246.53, '{"warranty": "6 months", "size": "XL"}'),
(3, 39, 2, 17378.43, 0.0, '{"size": "XL"}'),
(4, 119, 1, 1772.44, 123.58, '{"bundle_offer": true}'),
(4, 124, 10, 110081.0, 0.0, '{"warranty": "6 months", "bundle_offer": true}'),
(4, 44, 2, 12541.66, 0.0, '{"warranty": "2 years"}'),
(5, 23, 1, 16826.98, 0.0, '{"size": "L", "color": "Blue"}'),
(5, 77, 3, 871.81, 0.0, '{"warranty": "1 year"}'),
(6, 154, 6, 35258.24, 0.0, '{"bundle_offer": true}'),
(6, 10, 3, 2530.22, 0.0, '{"warranty": "1 year", "color": "Black", "storage_upgrade": "1TB SSD"}'),
(7, 102, 4, 20309.88, 0.0, '{"bundle_offer": true, "engraving": "Date"}'),
(7, 27, 2, 6915.3, 0.0, '{"bundle_offer": true}'),
(8, 164, 3, 15555.11, 0.0, '{"size": "S"}'),
(8, 160, 3, 6261.0, 0.0, '{"warranty": "6 months", "size": "XL", "engraving": "Message"}'),
(9, 131, 3, 24641.72, 0.0, '{"warranty": "2 years", "bundle_offer": true, "color": "Blue"}'),
(9, 175, 1, 7959.72, 646.6, '{"size": "S"}'),
(9, 37, 1, 17918.55, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "M", "color": "Red"}'),
(9, 194, 6, 102633.39, 0.0, '{"warranty": "2 years", "bundle_offer": true, "size": "S"}'),
(9, 170, 2, 5461.39, 425.6, '{"bundle_offer": true}'),
(10, 114, 2, 102334.04, 0.0, '{"warranty": "6 months"}'),
(10, 163, 5, 16619.74, 0.0, '{}'),
(10, 176, 2, 1918.99, 0.0, '{"warranty": "2 years", "bundle_offer": true}'),
(10, 113, 2, 41661.42, 7445.64, '{"warranty": "6 months"}'),
(10, 67, 2, 18463.91, 0.0, '{"warranty": "1 year"}'),
(11, 158, 3, 2609.45, 0.0, '{"bundle_offer": true, "color": "Red"}'),
(11, 142, 4, 13603.89, 0.0, '{"color": "White"}'),
(11, 194, 10, 8682.21, 1711.9, '{}'),
(12, 174, 9, 8550.77, 852.65, '{"warranty": "1 year"}'),
(13, 114, 5, 65182.42, 0.0, '{"warranty": "1 year"}'),
(13, 51, 8, 3067.23, 0.0, '{"bundle_offer": true}'),
(13, 23, 3, 13242.41, 0.0, '{}'),
(14, 188, 2, 9353.14, 0.0, '{"warranty": "2 years", "size": "L"}'),
(14, 34, 2, 16106.13, 1567.51, '{"warranty": "1 year", "color": "White", "engraving": "Date"}'),
(14, 140, 3, 9097.47, 0.0, '{"warranty": "1 year", "RAM_upgrade": "16GB"}'),
(14, 120, 3, 5852.78, 0.0, '{"warranty": "1 year", "bundle_offer": true, "storage_upgrade": "2TB HDD"}'),
(15, 59, 1, 1918.47, 381.74, '{"warranty": "2 years", "size": "XL", "color": "Red"}'),
(15, 152, 1, 85019.99, 14057.94, '{}'),
(15, 104, 1, 22603.7, 0.0, '{"warranty": "2 years", "color": "Blue"}'),
(15, 167, 2, 12166.72, 0.0, '{"warranty": "1 year", "size": "M"}'),
(16, 57, 2, 35786.23, 7138.18, '{}'),
(16, 3, 2, 67819.31, 8510.56, '{"warranty": "6 months", "size": "M", "color": "White"}'),
(16, 22, 1, 117763.28, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "L", "color": "Black"}'),
(16, 110, 1, 3729.05, 0.0, '{}'),
(17, 139, 4, 4774.5, 0.0, '{}'),
(17, 72, 2, 33267.1, 0.0, '{"warranty": "1 year"}'),
(18, 15, 3, 67054.24, 30187.5, '{"engraving": "Date"}'),
(19, 3, 1, 144390.2, 0.0, '{"warranty": "6 months"}'),
(19, 96, 6, 14102.35, 829.43, '{"warranty": "6 months", "size": "XL"}'),
(19, 29, 1, 4064.64, 318.74, '{"warranty": "2 years", "bundle_offer": true, "size": "S"}'),
(20, 64, 3, 7968.52, 0.0, '{"bundle_offer": true, "size": "L", "color": "Black"}'),
(21, 128, 3, 17931.37, 0.0, '{"bundle_offer": true, "installation": "Professional"}'),
(21, 147, 2, 6530.15, 0.0, '{"warranty": "2 years"}'),
(21, 200, 1, 28943.53, 0.0, '{"warranty": "2 years", "bundle_offer": true}'),
(21, 109, 3, 14346.98, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "M"}'),
(21, 116, 1, 44404.28, 0.0, '{"size": "S"}'),
(22, 61, 3, 2365.66, 302.47, '{"warranty": "1 year", "bundle_offer": true}'),
(22, 151, 10, 75466.22, 0.0, '{"warranty": "6 months"}'),
(22, 109, 1, 8366.36, 0.0, '{"size": "L"}'),
(23, 112, 1, 4396.54, 0.0, '{"color": "Blue"}'),
(23, 91, 2, 13216.35, 2603.89, '{"warranty": "2 years", "bundle_offer": true, "size": "L"}'),
(23, 1, 2, 10457.69, 1301.46, '{"warranty": "2 years", "size": "M", "color": "White"}'),
(23, 39, 3, 3077.99, 0.0, '{}'),
(24, 200, 1, 4689.46, 0.0, '{"warranty": "2 years"}'),
(24, 166, 5, 26839.36, 2475.41, '{}'),
(25, 25, 2, 9841.6, 0.0, '{"warranty": "2 years"}'),
(26, 117, 1, 22864.03, 0.0, '{}'),
(26, 16, 1, 24204.87, 4562.35, '{"size": "L"}'),
(26, 100, 2, 5766.9, 784.28, '{"bundle_offer": true, "installation": "Professional"}'),
(26, 53, 9, 8756.49, 0.0, '{"warranty": "6 months", "color": "Blue"}'),
(27, 10, 7, 19556.23, 0.0, '{"bundle_offer": true}'),
(27, 61, 2, 28910.43, 0.0, '{}'),
(27, 159, 3, 73086.88, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "XL"}'),
(27, 87, 1, 8037.15, 0.0, '{"warranty": "6 months"}'),
(28, 170, 5, 10740.88, 1782.94, '{}'),
(29, 150, 2, 15438.0, 919.46, '{"size": "S"}'),
(29, 120, 1, 9944.53, 0.0, '{"bundle_offer": true, "color": "Red"}'),
(29, 44, 2, 18620.24, 0.0, '{}'),
(29, 49, 2, 5548.26, 0.0, '{}'),
(29, 178, 7, 69203.46, 11970.22, '{"warranty": "6 months", "bundle_offer": true, "size": "M", "color": "Red"}'),
(30, 39, 8, 642.19, 0.0, '{"warranty": "1 year"}'),
(30, 31, 1, 26193.77, 0.0, '{"warranty": "1 year", "bundle_offer": true}'),
(31, 25, 3, 3687.56, 0.0, '{}'),
(31, 88, 2, 13367.24, 0.0, '{"size": "S", "color": "Black", "storage_upgrade": "512GB SSD"}'),
(31, 5, 3, 4383.36, 0.0, '{"size": "M"}'),
(31, 181, 3, 4811.44, 0.0, '{"warranty": "1 year"}'),
(31, 119, 2, 7353.05, 0.0, '{"warranty": "1 year", "size": "XL"}'),
(32, 185, 2, 48620.41, 0.0, '{"color": "Green"}'),
(32, 142, 3, 10119.56, 770.48, '{"warranty": "2 years", "color": "Green", "RAM_upgrade": "16GB"}'),
(32, 97, 2, 13375.91, 0.0, '{"bundle_offer": true, "color": "White"}'),
(32, 81, 3, 16763.24, 1701.27, '{"warranty": "6 months", "size": "L"}'),
(32, 68, 3, 15480.27, 3018.73, '{}'),
(33, 22, 4, 3505.11, 0.0, '{"warranty": "1 year", "bundle_offer": true, "color": "White"}'),
(33, 71, 3, 28402.05, 0.0, '{"warranty": "2 years", "bundle_offer": true, "size": "L", "color": "Green", "gift_wrap": true}'),
(33, 138, 3, 12422.23, 0.0, '{"warranty": "6 months", "color": "Blue"}'),
(34, 86, 3, 99207.32, 0.0, '{}'),
(34, 13, 3, 31809.42, 2506.06, '{}'),
(35, 136, 1, 5974.49, 0.0, '{"size": "S"}'),
(35, 21, 7, 11925.2, 0.0, '{}'),
(35, 162, 1, 8158.65, 0.0, '{"color": "White"}'),
(35, 4, 3, 4305.42, 0.0, '{}'),
(36, 181, 2, 8799.23, 927.12, '{"warranty": "2 years", "size": "S"}'),
(37, 12, 5, 19578.72, 3724.46, '{}'),
(37, 111, 7, 123250.79, 10518.04, '{"warranty": "1 year", "bundle_offer": true}'),
(37, 63, 5, 18340.29, 2531.0, '{"color": "Red"}'),
(38, 192, 2, 129185.48, 0.0, '{}'),
(38, 184, 2, 9754.62, 0.0, '{"warranty": "6 months", "size": "XL", "installation": "Professional"}'),
(39, 51, 2, 2333.86, 0.0, '{"warranty": "6 months", "installation": "Premium"}'),
(39, 54, 4, 1224.45, 0.0, '{"size": "XL"}'),
(39, 139, 3, 25712.68, 0.0, '{"size": "XL"}'),
(40, 24, 9, 117832.18, 0.0, '{"warranty": "1 year"}'),
(40, 188, 1, 39832.67, 0.0, '{"warranty": "6 months", "size": "XL"}'),
(40, 151, 2, 119032.74, 0.0, '{}'),
(40, 174, 7, 7244.9, 1175.87, '{"color": "Green"}'),
(41, 48, 1, 13992.42, 1904.57, '{"warranty": "6 months"}'),
(42, 106, 3, 26095.19, 0.0, '{"bundle_offer": true, "color": "Blue"}'),
(42, 169, 2, 6350.8, 0.0, '{"warranty": "1 year", "size": "XL"}'),
(42, 27, 3, 28557.99, 0.0, '{"warranty": "1 year"}'),
(42, 152, 6, 16357.68, 1155.23, '{"warranty": "2 years", "bundle_offer": true}'),
(42, 135, 3, 8188.05, 0.0, '{}'),
(43, 34, 8, 22542.53, 3553.09, '{}'),
(43, 153, 3, 6135.04, 0.0, '{"size": "M"}'),
(43, 12, 10, 10218.26, 0.0, '{"warranty": "6 months", "size": "L", "color": "Green"}'),
(43, 71, 1, 26209.83, 0.0, '{}'),
(44, 42, 2, 8661.75, 0.0, '{"warranty": "6 months", "gift_wrap": true}'),
(44, 180, 1, 11653.3, 0.0, '{"warranty": "1 year"}'),
(44, 25, 3, 8330.83, 1006.11, '{"warranty": "2 years", "size": "M", "color": "White"}'),
(45, 10, 5, 21467.8, 0.0, '{"warranty": "6 months", "RAM_upgrade": "64GB"}'),
(46, 34, 3, 20594.43, 5203.71, '{"size": "M"}'),
(46, 62, 3, 14154.58, 979.2, '{"warranty": "6 months"}'),
(46, 148, 5, 25240.32, 0.0, '{}'),
(47, 83, 3, 47247.77, 0.0, '{"bundle_offer": true, "color": "Red"}'),
(47, 118, 1, 8345.32, 0.0, '{"size": "M"}'),
(47, 62, 2, 91688.35, 15797.06, '{}'),
(48, 118, 1, 21198.94, 0.0, '{"warranty": "1 year", "size": "XL", "color": "Black"}'),
(49, 190, 6, 6350.0, 1070.72, '{"color": "Green"}'),
(49, 1, 2, 18924.87, 0.0, '{"bundle_offer": true, "engraving": "Date"}'),
(49, 11, 2, 4290.22, 0.0, '{}'),
(49, 5, 1, 21978.02, 0.0, '{"warranty": "1 year"}'),
(49, 184, 2, 51706.34, 8841.44, '{"installation": "Basic"}'),
(50, 85, 10, 14364.55, 1579.67, '{"warranty": "2 years", "bundle_offer": true, "size": "M", "storage_upgrade": "1TB SSD"}'),
(50, 181, 1, 5544.05, 335.74, '{"warranty": "6 months", "bundle_offer": true, "size": "M", "color": "Red"}'),
(50, 154, 3, 1708.93, 293.64, '{"bundle_offer": true, "color": "Red"}'),
(51, 70, 3, 24781.46, 2922.61, '{"bundle_offer": true, "size": "S"}'),
(51, 77, 10, 15377.68, 0.0, '{"bundle_offer": true, "color": "White"}'),
(51, 89, 9, 18659.36, 7728.53, '{}'),
(51, 197, 3, 27951.91, 0.0, '{"warranty": "2 years"}'),
(52, 101, 3, 10087.36, 1764.75, '{"bundle_offer": true}'),
(52, 159, 1, 1414.19, 0.0, '{"size": "L"}'),
(53, 25, 3, 94144.6, 0.0, '{"bundle_offer": true, "size": "L"}'),
(53, 92, 5, 15444.88, 0.0, '{"warranty": "6 months", "size": "XL"}'),
(53, 181, 3, 23074.18, 0.0, '{"warranty": "1 year"}'),
(53, 187, 2, 18303.66, 0.0, '{"warranty": "1 year", "size": "XL"}'),
(54, 6, 2, 76652.54, 0.0, '{"warranty": "1 year"}'),
(54, 56, 3, 14203.7, 1849.17, '{"warranty": "2 years"}'),
(54, 49, 8, 19916.06, 2642.45, '{"warranty": "6 months"}'),
(55, 17, 6, 1966.05, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "S"}'),
(55, 177, 3, 53552.69, 0.0, '{"gift_wrap": true}'),
(55, 68, 1, 2635.59, 170.56, '{"bundle_offer": true}'),
(56, 116, 1, 3527.64, 201.86, '{"warranty": "6 months", "bundle_offer": true}'),
(56, 144, 1, 2079.17, 0.0, '{}'),
(56, 126, 1, 42845.4, 0.0, '{"size": "M"}'),
(56, 31, 2, 13127.69, 0.0, '{"bundle_offer": true}'),
(57, 119, 1, 1948.22, 0.0, '{}'),
(57, 100, 2, 18555.51, 0.0, '{"warranty": "2 years"}'),
(57, 84, 6, 2253.18, 187.93, '{"warranty": "1 year", "color": "Red"}'),
(58, 160, 10, 1819.45, 333.85, '{"warranty": "6 months"}'),
(58, 140, 3, 5827.64, 833.65, '{"bundle_offer": true, "size": "S", "engraving": "Date"}'),
(58, 87, 4, 20775.36, 3997.17, '{}'),
(59, 162, 3, 9064.85, 0.0, '{"warranty": "1 year", "size": "XL"}'),
(60, 147, 3, 6919.02, 0.0, '{"warranty": "1 year", "color": "Black"}'),
(61, 107, 8, 8710.9, 3229.49, '{"warranty": "6 months", "size": "XL", "color": "Blue"}'),
(61, 200, 3, 1922.08, 328.34, '{"size": "L"}'),
(61, 125, 2, 7608.58, 0.0, '{}'),
(61, 112, 3, 7553.59, 0.0, '{"bundle_offer": true}'),
(61, 25, 5, 4201.96, 473.6, '{"size": "S"}'),
(62, 185, 1, 11524.73, 1785.05, '{"warranty": "6 months", "gift_wrap": true}'),
(62, 23, 3, 28628.94, 4775.13, '{"size": "M"}'),
(62, 156, 3, 9538.1, 0.0, '{"color": "Black"}'),
(62, 154, 2, 7602.56, 0.0, '{"warranty": "2 years"}'),
(62, 166, 2, 16641.35, 5299.09, '{}'),
(63, 200, 1, 75678.85, 0.0, '{}'),
(63, 15, 3, 14905.12, 1601.93, '{}'),
(63, 111, 1, 23061.08, 0.0, '{"warranty": "1 year"}'),
(63, 189, 1, 22504.81, 0.0, '{"size": "L", "color": "Blue"}'),
(63, 64, 2, 10976.69, 0.0, '{}'),
(64, 33, 10, 33174.65, 0.0, '{"size": "S", "color": "White"}'),
(65, 177, 1, 23472.67, 6341.38, '{"warranty": "1 year", "bundle_offer": true}'),
(65, 196, 1, 8686.18, 1152.27, '{"size": "S"}'),
(65, 116, 1, 19176.85, 0.0, '{"bundle_offer": true, "storage_upgrade": "2TB HDD"}'),
(65, 125, 2, 1568.28, 0.0, '{"size": "L"}'),
(66, 130, 2, 9737.32, 0.0, '{"color": "Green"}'),
(66, 86, 3, 5255.15, 0.0, '{"size": "XL"}'),
(66, 20, 2, 49325.77, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "XL"}'),
(66, 126, 2, 13582.26, 2415.64, '{"bundle_offer": true, "size": "XL"}'),
(66, 125, 3, 22905.34, 2248.19, '{"warranty": "2 years"}'),
(67, 172, 1, 1943.89, 0.0, '{"bundle_offer": true}'),
(67, 200, 1, 11591.04, 0.0, '{"warranty": "6 months"}'),
(68, 76, 3, 9656.67, 0.0, '{"bundle_offer": true}'),
(68, 15, 1, 2708.46, 343.69, '{}'),
(69, 92, 1, 8955.84, 0.0, '{}'),
(69, 159, 3, 3815.87, 1000.88, '{"color": "Red"}'),
(69, 73, 3, 119936.49, 0.0, '{"warranty": "2 years", "bundle_offer": true}'),
(69, 1, 2, 37257.32, 6349.39, '{"size": "S"}'),
(69, 144, 2, 24812.18, 0.0, '{"size": "S", "color": "Green", "installation": "Basic"}'),
(70, 185, 3, 15430.32, 0.0, '{"color": "White"}'),
(71, 175, 2, 80871.93, 5938.65, '{"color": "Black"}'),
(71, 93, 1, 18111.27, 1108.01, '{"warranty": "6 months"}'),
(71, 122, 2, 83290.81, 0.0, '{"warranty": "2 years", "color": "Red"}'),
(72, 125, 1, 13872.02, 0.0, '{"bundle_offer": true, "color": "Green"}'),
(72, 129, 2, 21380.71, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "S"}'),
(73, 97, 1, 1025.98, 0.0, '{"warranty": "6 months"}'),
(73, 35, 5, 30025.37, 0.0, '{}'),
(73, 145, 1, 19308.96, 8718.13, '{"warranty": "2 years", "RAM_upgrade": "64GB"}'),
(73, 179, 2, 5893.06, 1024.28, '{"size": "XL"}'),
(74, 85, 1, 5096.25, 0.0, '{}'),
(75, 137, 2, 19166.9, 0.0, '{"warranty": "2 years"}'),
(75, 81, 1, 14756.34, 0.0, '{"warranty": "6 months", "size": "L"}'),
(76, 60, 8, 11392.61, 1599.39, '{"size": "L"}'),
(76, 8, 3, 6982.96, 1231.86, '{"size": "S"}'),
(77, 175, 4, 772.58, 0.0, '{"size": "XL"}'),
(77, 1, 1, 3709.96, 0.0, '{}'),
(77, 55, 8, 6723.43, 0.0, '{"warranty": "2 years", "size": "M"}'),
(77, 133, 2, 7613.16, 1144.91, '{"warranty": "1 year", "size": "L"}'),
(77, 165, 1, 12755.62, 0.0, '{"warranty": "1 year"}'),
(78, 80, 2, 66779.34, 0.0, '{"warranty": "1 year", "size": "L", "color": "White"}'),
(79, 108, 3, 79956.28, 0.0, '{"size": "M"}'),
(79, 99, 1, 5780.04, 0.0, '{"size": "XL"}'),
(79, 49, 9, 5630.43, 0.0, '{"warranty": "2 years"}'),
(79, 60, 1, 6853.34, 0.0, '{"color": "White"}'),
(80, 108, 2, 28146.91, 0.0, '{"warranty": "6 months"}'),
(80, 60, 1, 11514.21, 0.0, '{}'),
(81, 117, 1, 8071.53, 1036.76, '{"bundle_offer": true, "size": "S", "color": "Black"}'),
(81, 161, 9, 149924.83, 0.0, '{"warranty": "2 years", "color": "Red"}'),
(81, 45, 10, 9198.91, 0.0, '{"bundle_offer": true, "size": "S"}'),
(82, 119, 1, 76088.79, 6622.7, '{"size": "M"}'),
(83, 120, 2, 18351.78, 1957.73, '{}'),
(83, 156, 6, 7675.06, 0.0, '{"bundle_offer": true, "storage_upgrade": "512GB SSD"}'),
(83, 51, 2, 18056.01, 2114.97, '{"warranty": "1 year", "size": "XL", "color": "Green"}'),
(83, 56, 1, 6698.5, 513.05, '{"bundle_offer": true, "size": "XL", "engraving": "Message"}'),
(84, 29, 1, 9988.38, 0.0, '{"warranty": "2 years", "size": "XL"}'),
(84, 164, 2, 9996.1, 0.0, '{"warranty": "1 year", "color": "Green"}'),
(84, 10, 8, 146056.3, 27592.45, '{"warranty": "1 year", "color": "Green", "gift_wrap": true}'),
(84, 124, 1, 19863.93, 9164.89, '{"size": "L"}'),
(84, 32, 1, 117445.48, 0.0, '{"size": "M"}'),
(85, 112, 2, 4334.17, 0.0, '{"size": "L"}'),
(85, 175, 2, 7235.67, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "S"}'),
(85, 60, 1, 43818.35, 0.0, '{}'),
(85, 64, 2, 9069.23, 683.14, '{"warranty": "6 months", "color": "Red"}'),
(86, 82, 3, 9944.95, 966.84, '{"warranty": "6 months"}'),
(87, 170, 3, 7818.06, 0.0, '{"warranty": "6 months", "size": "S"}'),
(88, 60, 2, 139336.09, 0.0, '{"warranty": "1 year"}'),
(88, 1, 3, 18762.47, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "XL"}'),
(88, 84, 3, 15356.11, 0.0, '{"bundle_offer": true}'),
(88, 65, 2, 9284.24, 0.0, '{"warranty": "2 years"}'),
(88, 148, 5, 15641.4, 2277.16, '{"warranty": "6 months", "gift_wrap": true}'),
(89, 171, 1, 26234.1, 1327.6, '{"size": "XL"}'),
(89, 113, 1, 631.75, 0.0, '{"warranty": "2 years"}'),
(90, 107, 2, 37990.19, 3487.42, '{"warranty": "1 year", "bundle_offer": true}'),
(90, 70, 5, 45508.3, 8715.32, '{"bundle_offer": true, "color": "Blue"}'),
(90, 32, 1, 23733.71, 0.0, '{}'),
(90, 50, 2, 5251.32, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "XL", "color": "Red"}'),
(90, 67, 1, 13191.92, 6132.18, '{"warranty": "2 years"}'),
(91, 135, 3, 117482.79, 20746.43, '{"warranty": "1 year", "bundle_offer": true, "size": "XL"}'),
(91, 97, 2, 4621.83, 0.0, '{"bundle_offer": true}'),
(91, 170, 2, 7151.54, 0.0, '{}'),
(91, 185, 1, 21957.39, 4213.95, '{"warranty": "1 year", "bundle_offer": true, "color": "Red"}'),
(92, 82, 3, 24201.52, 0.0, '{"warranty": "2 years"}'),
(92, 52, 1, 4519.0, 0.0, '{"warranty": "1 year", "size": "S", "color": "White"}'),
(93, 30, 2, 7367.27, 0.0, '{}'),
(93, 104, 2, 16364.64, 0.0, '{"bundle_offer": true}'),
(93, 77, 3, 22250.83, 2973.91, '{"bundle_offer": true, "color": "Red", "gift_wrap": true}'),
(93, 194, 5, 7976.81, 0.0, '{}'),
(94, 14, 1, 16482.39, 0.0, '{"warranty": "1 year", "color": "Red"}'),
(95, 139, 1, 22984.31, 0.0, '{}'),
(96, 68, 2, 57635.92, 0.0, '{"size": "M", "color": "White", "storage_upgrade": "1TB SSD"}'),
(96, 51, 3, 44687.89, 6120.88, '{"warranty": "1 year", "bundle_offer": true, "color": "White", "engraving": "Date"}'),
(96, 78, 10, 22576.92, 0.0, '{"bundle_offer": true, "size": "S"}'),
(96, 120, 1, 135828.24, 20560.95, '{}'),
(96, 135, 2, 6062.01, 0.0, '{}'),
(97, 80, 2, 16745.23, 2592.88, '{"size": "M", "engraving": "Message"}'),
(97, 26, 2, 21454.12, 3007.74, '{"warranty": "2 years"}'),
(97, 121, 3, 19865.86, 0.0, '{"warranty": "2 years", "size": "L"}'),
(97, 19, 3, 8896.64, 1628.21, '{}'),
(98, 187, 1, 8332.62, 727.44, '{}'),
(98, 196, 1, 21925.32, 0.0, '{"color": "White"}'),
(98, 179, 4, 16423.92, 0.0, '{"bundle_offer": true, "color": "Blue"}'),
(99, 135, 10, 15331.36, 0.0, '{}'),
(99, 53, 1, 3489.46, 0.0, '{"warranty": "2 years", "bundle_offer": true, "color": "Black", "installation": "Premium"}'),
(100, 125, 4, 128435.25, 0.0, '{"bundle_offer": true, "size": "S"}'),
(100, 183, 2, 76306.84, 0.0, '{}'),
(100, 55, 1, 35064.12, 0.0, '{"size": "XL"}'),
(101, 88, 1, 5276.91, 0.0, '{"warranty": "2 years"}'),
(101, 20, 2, 66052.43, 0.0, '{"warranty": "1 year", "installation": "Premium"}'),
(101, 62, 3, 4807.76, 0.0, '{"warranty": "2 years", "bundle_offer": true, "size": "L"}'),
(101, 67, 3, 135968.05, 0.0, '{"bundle_offer": true, "color": "Green"}'),
(102, 146, 1, 9137.47, 0.0, '{"warranty": "1 year", "color": "Green"}'),
(102, 118, 2, 14741.61, 0.0, '{"RAM_upgrade": "64GB"}'),
(102, 80, 1, 98856.74, 0.0, '{"size": "S"}'),
(102, 152, 1, 139919.84, 25210.68, '{"warranty": "6 months", "size": "L"}'),
(103, 155, 3, 27130.98, 0.0, '{"bundle_offer": true}'),
(104, 156, 2, 4354.6, 0.0, '{}'),
(104, 64, 3, 14260.05, 0.0, '{"bundle_offer": true}'),
(104, 63, 2, 22116.87, 0.0, '{"warranty": "2 years", "bundle_offer": true}'),
(104, 127, 3, 8980.07, 1471.96, '{"warranty": "6 months"}'),
(105, 122, 2, 27605.78, 0.0, '{}'),
(106, 75, 1, 18489.2, 1186.89, '{"warranty": "1 year"}'),
(106, 1, 3, 26543.79, 0.0, '{"warranty": "1 year"}'),
(107, 115, 3, 23904.37, 2942.46, '{}'),
(107, 80, 1, 1874.0, 0.0, '{"warranty": "1 year"}'),
(108, 92, 1, 8084.57, 0.0, '{}'),
(108, 76, 3, 38168.04, 3499.76, '{"warranty": "1 year", "engraving": "Message"}'),
(108, 8, 2, 3898.36, 0.0, '{"bundle_offer": true, "storage_upgrade": "2TB HDD"}'),
(109, 200, 2, 31022.55, 3853.18, '{"warranty": "1 year", "bundle_offer": true, "color": "Green"}'),
(109, 156, 2, 6474.92, 0.0, '{"warranty": "2 years"}'),
(110, 97, 9, 3448.44, 292.72, '{"size": "L"}'),
(111, 120, 3, 15982.54, 2500.02, '{"color": "Blue", "gift_wrap": true}'),
(111, 147, 5, 7618.61, 893.29, '{}'),
(111, 131, 2, 11898.88, 0.0, '{"warranty": "2 years", "color": "Red"}'),
(112, 174, 7, 20971.2, 0.0, '{"size": "L", "gift_wrap": true}'),
(112, 126, 3, 62686.81, 4024.25, '{"warranty": "6 months"}'),
(113, 191, 2, 27281.59, 3787.83, '{}'),
(113, 21, 2, 37319.5, 4734.87, '{"color": "Red"}'),
(113, 152, 3, 4667.87, 0.0, '{"warranty": "2 years", "color": "Black", "gift_wrap": true}'),
(113, 162, 3, 3516.86, 0.0, '{"warranty": "2 years"}'),
(113, 13, 1, 9882.94, 0.0, '{"warranty": "1 year"}'),
(114, 95, 1, 18934.48, 1814.27, '{"RAM_upgrade": "64GB"}'),
(114, 129, 9, 10379.65, 2784.86, '{"warranty": "2 years", "color": "Green"}'),
(114, 6, 10, 104673.08, 0.0, '{"size": "S", "storage_upgrade": "512GB SSD"}'),
(115, 161, 10, 802.59, 0.0, '{}'),
(115, 66, 3, 3075.6, 360.73, '{"warranty": "1 year"}'),
(115, 81, 6, 10071.5, 0.0, '{"color": "Black"}'),
(115, 86, 3, 102578.13, 15450.68, '{"color": "Red"}'),
(116, 168, 1, 16522.13, 974.71, '{"warranty": "1 year", "bundle_offer": true, "size": "XL"}'),
(117, 119, 2, 7987.01, 0.0, '{}'),
(117, 78, 2, 8172.93, 0.0, '{}'),
(117, 143, 3, 5814.26, 0.0, '{"engraving": "Message"}'),
(117, 1, 3, 22287.19, 0.0, '{"bundle_offer": true, "color": "Green"}'),
(117, 158, 2, 2975.94, 0.0, '{"warranty": "6 months", "color": "Blue"}'),
(118, 23, 2, 39820.62, 0.0, '{}'),
(119, 59, 9, 5554.42, 0.0, '{"warranty": "6 months", "gift_wrap": true}'),
(120, 103, 1, 46847.11, 20823.54, '{"size": "L", "color": "Green"}'),
(120, 39, 2, 13280.5, 0.0, '{"bundle_offer": true}'),
(120, 100, 4, 49404.64, 0.0, '{"bundle_offer": true}'),
(120, 167, 3, 20647.79, 2681.15, '{"warranty": "2 years", "bundle_offer": true, "gift_wrap": true}'),
(121, 92, 9, 28456.28, 0.0, '{"warranty": "1 year"}'),
(121, 191, 1, 24342.83, 2837.58, '{"warranty": "1 year", "color": "Red"}'),
(121, 159, 3, 21947.87, 0.0, '{"warranty": "6 months", "bundle_offer": true}'),
(121, 183, 3, 33696.34, 0.0, '{}'),
(121, 133, 3, 50868.82, 0.0, '{"warranty": "2 years", "engraving": "Message"}'),
(122, 187, 2, 7993.64, 0.0, '{"bundle_offer": true, "size": "XL", "installation": "Basic"}'),
(122, 83, 7, 18226.78, 0.0, '{}'),
(122, 11, 4, 5802.14, 975.93, '{"color": "Red"}'),
(123, 47, 2, 6783.4, 0.0, '{}'),
(123, 165, 3, 8226.07, 1121.97, '{}'),
(123, 32, 1, 25049.77, 0.0, '{"warranty": "2 years"}'),
(124, 33, 1, 2833.97, 250.17, '{"warranty": "6 months"}'),
(124, 29, 2, 13191.8, 0.0, '{}'),
(124, 7, 7, 8688.02, 0.0, '{}'),
(125, 56, 1, 3982.27, 0.0, '{"warranty": "2 years", "size": "L"}'),
(125, 96, 1, 696.76, 0.0, '{"size": "L", "RAM_upgrade": "64GB"}'),
(126, 32, 3, 34186.66, 0.0, '{"bundle_offer": true, "size": "XL"}'),
(126, 184, 5, 18222.55, 0.0, '{"warranty": "6 months", "bundle_offer": true, "color": "Black"}'),
(126, 74, 2, 25063.06, 0.0, '{"bundle_offer": true, "color": "White", "engraving": "Initials"}'),
(127, 7, 5, 2007.7, 255.82, '{"size": "S", "gift_wrap": true}'),
(128, 111, 3, 10116.71, 1696.1, '{"size": "XL"}'),
(128, 84, 2, 7359.37, 620.35, '{"warranty": "2 years", "size": "XL"}'),
(129, 189, 3, 14544.95, 0.0, '{"warranty": "2 years", "size": "L", "color": "Green"}'),
(130, 175, 2, 19084.08, 0.0, '{"warranty": "6 months", "bundle_offer": true}'),
(130, 185, 2, 19444.64, 2978.89, '{"warranty": "6 months", "bundle_offer": true, "size": "XL"}'),
(130, 80, 4, 16427.42, 0.0, '{}'),
(130, 23, 1, 39956.52, 0.0, '{"color": "Blue"}'),
(131, 13, 3, 23236.76, 3094.23, '{}'),
(131, 113, 2, 11656.49, 0.0, '{"warranty": "2 years"}'),
(131, 72, 1, 3556.67, 504.17, '{"warranty": "6 months", "color": "Black"}'),
(132, 47, 2, 25984.38, 2615.18, '{}'),
(132, 92, 3, 5050.56, 0.0, '{"warranty": "6 months"}'),
(133, 50, 6, 26039.49, 9853.12, '{"warranty": "6 months", "bundle_offer": true}'),
(133, 18, 1, 5654.21, 993.88, '{"size": "L", "color": "Blue"}'),
(133, 199, 3, 15844.45, 0.0, '{"color": "Red"}'),
(133, 82, 10, 2030.26, 0.0, '{"size": "L"}'),
(133, 174, 3, 60953.71, 11783.61, '{"warranty": "6 months"}'),
(134, 151, 2, 13603.75, 1330.17, '{"bundle_offer": true, "color": "Red"}'),
(134, 100, 3, 90547.15, 16210.75, '{"size": "M", "color": "Red"}'),
(134, 39, 2, 6491.19, 683.33, '{}'),
(135, 197, 7, 134951.08, 0.0, '{"gift_wrap": true}'),
(135, 8, 3, 5326.67, 0.0, '{}'),
(135, 71, 5, 11099.8, 561.6, '{"color": "Black"}'),
(135, 15, 1, 28028.15, 0.0, '{}'),
(135, 172, 3, 2502.65, 0.0, '{"bundle_offer": true, "color": "Green"}'),
(136, 167, 1, 4099.97, 0.0, '{"warranty": "1 year"}'),
(136, 142, 7, 71584.94, 5275.02, '{"bundle_offer": true, "color": "Green"}'),
(136, 106, 1, 9714.79, 1769.51, '{"warranty": "6 months", "installation": "Premium"}'),
(136, 171, 3, 8159.06, 0.0, '{"warranty": "6 months", "bundle_offer": true}'),
(137, 166, 1, 11972.5, 681.31, '{}'),
(137, 137, 10, 5506.43, 0.0, '{"warranty": "6 months"}'),
(138, 122, 1, 7841.12, 0.0, '{"engraving": "Date"}'),
(138, 12, 1, 41715.99, 0.0, '{"size": "L", "RAM_upgrade": "64GB"}'),
(139, 188, 1, 42809.14, 6381.64, '{"bundle_offer": true, "size": "L", "RAM_upgrade": "64GB"}'),
(139, 153, 1, 21508.71, 0.0, '{"warranty": "6 months"}'),
(139, 109, 3, 84156.43, 0.0, '{"engraving": "Initials"}'),
(140, 23, 5, 38739.37, 5766.5, '{"size": "M"}'),
(140, 97, 2, 9300.93, 0.0, '{"bundle_offer": true, "engraving": "Message"}'),
(140, 52, 3, 797.36, 0.0, '{"bundle_offer": true, "color": "Red"}'),
(140, 12, 3, 2546.14, 0.0, '{"warranty": "2 years", "engraving": "Date"}'),
(141, 161, 1, 9078.5, 0.0, '{"warranty": "2 years"}'),
(141, 80, 10, 17681.21, 2444.67, '{"warranty": "6 months", "bundle_offer": true, "size": "S"}'),
(142, 168, 3, 18947.45, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "S", "color": "Red"}'),
(142, 163, 2, 108694.1, 0.0, '{}'),
(142, 157, 1, 23885.45, 0.0, '{"warranty": "6 months", "size": "XL"}'),
(142, 94, 3, 4995.58, 405.61, '{"installation": "Professional"}'),
(143, 88, 3, 19421.2, 0.0, '{}'),
(143, 114, 2, 12231.7, 0.0, '{"warranty": "6 months", "size": "M"}'),
(143, 65, 2, 6464.86, 0.0, '{}'),
(144, 75, 2, 5014.79, 718.81, '{"size": "XL"}'),
(145, 92, 1, 84325.9, 0.0, '{"installation": "Premium"}'),
(145, 154, 1, 62483.3, 0.0, '{"bundle_offer": true, "size": "S"}'),
(145, 112, 10, 19297.27, 3029.12, '{"size": "M", "color": "Green"}'),
(146, 131, 3, 37923.84, 0.0, '{"warranty": "1 year", "color": "Green"}'),
(146, 190, 2, 42089.01, 0.0, '{"warranty": "2 years"}'),
(147, 60, 10, 16062.62, 0.0, '{"warranty": "2 years", "size": "S"}'),
(148, 82, 9, 115417.61, 0.0, '{"warranty": "1 year"}'),
(148, 198, 3, 8480.44, 0.0, '{"warranty": "1 year", "size": "L", "color": "White", "gift_wrap": true}'),
(148, 121, 3, 45997.52, 0.0, '{"warranty": "6 months"}'),
(148, 10, 3, 10755.84, 0.0, '{"size": "M"}'),
(149, 134, 7, 13322.68, 0.0, '{"warranty": "2 years", "bundle_offer": true, "size": "L"}'),
(149, 98, 3, 16588.96, 0.0, '{"warranty": "6 months"}'),
(150, 4, 3, 16257.12, 0.0, '{"storage_upgrade": "2TB HDD"}'),
(150, 118, 3, 18006.49, 1915.8, '{"warranty": "2 years"}'),
(150, 111, 1, 16041.61, 0.0, '{"bundle_offer": true}'),
(151, 61, 2, 2279.26, 0.0, '{"bundle_offer": true, "size": "S", "color": "Red"}'),
(151, 13, 2, 5819.72, 1107.97, '{"bundle_offer": true}'),
(151, 194, 3, 21839.12, 1120.48, '{}'),
(151, 138, 2, 97153.69, 0.0, '{"color": "White"}'),
(151, 38, 2, 16862.9, 976.85, '{"warranty": "1 year", "bundle_offer": true, "size": "XL"}'),
(152, 75, 6, 6692.11, 0.0, '{}'),
(152, 85, 1, 6298.1, 0.0, '{"size": "XL"}'),
(152, 177, 2, 17643.4, 0.0, '{"warranty": "2 years"}'),
(153, 54, 5, 2360.92, 362.84, '{"warranty": "1 year"}'),
(153, 109, 1, 14739.44, 0.0, '{"size": "L", "color": "Green"}'),
(153, 3, 6, 74959.05, 0.0, '{"gift_wrap": true}'),
(154, 124, 1, 17355.33, 0.0, '{}'),
(154, 181, 10, 44975.84, 6830.28, '{"size": "S"}'),
(154, 109, 3, 6989.34, 0.0, '{}'),
(154, 1, 1, 43518.12, 0.0, '{"size": "XL", "color": "Red", "gift_wrap": true}'),
(155, 20, 9, 9129.98, 1162.32, '{"size": "L"}'),
(156, 177, 1, 8697.79, 773.59, '{"warranty": "1 year", "size": "XL", "color": "Black"}'),
(156, 30, 1, 29832.31, 0.0, '{"warranty": "1 year"}'),
(156, 127, 1, 23536.66, 3154.59, '{"color": "White", "engraving": "Message"}'),
(156, 19, 1, 14788.68, 0.0, '{"size": "XL"}'),
(157, 53, 3, 11586.14, 0.0, '{"color": "White"}'),
(157, 121, 2, 22491.51, 0.0, '{"warranty": "2 years"}'),
(157, 30, 2, 63513.63, 7280.45, '{"bundle_offer": true, "size": "XL", "engraving": "Initials"}'),
(157, 74, 3, 25363.8, 8987.89, '{"warranty": "1 year", "bundle_offer": true, "color": "Black"}'),
(157, 38, 3, 17940.52, 0.0, '{"size": "XL"}'),
(158, 179, 3, 105914.31, 0.0, '{}'),
(158, 154, 2, 10150.14, 0.0, '{"size": "XL"}'),
(159, 174, 2, 5089.83, 288.48, '{"warranty": "6 months", "size": "L"}'),
(159, 166, 3, 7790.59, 1171.91, '{"warranty": "1 year", "bundle_offer": true, "size": "M", "color": "Red"}'),
(159, 189, 1, 23040.15, 2286.41, '{"bundle_offer": true, "size": "L", "color": "Blue"}'),
(159, 156, 2, 2023.74, 317.87, '{"bundle_offer": true}'),
(159, 118, 3, 2141.09, 126.87, '{"warranty": "2 years"}'),
(160, 23, 3, 7291.62, 1066.36, '{"warranty": "1 year", "color": "Blue"}'),
(160, 85, 1, 2410.16, 0.0, '{"bundle_offer": true, "size": "S"}'),
(160, 62, 3, 7329.89, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "XL", "color": "White"}'),
(161, 39, 3, 93687.79, 0.0, '{"warranty": "1 year", "size": "L"}'),
(161, 13, 2, 24049.71, 0.0, '{"bundle_offer": true}'),
(162, 114, 1, 14559.26, 0.0, '{"color": "Blue"}'),
(162, 154, 2, 25341.37, 0.0, '{}'),
(162, 12, 2, 10176.83, 1723.77, '{"warranty": "1 year", "color": "Red", "engraving": "Date"}'),
(162, 70, 3, 5789.02, 546.21, '{"bundle_offer": true, "size": "M"}'),
(163, 137, 1, 30560.59, 0.0, '{"size": "S"}'),
(163, 32, 3, 58741.66, 0.0, '{"warranty": "6 months"}'),
(163, 111, 3, 40256.71, 0.0, '{"size": "XL"}'),
(163, 3, 1, 43008.28, 0.0, '{"bundle_offer": true, "size": "XL", "RAM_upgrade": "16GB"}'),
(163, 68, 1, 42728.76, 2705.14, '{"warranty": "6 months", "color": "White"}'),
(164, 118, 3, 41026.26, 0.0, '{"warranty": "6 months"}'),
(164, 139, 3, 40546.66, 0.0, '{"size": "M"}'),
(165, 93, 3, 28857.89, 0.0, '{}'),
(165, 189, 3, 19772.26, 0.0, '{}'),
(165, 183, 8, 18268.41, 0.0, '{}'),
(166, 197, 2, 9924.27, 675.26, '{"warranty": "2 years", "bundle_offer": true, "color": "Green"}'),
(166, 153, 1, 34374.64, 0.0, '{"warranty": "1 year", "color": "Green", "gift_wrap": true}'),
(166, 103, 3, 14521.07, 0.0, '{"color": "Red", "storage_upgrade": "512GB SSD"}'),
(167, 190, 10, 612.6, 0.0, '{"bundle_offer": true}'),
(168, 74, 1, 22123.06, 2418.96, '{}'),
(168, 170, 3, 41638.73, 0.0, '{}'),
(168, 159, 2, 25064.81, 0.0, '{"color": "Black", "RAM_upgrade": "32GB"}'),
(168, 198, 9, 135522.75, 17992.47, '{"warranty": "1 year", "gift_wrap": true}'),
(169, 39, 1, 9685.48, 0.0, '{"bundle_offer": true, "size": "S"}'),
(169, 17, 2, 15301.6, 0.0, '{}'),
(169, 99, 1, 15184.45, 0.0, '{"warranty": "1 year", "bundle_offer": true, "RAM_upgrade": "64GB"}'),
(170, 28, 9, 25843.11, 0.0, '{"size": "L", "color": "White", "storage_upgrade": "1TB SSD"}'),
(170, 106, 2, 25415.1, 0.0, '{"warranty": "1 year"}'),
(170, 14, 1, 96019.85, 0.0, '{"warranty": "1 year", "size": "L"}'),
(170, 50, 1, 11019.06, 0.0, '{"color": "Blue"}'),
(170, 129, 3, 6392.58, 3059.98, '{"warranty": "1 year", "color": "Green"}'),
(171, 65, 1, 15707.22, 0.0, '{"RAM_upgrade": "32GB"}'),
(172, 98, 2, 46097.58, 2406.66, '{"warranty": "6 months", "color": "Green"}'),
(172, 168, 1, 12548.72, 0.0, '{"bundle_offer": true, "color": "Blue"}'),
(173, 17, 1, 6991.84, 0.0, '{"warranty": "2 years", "bundle_offer": true, "installation": "Professional"}'),
(173, 111, 3, 43261.8, 0.0, '{"warranty": "2 years", "bundle_offer": true}'),
(173, 112, 2, 2529.09, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "L"}'),
(173, 52, 2, 35157.61, 0.0, '{"color": "White", "installation": "Basic"}'),
(174, 138, 2, 9912.92, 0.0, '{"bundle_offer": true, "size": "S", "color": "White"}'),
(174, 125, 7, 8886.82, 1392.79, '{"bundle_offer": true}'),
(174, 180, 2, 7523.65, 0.0, '{"size": "M"}'),
(174, 46, 2, 28312.95, 3501.5, '{"warranty": "2 years"}'),
(175, 133, 7, 3058.58, 372.52, '{"warranty": "6 months", "bundle_offer": true}'),
(175, 104, 1, 22696.53, 1946.83, '{"warranty": "6 months", "bundle_offer": true}'),
(175, 74, 1, 127879.55, 15462.4, '{"warranty": "1 year", "bundle_offer": true}'),
(176, 25, 2, 14855.14, 0.0, '{"bundle_offer": true}'),
(176, 190, 2, 23317.32, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "L", "color": "White"}'),
(176, 56, 2, 3484.84, 253.83, '{"size": "M"}'),
(176, 23, 3, 43877.84, 0.0, '{"warranty": "6 months", "color": "White"}'),
(177, 179, 1, 6829.27, 0.0, '{"bundle_offer": true, "color": "White"}'),
(177, 48, 2, 16027.37, 2814.95, '{}'),
(177, 114, 2, 1926.18, 162.82, '{}'),
(177, 88, 1, 13194.5, 0.0, '{"size": "S", "color": "Red"}'),
(178, 82, 3, 25818.64, 0.0, '{"bundle_offer": true}'),
(178, 59, 8, 138161.31, 0.0, '{"bundle_offer": true}'),
(178, 128, 2, 5560.89, 595.92, '{"warranty": "2 years", "bundle_offer": true, "size": "XL"}'),
(178, 103, 3, 818.3, 0.0, '{}'),
(178, 42, 4, 26595.71, 0.0, '{}'),
(179, 158, 3, 9174.14, 0.0, '{"warranty": "1 year", "size": "M"}'),
(179, 85, 3, 3518.19, 397.49, '{"bundle_offer": true}'),
(179, 28, 10, 5519.6, 0.0, '{"warranty": "6 months"}'),
(180, 144, 1, 20742.38, 0.0, '{"warranty": "1 year", "color": "Red"}'),
(181, 47, 1, 42168.68, 0.0, '{"warranty": "2 years", "bundle_offer": true}'),
(181, 190, 2, 8652.11, 0.0, '{}'),
(182, 118, 1, 12173.26, 0.0, '{"bundle_offer": true, "size": "XL"}'),
(182, 191, 2, 38346.04, 0.0, '{"bundle_offer": true}'),
(182, 69, 3, 16723.36, 0.0, '{"warranty": "6 months", "bundle_offer": true, "size": "S"}'),
(182, 47, 7, 24169.82, 0.0, '{"warranty": "1 year", "bundle_offer": true, "size": "S"}'),
(183, 3, 10, 61202.17, 0.0, '{"warranty": "2 years"}'),
(183, 28, 1, 16153.47, 2774.5, '{"bundle_offer": true, "color": "Green"}'),
(183, 133, 3, 5703.01, 0.0, '{}'),
(183, 172, 3, 126992.97, 0.0, '{}'),
(184, 142, 8, 110289.01, 0.0, '{"gift_wrap": true}'),
(185, 128, 2, 87253.12, 0.0, '{"warranty": "1 year"}'),
(185, 78, 1, 15476.57, 1306.8, '{"warranty": "6 months"}'),
(185, 25, 1, 21770.12, 0.0, '{"warranty": "6 months"}'),
(185, 179, 1, 5036.59, 0.0, '{"warranty": "1 year", "bundle_offer": true, "engraving": "Message"}'),
(186, 111, 3, 16205.59, 0.0, '{"size": "S"}'),
(186, 154, 1, 21293.56, 7975.11, '{"color": "White", "installation": "Basic"}'),
(186, 79, 7, 8872.36, 0.0, '{"warranty": "2 years", "color": "Green"}'),
(186, 163, 3, 15934.92, 0.0, '{"bundle_offer": true, "color": "Green"}'),
(186, 170, 5, 1245.62, 0.0, '{"bundle_offer": true}'),
(187, 66, 2, 8295.16, 0.0, '{"storage_upgrade": "512GB SSD"}'),
(187, 58, 3, 21784.76, 0.0, '{"size": "L", "gift_wrap": true}'),
(187, 116, 2, 131600.17, 0.0, '{"color": "Green"}'),
(187, 90, 2, 11223.58, 2065.04, '{"warranty": "1 year", "size": "XL"}'),
(188, 167, 8, 2868.43, 0.0, '{"warranty": "2 years", "size": "M", "engraving": "Initials"}'),
(188, 85, 1, 23262.11, 0.0, '{"size": "L"}'),
(189, 120, 3, 117572.54, 0.0, '{}'),
(190, 146, 3, 12817.9, 0.0, '{"bundle_offer": true, "size": "M"}'),
(190, 13, 2, 19473.59, 0.0, '{"size": "L"}'),
(190, 69, 3, 39605.46, 5767.18, '{"warranty": "1 year", "bundle_offer": true, "size": "L"}'),
(191, 184, 2, 14546.56, 0.0, '{"warranty": "2 years"}'),
(191, 41, 2, 18257.38, 2303.66, '{"size": "S"}'),
(191, 64, 9, 21119.47, 2508.94, '{"bundle_offer": true, "color": "Red"}'),
(191, 62, 2, 26824.57, 3924.86, '{}'),
(192, 128, 3, 6619.26, 0.0, '{"size": "L", "color": "Blue"}'),
(192, 4, 1, 14429.02, 0.0, '{"warranty": "2 years"}'),
(192, 34, 1, 99767.68, 0.0, '{"size": "S"}'),
(193, 64, 2, 16961.2, 2429.59, '{"bundle_offer": true, "color": "Green"}'),
(193, 126, 2, 4825.12, 822.78, '{"size": "L"}'),
(193, 44, 3, 9196.16, 0.0, '{"bundle_offer": true, "size": "XL", "color": "White"}'),
(193, 68, 3, 73617.47, 0.0, '{"warranty": "6 months"}'),
(193, 156, 6, 10915.01, 0.0, '{"bundle_offer": true, "size": "S"}'),
(194, 75, 2, 86316.0, 0.0, '{"warranty": "1 year", "bundle_offer": true}'),
(194, 158, 2, 40672.21, 0.0, '{"warranty": "2 years", "color": "Black"}'),
(194, 175, 1, 43102.15, 6682.28, '{"bundle_offer": true, "size": "M"}'),
(194, 82, 1, 16067.33, 0.0, '{"size": "L"}'),
(195, 179, 3, 2447.24, 268.04, '{"warranty": "6 months", "color": "Black"}'),
(195, 49, 1, 15010.11, 0.0, '{"color": "Blue", "installation": "Premium"}'),
(195, 46, 3, 3247.39, 173.4, '{"warranty": "2 years"}'),
(196, 156, 7, 43006.55, 0.0, '{"bundle_offer": true, "engraving": "Message"}'),
(196, 51, 2, 123471.88, 0.0, '{"warranty": "6 months"}'),
(197, 136, 3, 24611.0, 0.0, '{"size": "XL", "color": "Black", "gift_wrap": true}'),
(197, 183, 9, 38425.67, 0.0, '{"size": "S"}'),
(198, 77, 1, 19066.98, 1091.22, '{"bundle_offer": true, "size": "XL", "color": "Blue"}'),
(198, 35, 1, 7656.15, 1183.9, '{"color": "Green"}'),
(198, 192, 1, 23832.85, 0.0, '{"size": "L", "color": "Green"}'),
(198, 176, 1, 13083.81, 0.0, '{"color": "Black"}'),
(199, 121, 3, 11417.97, 0.0, '{"bundle_offer": true, "size": "XL", "gift_wrap": true}'),
(199, 150, 1, 28136.07, 0.0, '{"color": "White"}'),
(199, 115, 3, 14187.49, 2318.93, '{"size": "M", "color": "Red"}'),
(200, 147, 2, 8132.06, 0.0, '{"size": "XL"}'),
(200, 85, 1, 49171.27, 0.0, '{}');


INSERT INTO departments (name, location, metadata)
VALUES
('Customer Service', 'Port Harcourt Support Office', '{"budget": "\u20a610M", "channels": ["Phone", "Email", "Chat", "Social Media"], "sla": "24-hour response time"}'),
('Customer Service 2', 'Abuja Helpdesk', '{"budget": "\u20a620M", "channels": ["Phone", "Email", "Chat", "Social Media"], "sla": "24-hour response time"}'),
('Human Resources', 'Abuja Regional HR', '{"budget": "\u20a628M", "functions": ["Recruitment", "Training & Development", "Compensation & Benefits", "Employee Relations", "Performance Management"], "employee_count": 145}'),
('Operations', 'Kano Distribution Center', '{"budget": "\u20a654M", "facilities": ["Main Warehouse", "Regional Distribution Centers", "Inventory Control"], "coverage": "National"}'),
('Marketing', 'Abuja Strategy Office', '{"budget": "\u20a660M", "channels": ["TV", "Email", "Social Media", "Radio", "Events"], "target_demographic": "Families"}'),
('Customer Service 3', 'Lagos Call Center', '{"budget": "\u20a626M", "channels": ["Phone", "Email", "Chat", "Social Media"], "sla": "24-hour response time"}'),
('IT', 'Port Harcourt Support Office', '{"budget": "\u20a661M", "projects": ["Cybersecurity Upgrade", "ERP Implementation", "E-commerce Platform", "Data Migration"], "tech_stack": ["Node.js", "Azure", "AWS", "React", "Angular"]}'),
('Operations 2', 'Lagos Logistics Hub', '{"budget": "\u20a642M", "facilities": ["Main Warehouse", "Regional Distribution Centers", "Quality Assurance", "Fleet Management"], "coverage": "National"}'),
('IT 2', 'Abuja Data Center', '{"budget": "\u20a695M", "projects": ["Network Infrastructure", "ERP Implementation"], "tech_stack": ["Node.js", "MySQL", "Python"]}'),
('Operations 3', 'Kano Distribution Center', '{"budget": "\u20a658M", "facilities": ["Main Warehouse", "Inventory Control"], "coverage": "National"}'),
('Sales', 'Kano Regional Office', '{"budget": "\u20a6125M", "target_market": "Nigeria", "sales_quota": "\u20a691M/month"}'),
('Customer Service 4', 'Abuja Helpdesk', '{"budget": "\u20a620M", "channels": ["Phone", "Email", "Chat", "Social Media"], "sla": "24-hour response time"}'),
('IT 3', 'Lagos Tech Hub', '{"budget": "\u20a664M", "projects": ["Data Migration", "E-commerce Platform"], "tech_stack": ["Angular", "Java", "Docker", "Node.js", "MongoDB"]}'),
('Finance', 'Abuja Regional Office', '{"budget": "\u20a6454M", "responsibilities": ["Accounts Payable", "Accounts Receivable", "Payroll", "Financial Reporting", "Tax Compliance", "Auditing"], "reporting_frequency": "Monthly"}'),
('Finance 2', 'Abuja Regional Office', '{"budget": "\u20a6154M", "responsibilities": ["Accounts Payable", "Accounts Receivable", "Payroll", "Financial Reporting", "Tax Compliance", "Auditing"], "reporting_frequency": "Monthly"}');


INSERT INTO products (product_name, price, category, stock_quantity, attributes)
VALUES
('Decorative Vase', 96.91, 'Home & Garden', 644, '{"assembly_required": true, "weight_capacity": "227kg"}'),
('Eco-Friendly Perfume', 313.19, 'Beauty', 364, '{"skin_type": "Dry", "volume": "366ml", "fragrance": "Unscented"}'),
('Shorts', 6.0, 'Fashion', 66, '{"size": "S", "color": "black", "material": "Polyester"}'),
('Face Serum', 840.52, 'Beauty', 829, '{"organic": true, "cruelty_free": true}'),
('Advanced Flip Flops', 29.54, 'Footwear', 350, '{"size": "46", "color": "Blue", "material": "Synthetic"}'),
('Wireless Headphones', 92.06, 'Electronics', 149, '{"color": "White", "battery_life": "25h", "weight": "421g"}'),
('Coffee Table', 32.61, 'Home & Garden', 533, '{"dimensions": "174x150cm", "color": "black", "material": "Ceramic"}'),
('History Book', 274.15, 'Books', 228, '{"format": "Hardcover", "ISBN": "978-1-02-061880-2", "genre": "Non-Fiction"}'),
('Luxury Skirt', 93.06, 'Fashion', 578, '{"size": "S", "color": "olive", "material": "Cotton"}'),
('Wireless T-Shirt', 129.11, 'Fashion', 141, '{"size": "L", "color": "black", "material": "Silk"}'),
('Running Shoes', 41.67, 'Footwear', 181, '{"closure": "Slip-on", "sole_material": "Rubber", "waterproof": false}'),
('Luxury Formal Oxfords', 586.56, 'Footwear', 86, '{"size": "44", "color": "White", "material": "Leather"}'),
('Flip Flops', 227.32, 'Footwear', 612, '{"closure": "Velcro", "sole_material": "PU", "waterproof": true}'),
('Flip Flops', 479.72, 'Footwear', 269, '{"size": "46", "color": "Red", "material": "Leather"}'),
('Children"s Book', 110.85, 'Books', 134, '{"format": "e-Book", "ISBN": "978-1-63187-880-0", "genre": "Non-Fiction"}'),
('Hair Conditioner', 395.6, 'Beauty', 66, '{"skin_type": "All", "volume": "176ml", "fragrance": "Unscented"}'),
('Fitness Tracker', 88.55, 'Electronics', 828, '{"RAM": "32GB", "storage": "128GB SSD", "screen_size": "15.6 inch"}'),
('Smart Basketball Shoes', 40.28, 'Footwear', 770, '{"closure": "Slip-on", "sole_material": "EVA", "waterproof": false}'),
('Moisturizer', 307.18, 'Beauty', 254, '{"skin_type": "Dry", "volume": "354ml", "fragrance": "Woody"}'),
('Lipstick', 370.67, 'Beauty', 272, '{"skin_type": "Oily", "volume": "494ml", "fragrance": "Woody"}'),
('Basketball Shoes', 546.08, 'Footwear', 197, '{"size": "38", "color": "Black", "material": "Mesh"}'),
('Lipstick', 541.49, 'Beauty', 895, '{"skin_type": "Sensitive", "volume": "101ml", "fragrance": "Unscented"}'),
('Portable Speaker', 240.99, 'Electronics', 50, '{"color": "Blue", "battery_life": "30h", "weight": "681g"}'),
('Business Strategy', 33.19, 'Books', 304, '{"author": "Ronald Contreras", "pages": 297, "publisher": "Fernandez Inc", "language": "English"}'),
('Smart Summer Dress', 24.93, 'Fashion', 770, '{"care_instructions": "Dry Clean Only", "style": "Casual"}'),
('Wireless Gaming Mouse', 131.74, 'Electronics', 622, '{"RAM": "32GB", "storage": "256GB SSD", "screen_size": "13.3 inch"}'),
('Perfume', 348.97, 'Beauty', 393, '{"organic": false, "cruelty_free": true}'),
('Advanced Business Strategy', 16.9, 'Books', 706, '{"format": "Hardcover", "ISBN": "978-0-650-84806-1", "genre": "Non-Fiction"}'),
('Science Fiction Novel', 12.37, 'Books', 848, '{"format": "Paperback", "ISBN": "978-0-654-67781-0", "genre": "Non-Fiction"}'),
('Wireless Headphones', 95.41, 'Electronics', 602, '{"color": "White", "battery_life": "10h", "weight": "537g"}'),
('Cookbook', 56.62, 'Books', 70, '{"author": "Donna Bishop", "pages": 483, "publisher": "Hamilton, Guerra and Price", "language": "English"}'),
('Basketball Shoes', 108.16, 'Footwear', 989, '{"size": "36", "color": "Blue", "material": "Canvas"}'),
('Premium Makeup Kit', 1666.21, 'Beauty', 513, '{"skin_type": "Oily", "volume": "188ml", "fragrance": "Citrus"}'),
('Business Strategy', 65.42, 'Books', 45, '{"format": "Paperback", "ISBN": "978-1-4464-2957-0", "genre": "Non-Fiction"}'),
('Portable Speaker', 82.56, 'Electronics', 390, '{"resolution": "FHD", "connectivity": "USB-C", "processor": "AMD Ryzen 7"}'),
('Cookbook', 2.43, 'Books', 101, '{"format": "e-Book", "ISBN": "978-0-02-051871-6", "genre": "Fiction"}'),
('Storage Cabinet', 57.75, 'Home & Garden', 178, '{"dimensions": "183x168cm", "color": "blue", "material": "Wood"}'),
('Mechanical Keyboard', 1656.32, 'Electronics', 909, '{"resolution": "FHD", "connectivity": "Bluetooth 5.0", "processor": "Intel i5"}'),
('Cookware Set', 477.43, 'Home & Garden', 464, '{"dimensions": "194x28cm", "color": "teal", "material": "Metal"}'),
('Wireless Business Strategy', 440.21, 'Books', 202, '{"author": "Derek Leblanc", "pages": 721, "publisher": "Murphy LLC", "language": "English"}'),
('Pro Children"s Book', 346.67, 'Books', 431, '{"format": "Paperback", "ISBN": "978-1-05-443782-0", "genre": "Fiction"}'),
('Smart Bluetooth Earbuds', 99.93, 'Electronics', 919, '{"resolution": "4K", "connectivity": "Wi-Fi 6", "processor": "AMD Ryzen 7"}'),
('Eco-Friendly Cookbook', 78.67, 'Books', 449, '{"author": "James Barnes", "pages": 373, "publisher": "Cobb-Bauer", "language": "English"}'),
('Pro Makeup Kit', 3.47, 'Beauty', 202, '{"skin_type": "Dry", "volume": "203ml", "fragrance": "Floral"}'),
('Pro Sweater', 118.92, 'Fashion', 503, '{"size": "S", "color": "yellow", "material": "Wool"}'),
('Programming Textbook', 856.14, 'Books', 825, '{"format": "e-Book", "ISBN": "978-1-341-01356-0", "genre": "Fiction"}'),
('Programming Textbook', 393.69, 'Books', 259, '{"author": "Melody Cooley", "pages": 443, "publisher": "Keith-Salas", "language": "English"}'),
('Eco-Friendly Sweater', 98.47, 'Fashion', 136, '{"size": "L", "color": "green", "material": "Cotton"}'),
('Portable Speaker', 3.64, 'Electronics', 500, '{"color": "Blue", "battery_life": "17h", "weight": "273g"}'),
('Basketball Shoes', 843.49, 'Footwear', 141, '{"closure": "Velcro", "sole_material": "Rubber", "waterproof": false}'),
('Mechanical Keyboard', 186.11, 'Electronics', 71, '{"RAM": "4GB", "storage": "128GB SSD", "screen_size": "13.3 inch"}'),
('T-Shirt', 869.18, 'Fashion', 252, '{"care_instructions": "Dry Clean Only", "style": "Casual"}'),
('Sandals', 80.14, 'Footwear', 963, '{"closure": "Lace-up", "sole_material": "EVA", "waterproof": false}'),
('Luxury Tablet', 83.94, 'Electronics', 266, '{"resolution": "HD", "connectivity": "USB-C", "processor": "Apple M1"}'),
('Makeup Kit', 91.36, 'Beauty', 596, '{"organic": true, "cruelty_free": true}'),
('Premium Moisturizer', 8.56, 'Beauty', 153, '{"organic": true, "cruelty_free": true}'),
('Advanced Summer Dress', 57.65, 'Fashion', 767, '{"size": "M", "color": "blue", "material": "Silk"}'),
('Running Shoes', 947.76, 'Footwear', 360, '{"closure": "Lace-up", "sole_material": "PU", "waterproof": true}'),
('Advanced Cookbook', 14.84, 'Books', 925, '{"format": "e-Book", "ISBN": "978-1-81253-843-1", "genre": "Non-Fiction"}'),
('Bluetooth Earbuds', 643.19, 'Electronics', 785, '{"RAM": "8GB", "storage": "128GB SSD", "screen_size": "17.3 inch"}'),
('Wall Clock', 72.33, 'Home & Garden', 482, '{"dimensions": "193x14cm", "color": "navy", "material": "Metal"}'),
('Science Fiction Novel', 56.91, 'Books', 22, '{"author": "Amy Duncan", "pages": 416, "publisher": "Ellis-Bishop", "language": "English"}'),
('Lipstick', 26.64, 'Beauty', 221, '{"organic": false, "cruelty_free": false}'),
('Cookware Set', 699.64, 'Home & Garden', 177, '{"assembly_required": true, "weight_capacity": "41kg"}'),
('Smart Formal Oxfords', 903.99, 'Footwear', 347, '{"closure": "Velcro", "sole_material": "PU", "waterproof": false}'),
('Lipstick', 479.72, 'Beauty', 346, '{"organic": false, "cruelty_free": true}'),
('Eco-Friendly Self-Help Guide', 724.6, 'Books', 488, '{"author": "Miss Kristen Salinas", "pages": 242, "publisher": "Beltran-Dean", "language": "English"}'),
('Smart Makeup Kit', 94.63, 'Beauty', 196, '{"skin_type": "Sensitive", "volume": "222ml", "fragrance": "Floral"}'),
('Cookbook', 13.89, 'Books', 51, '{"format": "e-Book", "ISBN": "978-1-06-859732-9", "genre": "Fiction"}'),
('Science Fiction Novel', 68.31, 'Books', 106, '{"author": "Wendy Smith", "pages": 773, "publisher": "Jacobson Group", "language": "English"}'),
('Dress Shoes', 160.25, 'Footwear', 442, '{"size": "39", "color": "Blue", "material": "Canvas"}'),
('Eco-Friendly Smart Watch', 18.76, 'Electronics', 840, '{"RAM": "8GB", "storage": "1000GB SSD", "screen_size": "15.6 inch"}'),
('Pro Business Strategy', 465.92, 'Books', 226, '{"format": "e-Book", "ISBN": "978-1-362-95014-1", "genre": "Non-Fiction"}'),
('Face Serum', 922.53, 'Beauty', 656, '{"organic": true, "cruelty_free": false}'),
('Sunscreen', 159.5, 'Beauty', 478, '{"skin_type": "Dry", "volume": "484ml", "fragrance": "Floral"}'),
('Portable Speaker', 75.59, 'Electronics', 771, '{"resolution": "HD", "connectivity": "Wi-Fi 6", "processor": "Apple M1"}'),
('Self-Help Guide', 32.74, 'Books', 390, '{"format": "Hardcover", "ISBN": "978-0-582-45527-6", "genre": "Non-Fiction"}'),
('Premium T-Shirt', 1769.68, 'Fashion', 332, '{"size": "XL", "color": "purple", "material": "Polyester"}'),
('Sunscreen', 152.3, 'Beauty', 579, '{"skin_type": "All", "volume": "150ml", "fragrance": "Floral"}'),
('Advanced Perfume', 11.03, 'Beauty', 343, '{"organic": true, "cruelty_free": false}'),
('Smart Children"s Book', 84.78, 'Books', 439, '{"format": "Hardcover", "ISBN": "978-0-576-93168-7", "genre": "Fiction"}'),
('External SSD', 773.15, 'Electronics', 207, '{"color": "Silver", "battery_life": "9h", "weight": "383g"}'),
('Casual Sneakers', 638.11, 'Footwear', 874, '{"size": "43", "color": "Blue", "material": "Leather"}'),
('Business Strategy', 153.85, 'Books', 173, '{"author": "Timothy Petersen", "pages": 749, "publisher": "Hernandez-Mercado", "language": "English"}'),
('Desk Lamp', 71.75, 'Home & Garden', 732, '{"dimensions": "152x11cm", "color": "fuchsia", "material": "Wood"}'),
('Body Lotion', 848.87, 'Beauty', 399, '{"organic": false, "cruelty_free": true}'),
('Luxury Sandals', 7.71, 'Footwear', 281, '{"closure": "Lace-up", "sole_material": "PU", "waterproof": false}'),
('Luxury Makeup Kit', 37.15, 'Beauty', 283, '{"skin_type": "Oily", "volume": "261ml", "fragrance": "Citrus"}'),
('Body Lotion', 176.56, 'Beauty', 777, '{"organic": false, "cruelty_free": true}'),
('History Book', 12.94, 'Books', 153, '{"author": "Jason Simpson", "pages": 476, "publisher": "Vega-Carter", "language": "English"}'),
('Eco-Friendly Perfume', 47.69, 'Beauty', 349, '{"skin_type": "Dry", "volume": "264ml", "fragrance": "Unscented"}'),
('Makeup Kit', 10.67, 'Beauty', 287, '{"organic": true, "cruelty_free": true}'),
('Tool Kit', 983.42, 'Home & Garden', 275, '{"dimensions": "51x14cm", "color": "purple", "material": "Ceramic"}'),
('Tool Kit', 65.51, 'Home & Garden', 355, '{"dimensions": "20x36cm", "color": "white", "material": "Metal"}'),
('Pro Moisturizer', 50.32, 'Beauty', 501, '{"skin_type": "All", "volume": "208ml", "fragrance": "Floral"}'),
('Coffee Table', 750.12, 'Home & Garden', 330, '{"assembly_required": false, "weight_capacity": "221kg"}'),
('Skirt', 939.92, 'Fashion', 228, '{"size": "M", "color": "aqua", "material": "Polyester"}'),
('Smart E-Reader', 62.37, 'Electronics', 704, '{"RAM": "32GB", "storage": "128GB HDD", "screen_size": "13.3 inch"}'),
('Lipstick', 63.01, 'Beauty', 125, '{"skin_type": "Dry", "volume": "117ml", "fragrance": "Floral"}'),
('Shampoo', 106.05, 'Beauty', 791, '{"skin_type": "Dry", "volume": "182ml", "fragrance": "Floral"}'),
('Sunscreen', 168.72, 'Beauty', 396, '{"skin_type": "Sensitive", "volume": "379ml", "fragrance": "Woody"}'),
('Smart Cookbook', 44.84, 'Books', 886, '{"author": "Michael Herman", "pages": 507, "publisher": "Mcmahon, Maldonado and Skinner", "language": "English"}'),
('Makeup Kit', 45.9, 'Beauty', 88, '{"skin_type": "Oily", "volume": "244ml", "fragrance": "Unscented"}'),
('Poetry Collection', 275.82, 'Books', 324, '{"author": "Amber Smith", "pages": 561, "publisher": "Garcia LLC", "language": "English"}'),
('Eco-Friendly Mechanical Keyboard', 60.79, 'Electronics', 206, '{"resolution": "4K", "connectivity": "Bluetooth 5.0", "processor": "Intel i5"}'),
('Advanced Wireless Headphones', 19.97, 'Electronics', 851, '{"color": "Silver", "battery_life": "19h", "weight": "328g"}'),
('History Book', 46.04, 'Books', 432, '{"format": "Paperback", "ISBN": "978-1-56442-834-9", "genre": "Fiction"}'),
('T-Shirt', 40.18, 'Fashion', 547, '{"care_instructions": "Machine Wash", "style": "Modern"}'),
('Cookbook', 53.42, 'Books', 940, '{"author": "Leah Riley", "pages": 625, "publisher": "Grant, Garner and Tran", "language": "English"}'),
('Advanced Shampoo', 502.21, 'Beauty', 307, '{"organic": true, "cruelty_free": true}'),
('Basketball Shoes', 65.76, 'Footwear', 565, '{"closure": "Lace-up", "sole_material": "EVA", "waterproof": false}'),
('Mechanical Keyboard', 591.37, 'Electronics', 561, '{"color": "White", "battery_life": "35h", "weight": "963g"}'),
('Decorative Vase', 77.79, 'Home & Garden', 900, '{"dimensions": "120x50cm", "color": "silver", "material": "Ceramic"}'),
('T-Shirt', 70.32, 'Fashion', 52, '{"care_instructions": "Dry Clean Only", "style": "Formal"}'),
('External SSD', 68.58, 'Electronics', 129, '{"color": "Silver", "battery_life": "14h", "weight": "407g"}'),
('Luxury Sweater', 237.87, 'Fashion', 896, '{"care_instructions": "Machine Wash", "style": "Casual"}'),
('Sunscreen', 795.59, 'Beauty', 532, '{"skin_type": "Oily", "volume": "434ml", "fragrance": "Floral"}'),
('Bluetooth Earbuds', 79.24, 'Electronics', 431, '{"resolution": "4K", "connectivity": "Bluetooth 5.0", "processor": "AMD Ryzen 7"}'),
('Body Lotion', 82.32, 'Beauty', 112, '{"organic": false, "cruelty_free": false}'),
('Eco-Friendly T-Shirt', 385.58, 'Fashion', 121, '{"size": "M", "color": "white", "material": "Cotton"}'),
('Fitness Tracker', 60.86, 'Electronics', 82, '{"RAM": "32GB", "storage": "128GB HDD", "screen_size": "13.3 inch"}'),
('Cookbook', 422.3, 'Books', 462, '{"format": "Paperback", "ISBN": "978-0-7443-6417-0", "genre": "Fiction"}'),
('Pro Cookware Set', 87.97, 'Home & Garden', 35, '{"dimensions": "120x32cm", "color": "olive", "material": "Plastic"}'),
('Garden Chair', 8.63, 'Home & Garden', 893, '{"assembly_required": true, "weight_capacity": "367kg"}'),
('Flip Flops', 408.51, 'Footwear', 141, '{"size": "36", "color": "Blue", "material": "Leather"}'),
('Wall Clock', 15.8, 'Home & Garden', 451, '{"dimensions": "133x23cm", "color": "olive", "material": "Ceramic"}'),
('Mechanical Keyboard', 78.81, 'Electronics', 405, '{"color": "White", "battery_life": "42h", "weight": "91g"}'),
('Shorts', 361.67, 'Fashion', 262, '{"care_instructions": "Dry Clean Only", "style": "Formal"}'),
('Makeup Kit', 749.89, 'Beauty', 522, '{"organic": true, "cruelty_free": false}'),
('Portable Speaker', 574.61, 'Electronics', 508, '{"color": "Black", "battery_life": "7h", "weight": "99g"}'),
('Wireless Wireless Headphones', 29.78, 'Electronics', 470, '{"resolution": "FHD", "connectivity": "USB-C", "processor": "AMD Ryzen 7"}'),
('Dress Shirt', 362.26, 'Fashion', 306, '{"care_instructions": "Dry Clean Only", "style": "Vintage"}'),
('Smart Casual Sneakers', 123.07, 'Footwear', 125, '{"size": "45", "color": "White", "material": "Mesh"}'),
('Premium Dress Shirt', 17.99, 'Fashion', 664, '{"care_instructions": "Dry Clean Only", "style": "Vintage"}'),
('Wireless T-Shirt', 143.88, 'Fashion', 370, '{"size": "S", "color": "yellow", "material": "Wool"}'),
('Bluetooth Earbuds', 420.65, 'Electronics', 141, '{"resolution": "FHD", "connectivity": "Bluetooth 5.0", "processor": "AMD Ryzen 7"}'),
('Advanced Cookbook', 66.94, 'Books', 299, '{"author": "Tammy Mitchell", "pages": 517, "publisher": "Andersen-Daniels", "language": "English"}'),
('Sandals', 378.2, 'Footwear', 37, '{"size": "48", "color": "Red", "material": "Synthetic"}'),
('Advanced Business Strategy', 459.54, 'Books', 388, '{"format": "e-Book", "ISBN": "978-1-84399-239-4", "genre": "Fiction"}'),
('Pro Jacket', 6.08, 'Fashion', 507, '{"care_instructions": "Machine Wash", "style": "Modern"}'),
('Bedding Set', 116.68, 'Home & Garden', 247, '{"assembly_required": true, "weight_capacity": "175kg"}'),
('Tablet', 142.7, 'Electronics', 404, '{"resolution": "FHD", "connectivity": "Bluetooth 5.0", "processor": "Intel i5"}'),
('Smart Gaming Mouse', 486.63, 'Electronics', 751, '{"RAM": "32GB", "storage": "1000GB SSD", "screen_size": "13.3 inch"}'),
('Premium Hiking Boots', 30.04, 'Footwear', 90, '{"closure": "Velcro", "sole_material": "EVA", "waterproof": true}'),
('Casual Sneakers', 941.48, 'Footwear', 182, '{"closure": "Velcro", "sole_material": "Rubber", "waterproof": false}'),
('Shampoo', 346.48, 'Beauty', 20, '{"organic": true, "cruelty_free": true}'),
('Biography', 414.57, 'Books', 871, '{"format": "Hardcover", "ISBN": "978-1-316-24442-5", "genre": "Non-Fiction"}'),
('Bedding Set', 726.1, 'Home & Garden', 55, '{"dimensions": "109x191cm", "color": "teal", "material": "Ceramic"}'),
('Blazer', 239.05, 'Fashion', 235, '{"care_instructions": "Machine Wash", "style": "Casual"}'),
('Wireless Moisturizer', 597.79, 'Beauty', 752, '{"organic": true, "cruelty_free": true}'),
('Decorative Vase', 414.63, 'Home & Garden', 230, '{"assembly_required": false, "weight_capacity": "401kg"}'),
('Eco-Friendly T-Shirt', 21.43, 'Fashion', 569, '{"size": "M", "color": "gray", "material": "Silk"}'),
('Sunscreen', 408.3, 'Beauty', 956, '{"organic": true, "cruelty_free": false}'),
('Lipstick', 19.95, 'Beauty', 262, '{"organic": false, "cruelty_free": false}'),
('Smart Tool Kit', 480.44, 'Home & Garden', 760, '{"dimensions": "163x73cm", "color": "lime", "material": "Metal"}'),
('Flip Flops', 13.7, 'Footwear', 179, '{"size": "41", "color": "White", "material": "Mesh"}'),
('Wireless Headphones', 776.65, 'Electronics', 329, '{"resolution": "HD", "connectivity": "USB-C", "processor": "Apple M1"}'),
('Blazer', 52.65, 'Fashion', 123, '{"care_instructions": "Dry Clean Only", "style": "Vintage"}'),
('Science Fiction Novel', 85.36, 'Books', 70, '{"format": "e-Book", "ISBN": "978-0-252-46596-3", "genre": "Fiction"}'),
('Skirt', 547.1, 'Fashion', 53, '{"care_instructions": "Dry Clean Only", "style": "Vintage"}'),
('Eco-Friendly Sunscreen', 1561.6, 'Beauty', 199, '{"organic": true, "cruelty_free": true}'),
('Eco-Friendly Body Lotion', 223.54, 'Beauty', 83, '{"skin_type": "Oily", "volume": "406ml", "fragrance": "Floral"}'),
('Wall Clock', 61.3, 'Home & Garden', 361, '{"dimensions": "183x138cm", "color": "black", "material": "Plastic"}'),
('Premium Sunscreen', 46.82, 'Beauty', 172, '{"organic": true, "cruelty_free": true}'),
('Training Shoes', 150.17, 'Footwear', 253, '{"size": "38", "color": "Red", "material": "Leather"}'),
('Smart Watch', 451.29, 'Electronics', 639, '{"RAM": "32GB", "storage": "1000GB HDD", "screen_size": "15.6 inch"}'),
('Poetry Collection', 555.39, 'Books', 917, '{"format": "Paperback", "ISBN": "978-0-7112-3248-8", "genre": "Fiction"}'),
('Advanced Sunscreen', 565.55, 'Beauty', 265, '{"organic": false, "cruelty_free": true}'),
('Sandals', 88.11, 'Footwear', 63, '{"closure": "Slip-on", "sole_material": "PU", "waterproof": true}'),
('Children"s Book', 33.75, 'Books', 377, '{"author": "Dawn Russell", "pages": 725, "publisher": "Ward PLC", "language": "English"}'),
('Advanced Jacket', 499.38, 'Fashion', 300, '{"care_instructions": "Dry Clean Only", "style": "Vintage"}'),
('Tablet', 23.95, 'Electronics', 866, '{"resolution": "HD", "connectivity": "Wi-Fi 6", "processor": "Apple M1"}'),
('Bluetooth Earbuds', 16.99, 'Electronics', 138, '{"resolution": "FHD", "connectivity": "Wi-Fi 6", "processor": "Apple M1"}'),
('Sweater', 235.85, 'Fashion', 445, '{"size": "S", "color": "olive", "material": "Cotton"}'),
('Advanced Tablet', 941.21, 'Electronics', 109, '{"color": "Blue", "battery_life": "24h", "weight": "968g"}'),
('Self-Help Guide', 566.71, 'Books', 369, '{"author": "Todd Klein", "pages": 239, "publisher": "Hunter-Gordon", "language": "English"}'),
('Moisturizer', 14.19, 'Beauty', 63, '{"skin_type": "Dry", "volume": "356ml", "fragrance": "Citrus"}'),
('Jeans', 32.27, 'Fashion', 322, '{"care_instructions": "Dry Clean Only", "style": "Formal"}'),
('Luxury Storage Cabinet', 458.75, 'Home & Garden', 306, '{"dimensions": "18x119cm", "color": "yellow", "material": "Wood"}'),
('Desk Lamp', 18.17, 'Home & Garden', 972, '{"dimensions": "180x54cm", "color": "fuchsia", "material": "Plastic"}'),
('Business Strategy', 96.81, 'Books', 46, '{"format": "Hardcover", "ISBN": "978-1-238-79204-2", "genre": "Non-Fiction"}'),
('Premium Dress Shirt', 835.76, 'Fashion', 554, '{"care_instructions": "Dry Clean Only", "style": "Modern"}'),
('Bedding Set', 776.78, 'Home & Garden', 19, '{"assembly_required": true, "weight_capacity": "217kg"}'),
('Moisturizer', 476.33, 'Beauty', 166, '{"organic": true, "cruelty_free": true}'),
('Casual Sneakers', 81.15, 'Footwear', 28, '{"closure": "Lace-up", "sole_material": "PU", "waterproof": false}'),
('Portable Speaker', 48.8, 'Electronics', 711, '{"resolution": "4K", "connectivity": "Bluetooth 5.0", "processor": "Apple M1"}'),
('Hiking Boots', 313.26, 'Footwear', 276, '{"closure": "Lace-up", "sole_material": "EVA", "waterproof": true}'),
('Jacket', 706.25, 'Fashion', 411, '{"size": "XL", "color": "green", "material": "Cotton"}'),
('Cookbook', 921.64, 'Books', 122, '{"author": "David Johnson", "pages": 322, "publisher": "Holmes-Johnson", "language": "English"}'),
('History Book', 367.34, 'Books', 15, '{"format": "Paperback", "ISBN": "978-1-908912-80-0", "genre": "Fiction"}'),
('Eco-Friendly Tool Kit', 23.22, 'Home & Garden', 591, '{"assembly_required": false, "weight_capacity": "443kg"}'),
('Wall Clock', 361.28, 'Home & Garden', 978, '{"dimensions": "184x36cm", "color": "silver", "material": "Wood"}'),
('History Book', 220.96, 'Books', 380, '{"format": "Paperback", "ISBN": "978-1-119-87082-1", "genre": "Fiction"}'),
('Advanced Moisturizer', 687.03, 'Beauty', 197, '{"skin_type": "Oily", "volume": "44ml", "fragrance": "Unscented"}'),
('Desk Lamp', 78.41, 'Home & Garden', 257, '{"assembly_required": true, "weight_capacity": "133kg"}'),
('Advanced Jacket', 19.45, 'Fashion', 520, '{"size": "M", "color": "maroon", "material": "Silk"}'),
('Running Shoes', 96.8, 'Footwear', 89, '{"closure": "Lace-up", "sole_material": "PU", "waterproof": true}'),
('Smart Bluetooth Earbuds', 88.72, 'Electronics', 411, '{"RAM": "4GB", "storage": "256GB HDD", "screen_size": "15.6 inch"}'),
('Programming Textbook', 83.83, 'Books', 724, '{"author": "Tracy Walker", "pages": 480, "publisher": "Rivera, Hodge and Maldonado", "language": "English"}'),
('Self-Help Guide', 43.22, 'Books', 247, '{"author": "Heather Macdonald", "pages": 511, "publisher": "Jones, Wade and Santiago", "language": "English"}');




INSERT INTO employees (name, department_id, manager_id, role, hire_date, salary, contact_info, skills)
VALUES
('Nneka Okoh', 1, NULL, 'Sales Manager', '2019-08-02', 7601.57, '{"email": "nneka.okoh407@company.com", "phone": "+2348072864440"}', '{"sales_skills": ["Key Account Management", "Sales Forecasting"], "soft_skills": ["Leadership", "Decision Making"]}'),
('Amara Okoh', 1, NULL, 'Head of Sales', '2017-03-25', 9277.94, '{"email": "amara.okoh43@company.com", "phone": "+2348040204024"}', '{"sales_skills": ["Strategic Planning"], "soft_skills": ["Presentation", "Negotiation", "Leadership"]}'),
('Oluwaseun Sule', 1, NULL, 'Head of Sales', '2019-09-05', 5035.54, '{"email": "oluwaseun.sule265@company.com", "phone": "+2348087722972"}', '{"sales_skills": ["Sales Forecasting", "CRM Systems"], "soft_skills": ["Decision Making", "Negotiation", "Presentation"]}'),
('Tunde Uche', 1, 3, 'Sales Representative', '2019-01-30', 3859.38, '{"email": "tunde.uche827@company.com", "phone": "+2348086950768"}', '{"sales_skills": ["Product Knowledge"], "soft_skills": ["Persuasion", "Communication"]}'),
('Oluwaseun Aliyu', 1, 1, 'Sales Associate', '2019-04-23', 3994.36, '{"email": "oluwaseun.aliyu231@company.com", "phone": "+2348095045724"}', '{"sales_skills": ["Customer Engagement", "Product Knowledge", "Sales Presentations"], "soft_skills": ["Communication", "Resilience", "Active Listening"]}'),
('Chioma Ibrahim', 1, 2, 'Sales Associate', '2023-11-30', 2259.63, '{"email": "chioma.ibrahim529@company.com", "phone": "+2348081141336"}', '{"sales_skills": ["Prospecting", "Customer Engagement", "Product Knowledge"], "soft_skills": ["Active Listening", "Resilience"]}'),
('Femi Onyeama', 1, 3, 'Sales Associate', '2023-12-16', 4853.46, '{"email": "femi.onyeama501@company.com", "phone": "+2348067646360"}', '{"sales_skills": ["Product Knowledge"], "soft_skills": ["Active Listening"]}'),
('Emeka Ojo', 1, 2, 'Business Development', '2018-05-06', 3565.62, '{"email": "emeka.ojo101@company.com", "phone": "+2348071035553"}', '{"sales_skills": ["Prospecting", "Sales Presentations", "Product Knowledge"], "soft_skills": ["Resilience"]}'),
('Amara Adeyemi', 1, 2, 'Sales Representative', '2020-02-09', 3815.87, '{"email": "amara.adeyemi343@company.com", "phone": "+2348074659611"}', '{"sales_skills": ["Customer Engagement"], "soft_skills": ["Persuasion", "Communication"]}'),
('Zainab Chukwu', 1, 2, 'Business Development', '2019-10-04', 4061.88, '{"email": "zainab.chukwu578@company.com", "phone": "+2348050558029"}', '{"sales_skills": ["Customer Engagement", "Sales Presentations", "Prospecting"], "soft_skills": ["Persuasion", "Communication", "Resilience"]}'),
('Tunde Nwosu', 1, 3, 'Business Development', '2018-09-14', 2626.14, '{"email": "tunde.nwosu738@company.com", "phone": "+2348085240278"}', '{"sales_skills": ["Product Knowledge", "Prospecting"], "soft_skills": ["Communication", "Persuasion"]}'),
('Ebere Ogunleye', 1, 3, 'Account Executive', '2018-02-22', 4311.26, '{"email": "ebere.ogunleye244@company.com", "phone": "+2348018016620"}', '{"sales_skills": ["Customer Engagement", "Product Knowledge"], "soft_skills": ["Communication", "Resilience"]}'),
('Yewande Sule', 1, 2, 'Account Executive', '2024-06-29', 4383.98, '{"email": "yewande.sule582@company.com", "phone": "+2348055548640"}', '{"sales_skills": ["Customer Engagement"], "soft_skills": ["Active Listening", "Communication", "Persuasion"]}'),
('Musa Balogun', 1, 1, 'Account Executive', '2020-09-21', 4180.92, '{"email": "musa.balogun727@company.com", "phone": "+2348072737057"}', '{"sales_skills": ["Sales Presentations", "Product Knowledge"], "soft_skills": ["Resilience", "Persuasion"]}'),
('Adanna Ogbonna', 1, 2, 'Sales Representative', '2025-03-28', 3038.62, '{"email": "adanna.ogbonna297@company.com", "phone": "+2348090909062"}', '{"sales_skills": ["Customer Engagement"], "soft_skills": ["Resilience", "Persuasion"]}'),
('Chioma Alade', 1, 2, 'Account Executive', '2023-11-10', 4509.51, '{"email": "chioma.alade760@company.com", "phone": "+2348003011666"}', '{"sales_skills": ["Prospecting", "Sales Presentations", "Customer Engagement"], "soft_skills": ["Communication"]}'),
('Jide Ojo', 1, 3, 'Sales Associate', '2022-09-18', 3267.2, '{"email": "jide.ojo758@company.com", "phone": "+2348022299220"}', '{"sales_skills": ["Prospecting"], "soft_skills": ["Communication"]}'),
('Deborah Okoro', 1, 2, 'Sales Associate', '2020-06-25', 2861.39, '{"email": "deborah.okoro290@company.com", "phone": "+2348064576738"}', '{"sales_skills": ["Customer Engagement", "Prospecting", "Sales Presentations"], "soft_skills": ["Communication", "Active Listening", "Resilience"]}'),
('Musa Mohammed', 1, 2, 'Sales Representative', '2020-07-09', 2596.47, '{"email": "musa.mohammed932@company.com", "phone": "+2348026196856"}', '{"sales_skills": ["Sales Presentations", "Product Knowledge"], "soft_skills": ["Active Listening", "Persuasion", "Communication"]}'),
('Emeka Adeyemi', 1, 3, 'Sales Associate', '2025-02-09', 3728.44, '{"email": "emeka.adeyemi803@company.com", "phone": "+2348040942335"}', '{"sales_skills": ["Product Knowledge"], "soft_skills": ["Active Listening", "Communication", "Resilience"]}'),
('Tunde Akinwande', 1, 1, 'Business Development', '2024-10-04', 4299.34, '{"email": "tunde.akinwande161@company.com", "phone": "+2348010081882"}', '{"sales_skills": ["Customer Engagement", "Sales Presentations", "Product Knowledge"], "soft_skills": ["Communication", "Persuasion", "Resilience"]}'),
('Ifeoma Bakare', 1, 3, 'Sales Associate', '2024-07-10', 1992.69, '{"email": "ifeoma.bakare420@company.com", "phone": "+2348047469213"}', '{"sales_skills": ["Prospecting", "Product Knowledge"], "soft_skills": ["Persuasion"]}'),
('Funke Onyema', 1, 1, 'Sales Associate', '2022-05-06', 4490.76, '{"email": "funke.onyema732@company.com", "phone": "+2348089119252"}', '{"sales_skills": ["Sales Presentations"], "soft_skills": ["Resilience", "Communication", "Active Listening"]}'),
('Sani Ogbonna', 1, 2, 'Sales Associate', '2021-05-25', 3337.48, '{"email": "sani.ogbonna69@company.com", "phone": "+2348062416480"}', '{"sales_skills": ["Customer Engagement", "Product Knowledge"], "soft_skills": ["Communication"]}'),
('Amina Aliyu', 1, 1, 'Sales Representative', '2020-08-25', 3619.39, '{"email": "amina.aliyu485@company.com", "phone": "+2348072631903"}', '{"sales_skills": ["Sales Presentations", "Product Knowledge"], "soft_skills": ["Active Listening"]}'),
('Ebere Onyeama', 1, 2, 'Sales Representative', '2022-01-29', 3983.63, '{"email": "ebere.onyeama378@company.com", "phone": "+2348039226892"}', '{"sales_skills": ["Sales Presentations", "Product Knowledge", "Prospecting"], "soft_skills": ["Persuasion", "Communication"]}'),
('Jide Balogun', 1, 2, 'Sales Associate', '2022-11-20', 4975.59, '{"email": "jide.balogun980@company.com", "phone": "+2348064058267"}', '{"sales_skills": ["Product Knowledge", "Sales Presentations"], "soft_skills": ["Active Listening", "Persuasion", "Resilience"]}'),
('Sani Umar', 1, 1, 'Account Executive', '2019-04-26', 2459.71, '{"email": "sani.umar707@company.com", "phone": "+2348033316584"}', '{"sales_skills": ["Customer Engagement", "Prospecting"], "soft_skills": ["Resilience", "Active Listening", "Communication"]}'),
('Yewande Akintola', 2, NULL, 'DevOps Manager', '2019-09-18', 4253.14, '{"email": "yewande.akintola777@company.com", "phone": "+2348096311373"}', '{"technical_skills": ["Cloud Infrastructure", "DevOps", "System Architecture"], "management_skills": ["Team Leadership"]}'),
('Kunle Mohammed', 2, NULL, 'IT Manager', '2015-07-17', 7502.11, '{"email": "kunle.mohammed74@company.com", "phone": "+2348096575872"}', '{"technical_skills": ["DevOps"], "management_skills": ["Project Management", "Budgeting", "Vendor Management"]}'),
('Deborah Uche', 2, NULL, 'Systems Architect', '2015-01-11', 8778.94, '{"email": "deborah.uche538@company.com", "phone": "+2348003677902"}', '{"technical_skills": ["DevOps"], "management_skills": ["Budgeting"]}'),
('Femi Onyeka', 2, 30, 'IT Support', '2023-02-25', 2774.74, '{"email": "femi.onyeka840@company.com", "phone": "+2348052821552"}', '{"technical_skills": ["Programming", "Troubleshooting", "Database Management"], "certifications": ["CompTIA"]}'),
('Emeka Okafor', 2, 31, 'Software Engineer', '2023-01-31', 2390.28, '{"email": "emeka.okafor820@company.com", "phone": "+2348080685281"}', '{"technical_skills": ["Troubleshooting", "Networking", "Database Management"], "certifications": ["Cisco Certified", "Microsoft Certified"]}'),
('Chiamaka Bello', 2, 30, 'Software Engineer', '2021-11-12', 2326.05, '{"email": "chiamaka.bello355@company.com", "phone": "+2348022297348"}', '{"technical_skills": ["Networking", "Database Management"], "certifications": ["Cisco Certified", "Microsoft Certified", "CompTIA"]}'),
('Amara Onyeka', 2, 30, 'Data Analyst', '2021-04-26', 4266.12, '{"email": "amara.onyeka427@company.com", "phone": "+2348014678513"}', '{"technical_skills": ["Troubleshooting", "Networking"], "certifications": ["AWS Certified", "Cisco Certified"]}'),
('Emeka Adeleke', 2, 31, 'IT Support', '2024-02-11', 3502.7, '{"email": "emeka.adeleke87@company.com", "phone": "+2348046214414"}', '{"technical_skills": ["Programming", "Database Management", "Troubleshooting"], "certifications": ["Microsoft Certified", "Cisco Certified", "AWS Certified"]}'),
('Obinna Ibrahim', 2, 31, 'Software Engineer', '2023-07-01', 3566.63, '{"email": "obinna.ibrahim888@company.com", "phone": "+2348093589473"}', '{"technical_skills": ["Troubleshooting", "Database Management"], "certifications": ["Microsoft Certified", "CompTIA", "AWS Certified"]}'),
('Aisha Alade', 2, 31, 'Network Engineer', '2019-07-01', 3204.16, '{"email": "aisha.alade677@company.com", "phone": "+2348014806674"}', '{"technical_skills": ["Networking", "Database Management", "Programming"], "certifications": ["Microsoft Certified", "Cisco Certified"]}'),
('Chinedu Alade', 2, 30, 'System Admin', '2019-11-08', 2277.38, '{"email": "chinedu.alade917@company.com", "phone": "+2348088833674"}', '{"technical_skills": ["Networking", "Database Management", "Programming"], "certifications": ["Microsoft Certified", "AWS Certified"]}'),
('Zainab Akinwande', 2, 31, 'Data Analyst', '2021-03-05', 3193.59, '{"email": "zainab.akinwande632@company.com", "phone": "+2348066328760"}', '{"technical_skills": ["Troubleshooting", "Database Management"], "certifications": ["AWS Certified"]}'),
('Femi Onyeama', 2, 31, 'IT Support', '2025-05-28', 4057.86, '{"email": "femi.onyeama59@company.com", "phone": "+2348011539999"}', '{"technical_skills": ["Programming", "Networking"], "certifications": ["CompTIA", "Microsoft Certified"]}'),
('Wale Okoh', 2, 31, 'Network Engineer', '2020-08-19', 3144.04, '{"email": "wale.okoh340@company.com", "phone": "+2348074801467"}', '{"technical_skills": ["Networking", "Database Management"], "certifications": ["Cisco Certified"]}'),
('Chinedu Okoro', 2, 31, 'System Admin', '2021-05-18', 3275.61, '{"email": "chinedu.okoro820@company.com", "phone": "+2348094534593"}', '{"technical_skills": ["Troubleshooting", "Database Management"], "certifications": ["AWS Certified", "Microsoft Certified", "Cisco Certified"]}'),
('Femi Bakare', 2, 30, 'Data Analyst', '2020-01-10', 2021.41, '{"email": "femi.bakare159@company.com", "phone": "+2348029253663"}', '{"technical_skills": ["Programming", "Networking", "Troubleshooting"], "certifications": ["AWS Certified"]}'),
('Amina Balogun', 2, 31, 'Software Engineer', '2022-04-21', 2733.29, '{"email": "amina.balogun626@company.com", "phone": "+2348076777063"}', '{"technical_skills": ["Database Management"], "certifications": ["AWS Certified", "Microsoft Certified"]}'),
('Wale Ojo', 2, 31, 'Software Engineer', '2022-03-14', 1933.11, '{"email": "wale.ojo382@company.com", "phone": "+2348000512515"}', '{"technical_skills": ["Troubleshooting", "Database Management"], "certifications": ["AWS Certified", "Microsoft Certified"]}'),
('Obinna Bakare', 2, 29, 'Data Analyst', '2021-12-16', 3989.88, '{"email": "obinna.bakare163@company.com", "phone": "+2348025727335"}', '{"technical_skills": ["Troubleshooting", "Programming", "Database Management"], "certifications": ["CompTIA", "AWS Certified", "Cisco Certified"]}'),
('Tunde Balogun', 2, 30, 'Data Analyst', '2022-10-14', 1915.3, '{"email": "tunde.balogun171@company.com", "phone": "+2348049434708"}', '{"technical_skills": ["Troubleshooting", "Networking", "Database Management"], "certifications": ["Cisco Certified", "CompTIA", "Microsoft Certified"]}'),
('Okonkwo Chukwu', 2, 31, 'Network Engineer', '2022-05-12', 1815.18, '{"email": "okonkwo.chukwu388@company.com", "phone": "+2348023639868"}', '{"technical_skills": ["Programming", "Database Management"], "certifications": ["Microsoft Certified", "CompTIA"]}'),
('Yewande Ibrahim', 2, 31, 'System Admin', '2024-05-08', 1772.04, '{"email": "yewande.ibrahim762@company.com", "phone": "+2348015767954"}', '{"technical_skills": ["Database Management"], "certifications": ["CompTIA", "Microsoft Certified"]}'),
('Nneka Adeleke', 3, NULL, 'Marketing Director', '2016-05-02', 5193.33, '{"email": "nneka.adeleke278@company.com", "phone": "+2348051886924"}', '{"marketing_skills": ["Campaign Management", "Market Research"], "analytical_skills": ["Customer Segmentation"]}'),
('Emeka Bakare', 3, NULL, 'Brand Manager', '2016-07-19', 6137.61, '{"email": "emeka.bakare40@company.com", "phone": "+2348040140656"}', '{"marketing_skills": ["Campaign Management", "Market Research", "Brand Strategy"], "analytical_skills": ["Customer Segmentation"]}'),
('Zainab Nwosu', 3, NULL, 'Marketing Director', '2017-09-03', 4781.05, '{"email": "zainab.nwosu583@company.com", "phone": "+2348043072968"}', '{"marketing_skills": ["Market Research", "Digital Marketing", "Campaign Management"], "analytical_skills": ["Customer Segmentation"]}'),
('Oluwaseun Okoh', 3, 53, 'Content Creator', '2020-12-17', 3933.13, '{"email": "oluwaseun.okoh977@company.com", "phone": "+2348018601406"}', '{"marketing_skills": ["Email Marketing", "Content Creation"], "creative_skills": ["Graphic Design"]}'),
('Ngozi Nwosu', 3, 52, 'SEO Analyst', '2018-07-30', 3070.33, '{"email": "ngozi.nwosu144@company.com", "phone": "+2348032282537"}', '{"marketing_skills": ["Email Marketing", "Content Creation"], "creative_skills": ["Graphic Design"]}'),
('Tunde Ogbonna', 3, 51, 'Marketing Specialist', '2024-03-15', 2981.94, '{"email": "tunde.ogbonna41@company.com", "phone": "+2348037152879"}', '{"marketing_skills": ["Email Marketing", "Content Creation"], "creative_skills": ["Copywriting"]}'),
('Tunde Adewale', 3, 51, 'Social Media Manager', '2021-12-20', 2108.18, '{"email": "tunde.adewale709@company.com", "phone": "+2348006991427"}', '{"marketing_skills": ["SEO/SEM"], "creative_skills": ["Video Production"]}'),
('Chukwu Onyeka', 3, 53, 'Social Media Manager', '2022-08-02', 1766.06, '{"email": "chukwu.onyeka659@company.com", "phone": "+2348005718802"}', '{"marketing_skills": ["Content Creation", "SEO/SEM"], "creative_skills": ["Video Production"]}'),
('Yusuf Aliyu', 3, 53, 'Marketing Specialist', '2018-09-23', 1816.14, '{"email": "yusuf.aliyu572@company.com", "phone": "+2348043759541"}', '{"marketing_skills": ["Social Media", "Email Marketing", "Content Creation"], "creative_skills": ["Copywriting", "Video Production"]}'),
('Yusuf Okoh', 3, 51, 'Social Media Manager', '2023-04-08', 4751.99, '{"email": "yusuf.okoh233@company.com", "phone": "+2348041053259"}', '{"marketing_skills": ["Email Marketing", "Content Creation"], "creative_skills": ["Copywriting"]}'),
('Abdul Adewale', 3, 53, 'Content Creator', '2023-06-24', 2654.39, '{"email": "abdul.adewale192@company.com", "phone": "+2348038269916"}', '{"marketing_skills": ["Content Creation", "Email Marketing"], "creative_skills": ["Graphic Design", "Video Production"]}'),
('Chukwu Sule', 3, 53, 'Social Media Manager', '2021-06-23', 3849.86, '{"email": "chukwu.sule792@company.com", "phone": "+2348068844995"}', '{"marketing_skills": ["Content Creation"], "creative_skills": ["Graphic Design", "UX/UI", "Video Production"]}'),
('Wale Alade', 3, 51, 'Content Creator', '2019-05-25', 3284.91, '{"email": "wale.alade559@company.com", "phone": "+2348079986729"}', '{"marketing_skills": ["Email Marketing", "Social Media", "Content Creation"], "creative_skills": ["UX/UI"]}'),
('Obinna Uche', 3, 53, 'Content Creator', '2019-04-16', 4868.47, '{"email": "obinna.uche645@company.com", "phone": "+2348099221857"}', '{"marketing_skills": ["SEO/SEM", "Social Media", "Email Marketing"], "creative_skills": ["Graphic Design"]}'),
('Deborah Ogunleye', 3, 51, 'Content Creator', '2018-02-12', 4970.61, '{"email": "deborah.ogunleye128@company.com", "phone": "+2348098363016"}', '{"marketing_skills": ["Email Marketing", "Content Creation", "Social Media"], "creative_skills": ["Copywriting"]}'),
('Yewande Akintola', 3, 51, 'Social Media Manager', '2020-10-29', 4243.31, '{"email": "yewande.akintola382@company.com", "phone": "+2348039863261"}', '{"marketing_skills": ["Email Marketing"], "creative_skills": ["Graphic Design"]}'),
('Yusuf Akintola', 3, 52, 'Social Media Manager', '2022-08-12', 4365.84, '{"email": "yusuf.akintola50@company.com", "phone": "+2348021914108"}', '{"marketing_skills": ["Content Creation", "SEO/SEM"], "creative_skills": ["Graphic Design"]}'),
('Okonkwo Ibrahim', 3, 53, 'Social Media Manager', '2018-04-19', 3903.53, '{"email": "okonkwo.ibrahim840@company.com", "phone": "+2348092038954"}', '{"marketing_skills": ["Social Media"], "creative_skills": ["Graphic Design"]}'),
('Abdul Okonkwo', 3, 53, 'Marketing Specialist', '2018-06-16', 4122.7, '{"email": "abdul.okonkwo352@company.com", "phone": "+2348080803869"}', '{"marketing_skills": ["Content Creation", "SEO/SEM"], "creative_skills": ["Video Production", "UX/UI", "Copywriting"]}'),
('Chukwu Okoh', 3, 53, 'SEO Analyst', '2023-03-03', 2423.09, '{"email": "chukwu.okoh213@company.com", "phone": "+2348034784633"}', '{"marketing_skills": ["Content Creation", "Email Marketing"], "creative_skills": ["Video Production"]}'),
('Yewande Ogunleye', 3, 51, 'Social Media Manager', '2020-09-21', 3002.97, '{"email": "yewande.ogunleye896@company.com", "phone": "+2348050051941"}', '{"marketing_skills": ["Content Creation"], "creative_skills": ["UX/UI"]}'),
('Chukwu Oladipo', 3, 52, 'Marketing Specialist', '2025-03-17', 1891.68, '{"email": "chukwu.oladipo220@company.com", "phone": "+2348039832485"}', '{"marketing_skills": ["SEO/SEM"], "creative_skills": ["Graphic Design"]}'),
('Amina Akinwande', 4, NULL, 'Financial Controller', '2017-01-14', 9594.93, '{"email": "amina.akinwande804@company.com", "phone": "+2348007083687"}', '{"finance_skills": ["Risk Management", "Financial Planning"], "certifications": ["ACCA", "CPA"]}'),
('Funke Onyema', 4, NULL, 'Finance Manager', '2019-06-12', 9576.08, '{"email": "funke.onyema89@company.com", "phone": "+2348011075215"}', '{"finance_skills": ["Compliance", "Investment Analysis", "Risk Management"], "certifications": ["ACCA", "CPA"]}'),
('Amara Onyeka', 4, NULL, 'Accounting Lead', '2016-09-12', 9621.04, '{"email": "amara.onyeka273@company.com", "phone": "+2348021400830"}', '{"finance_skills": ["Financial Planning", "Risk Management"], "certifications": ["ACCA"]}'),
('Aisha Ojo', 4, 73, 'Financial Analyst', '2025-01-15', 4239.17, '{"email": "aisha.ojo430@company.com", "phone": "+2348062484651"}', '{"finance_skills": ["Bookkeeping"], "software_skills": ["Oracle Financials", "QuickBooks", "SAP"]}'),
('Yusuf Okafor', 4, 73, 'Accountant', '2023-06-05', 4160.9, '{"email": "yusuf.okafor842@company.com", "phone": "+2348027309780"}', '{"finance_skills": ["Payroll Processing", "Bookkeeping"], "software_skills": ["Excel"]}'),
('Femi Okafor', 4, 74, 'Payroll Specialist', '2025-07-04', 2330.78, '{"email": "femi.okafor841@company.com", "phone": "+2348023519836"}', '{"finance_skills": ["Payroll Processing"], "software_skills": ["SAP", "Oracle Financials"]}'),
('Abdul Sule', 4, 73, 'Accountant', '2018-01-04', 3301.98, '{"email": "abdul.sule224@company.com", "phone": "+2348021638482"}', '{"finance_skills": ["Tax Preparation"], "software_skills": ["QuickBooks", "SAP", "Oracle Financials"]}'),
('Chioma Onyema', 4, 73, 'Accountant', '2021-01-12', 2856.42, '{"email": "chioma.onyema759@company.com", "phone": "+2348071108250"}', '{"finance_skills": ["Bookkeeping", "Tax Preparation"], "software_skills": ["SAP"]}'),
('Zainab Uche', 4, 73, 'Auditor', '2019-03-26', 1513.8, '{"email": "zainab.uche14@company.com", "phone": "+2348060373504"}', '{"finance_skills": ["Payroll Processing"], "software_skills": ["QuickBooks"]}'),
('Musa Alade', 4, 74, 'Financial Analyst', '2021-12-03', 3329.99, '{"email": "musa.alade577@company.com", "phone": "+2348035610034"}', '{"finance_skills": ["Tax Preparation"], "software_skills": ["SAP", "QuickBooks", "Excel"]}'),
('Yewande Okoro', 4, 73, 'Payroll Specialist', '2019-07-04', 1807.01, '{"email": "yewande.okoro25@company.com", "phone": "+2348084336373"}', '{"finance_skills": ["Tax Preparation", "Bookkeeping"], "software_skills": ["SAP", "QuickBooks", "Excel"]}'),
('Zainab Adewale', 4, 74, 'Payroll Specialist', '2021-05-05', 1524.2, '{"email": "zainab.adewale224@company.com", "phone": "+2348044804087"}', '{"finance_skills": ["Tax Preparation", "Payroll Processing"], "software_skills": ["QuickBooks"]}'),
('Yewande Ogbonna', 4, 75, 'Accountant', '2020-01-27', 3966.27, '{"email": "yewande.ogbonna597@company.com", "phone": "+2348078823268"}', '{"finance_skills": ["Bookkeeping", "Financial Reporting"], "software_skills": ["Excel", "Oracle Financials"]}'),
('Zainab Onyia', 4, 75, 'Auditor', '2020-08-24', 3111.67, '{"email": "zainab.onyia74@company.com", "phone": "+2348098514509"}', '{"finance_skills": ["Bookkeeping"], "software_skills": ["QuickBooks", "Excel"]}'),
('Femi Adeyemi', 4, 75, 'Auditor', '2018-06-16', 3821.31, '{"email": "femi.adeyemi379@company.com", "phone": "+2348010882884"}', '{"finance_skills": ["Payroll Processing"], "software_skills": ["Oracle Financials", "SAP", "Excel"]}'),
('Chinedu Mohammed', 4, 74, 'Auditor', '2018-06-01', 4377.14, '{"email": "chinedu.mohammed350@company.com", "phone": "+2348087595420"}', '{"finance_skills": ["Tax Preparation", "Payroll Processing"], "software_skills": ["SAP", "Excel", "QuickBooks"]}'),
('Ifeoma Balogun', 4, 74, 'Payroll Specialist', '2019-06-07', 4103.0, '{"email": "ifeoma.balogun207@company.com", "phone": "+2348039825981"}', '{"finance_skills": ["Tax Preparation"], "software_skills": ["SAP"]}'),
('Okonkwo Onyeama', 5, NULL, 'Supply Chain Lead', '2017-04-18', 6618.83, '{"email": "okonkwo.onyeama794@company.com", "phone": "+2348087429165"}', '{"operations_skills": ["Process Optimization"], "management_skills": ["Team Leadership", "Strategic Planning", "Vendor Negotiation"]}'),
('Fatima Okonkwo', 5, NULL, 'Supply Chain Lead', '2019-12-17', 9800.62, '{"email": "fatima.okonkwo527@company.com", "phone": "+2348004188593"}', '{"operations_skills": ["Logistics"], "management_skills": ["Team Leadership", "Budget Management"]}'),
('Jide Eze', 5, NULL, 'Logistics Director', '2016-08-09', 4053.55, '{"email": "jide.eze832@company.com", "phone": "+2348002084674"}', '{"operations_skills": ["Quality Control", "Process Optimization", "Logistics"], "management_skills": ["Team Leadership", "Strategic Planning"]}'),
('Ebere Eze', 5, 90, 'Operations Coordinator', '2024-12-27', 4779.41, '{"email": "ebere.eze592@company.com", "phone": "+2348022285118"}', '{"operations_skills": ["Documentation", "Order Fulfillment", "Facility Management"], "technical_skills": ["Six Sigma", "ERP Systems", "Safety Compliance"]}'),
('Chukwu Ogbonna', 5, 91, 'Operations Coordinator', '2023-04-05', 4630.35, '{"email": "chukwu.ogbonna266@company.com", "phone": "+2348068110713"}', '{"operations_skills": ["Order Fulfillment", "Facility Management"], "technical_skills": ["Six Sigma"]}'),
('Abdul Adewale', 5, 92, 'Facilities Manager', '2022-09-19', 4702.67, '{"email": "abdul.adewale958@company.com", "phone": "+2348097745718"}', '{"operations_skills": ["Documentation", "Facility Management", "Inventory Management"], "technical_skills": ["Warehouse Management", "Six Sigma"]}'),
('Kunle Oladipo', 5, 91, 'Operations Coordinator', '2023-12-16', 4236.83, '{"email": "kunle.oladipo395@company.com", "phone": "+2348080476336"}', '{"operations_skills": ["Facility Management", "Inventory Management", "Documentation"], "technical_skills": ["Safety Compliance", "ERP Systems"]}'),
('Yewande Akintola', 5, 92, 'Quality Assurance', '2019-03-13', 2970.49, '{"email": "yewande.akintola90@company.com", "phone": "+2348034446096"}', '{"operations_skills": ["Order Fulfillment", "Facility Management", "Inventory Management"], "technical_skills": ["ERP Systems", "Warehouse Management", "Six Sigma"]}'),
('Tunde Alade', 5, 90, 'Facilities Manager', '2024-10-10', 4595.65, '{"email": "tunde.alade599@company.com", "phone": "+2348011532284"}', '{"operations_skills": ["Inventory Management", "Facility Management", "Documentation"], "technical_skills": ["Warehouse Management", "Six Sigma", "Safety Compliance"]}'),
('Ngozi Okoh', 5, 91, 'Operations Coordinator', '2024-09-26', 4630.62, '{"email": "ngozi.okoh398@company.com", "phone": "+2348082573243"}', '{"operations_skills": ["Facility Management"], "technical_skills": ["Warehouse Management", "Six Sigma", "Safety Compliance"]}'),
('Chiamaka Ojo', 5, 91, 'Operations Coordinator', '2022-11-21', 3439.9, '{"email": "chiamaka.ojo285@company.com", "phone": "+2348077014087"}', '{"operations_skills": ["Documentation", "Facility Management", "Inventory Management"], "technical_skills": ["Safety Compliance", "Warehouse Management"]}'),
('Aisha Ibrahim', 5, 91, 'Facilities Manager', '2019-05-05', 2837.88, '{"email": "aisha.ibrahim7@company.com", "phone": "+2348005044724"}', '{"operations_skills": ["Facility Management", "Documentation"], "technical_skills": ["Warehouse Management"]}'),
('Wale Onyema', 5, 92, 'Operations Coordinator', '2024-02-10', 4576.53, '{"email": "wale.onyema637@company.com", "phone": "+2348021602393"}', '{"operations_skills": ["Documentation"], "technical_skills": ["Safety Compliance", "Six Sigma", "ERP Systems"]}'),
('Wale Onyema', 5, 91, 'Operations Coordinator', '2019-03-21', 4968.43, '{"email": "wale.onyema205@company.com", "phone": "+2348096016925"}', '{"operations_skills": ["Order Fulfillment", "Inventory Management"], "technical_skills": ["ERP Systems"]}'),
('Fatima Onyema', 5, 90, 'Facilities Manager', '2023-02-13', 3546.5, '{"email": "fatima.onyema602@company.com", "phone": "+2348005076736"}', '{"operations_skills": ["Documentation", "Facility Management"], "technical_skills": ["Warehouse Management", "ERP Systems"]}'),
('Chinedu Okafor', 5, 90, 'Inventory Specialist', '2024-11-10', 1882.62, '{"email": "chinedu.okafor35@company.com", "phone": "+2348014405393"}', '{"operations_skills": ["Documentation"], "technical_skills": ["Six Sigma", "Safety Compliance"]}'),
('Femi Adeyemi', 5, 92, 'Facilities Manager', '2018-06-03', 4435.82, '{"email": "femi.adeyemi572@company.com", "phone": "+2348028004402"}', '{"operations_skills": ["Documentation", "Facility Management", "Inventory Management"], "technical_skills": ["Warehouse Management", "ERP Systems", "Safety Compliance"]}'),
('Zainab Onyeka', 6, NULL, 'Talent Acquisition Lead', '2015-09-29', 4187.76, '{"email": "zainab.onyeka509@company.com", "phone": "+2348046896192"}', '{"hr_skills": ["Compensation & Benefits"], "certifications": ["SPHR", "SHRM-CP"]}'),
('Okonkwo Onyema', 6, NULL, 'HR Manager', '2020-05-02', 8612.82, '{"email": "okonkwo.onyema226@company.com", "phone": "+2348076872638"}', '{"hr_skills": ["Employee Relations", "Performance Management"], "certifications": ["SPHR", "SHRM-CP", "HRCI"]}'),
('Ngozi Adeyemi', 6, NULL, 'HR Director', '2019-08-29', 6635.02, '{"email": "ngozi.adeyemi168@company.com", "phone": "+2348039803860"}', '{"hr_skills": ["Talent Acquisition", "Employee Relations", "Performance Management"], "certifications": ["SPHR", "PHR", "HRCI"]}'),
('Chinedu Onyeama', 6, 109, 'HR Associate', '2019-04-14', 2400.1, '{"email": "chinedu.onyeama500@company.com", "phone": "+2348086461255"}', '{"hr_skills": ["Onboarding", "Training Coordination", "Recruitment"], "soft_skills": ["Discretion"]}'),
('Aisha Bello', 6, 109, 'Compensation Analyst', '2020-09-07', 4881.52, '{"email": "aisha.bello189@company.com", "phone": "+2348057886440"}', '{"hr_skills": ["Onboarding", "HR Administration", "Training Coordination"], "soft_skills": ["Empathy"]}'),
('Kunle Balogun', 6, 107, 'Training Coordinator', '2024-01-11', 1825.5, '{"email": "kunle.balogun271@company.com", "phone": "+2348012268792"}', '{"hr_skills": ["HR Administration"], "soft_skills": ["Empathy"]}'),
('Chioma Sule', 6, 109, 'Training Coordinator', '2019-07-14', 4455.72, '{"email": "chioma.sule554@company.com", "phone": "+2348050255416"}', '{"hr_skills": ["Onboarding", "Training Coordination"], "soft_skills": ["Empathy", "Discretion"]}'),
('Nneka Adeleke', 6, 109, 'Compensation Analyst', '2019-08-26', 2139.2, '{"email": "nneka.adeleke350@company.com", "phone": "+2348085590305"}', '{"hr_skills": ["Recruitment", "Onboarding", "Training Coordination"], "soft_skills": ["Conflict Resolution", "Discretion"]}'),
('Yewande Okoro', 6, 107, 'HR Associate', '2018-02-14', 2692.3, '{"email": "yewande.okoro143@company.com", "phone": "+2348027656618"}', '{"hr_skills": ["Onboarding", "Training Coordination"], "soft_skills": ["Communication", "Conflict Resolution"]}'),
('Femi Adeleke', 6, 107, 'HR Associate', '2021-09-15', 4255.91, '{"email": "femi.adeleke782@company.com", "phone": "+2348069638600"}', '{"hr_skills": ["HR Administration"], "soft_skills": ["Empathy", "Conflict Resolution", "Discretion"]}'),
('Femi Adeyemi', 6, 107, 'Training Coordinator', '2025-06-15', 1929.87, '{"email": "femi.adeyemi138@company.com", "phone": "+2348048602489"}', '{"hr_skills": ["Onboarding", "HR Administration", "Recruitment"], "soft_skills": ["Discretion"]}'),
('Abdul Onyema', 6, 107, 'Compensation Analyst', '2025-01-28', 2921.4, '{"email": "abdul.onyema932@company.com", "phone": "+2348074336693"}', '{"hr_skills": ["Training Coordination"], "soft_skills": ["Communication"]}'),
('Emeka Umar', 6, 109, 'Training Coordinator', '2024-07-04', 4671.99, '{"email": "emeka.umar936@company.com", "phone": "+2348011540778"}', '{"hr_skills": ["Recruitment", "Training Coordination"], "soft_skills": ["Empathy", "Discretion"]}'),
('Chinedu Ojo', 6, 109, 'HR Associate', '2019-12-11', 2898.55, '{"email": "chinedu.ojo402@company.com", "phone": "+2348001702080"}', '{"hr_skills": ["HR Administration", "Onboarding"], "soft_skills": ["Communication"]}'),
('Oluwaseun Ogbonna', 6, 109, 'Compensation Analyst', '2022-12-22', 2024.87, '{"email": "oluwaseun.ogbonna272@company.com", "phone": "+2348080109539"}', '{"hr_skills": ["Recruitment"], "soft_skills": ["Empathy"]}'),
('Amara Bello', 6, 108, 'HR Associate', '2019-01-24', 3426.95, '{"email": "amara.bello533@company.com", "phone": "+2348087067823"}', '{"hr_skills": ["Onboarding"], "soft_skills": ["Conflict Resolution", "Empathy"]}'),
('Femi Okoh', 6, 108, 'Recruiter', '2018-01-01', 3889.52, '{"email": "femi.okoh990@company.com", "phone": "+2348041497239"}', '{"hr_skills": ["Onboarding"], "soft_skills": ["Communication"]}'),
('Musa Adewale', 7, NULL, 'Customer Service Manager', '2019-09-11', 6566.36, '{"email": "musa.adewale324@company.com", "phone": "+2348071013155"}', '{"service_skills": ["Complaint Resolution"], "management_skills": ["Training Development", "Performance Metrics", "Process Improvement"]}'),
('Sani Uche', 7, NULL, 'Client Success Director', '2017-09-20', 9506.08, '{"email": "sani.uche506@company.com", "phone": "+2348088645263"}', '{"service_skills": ["Quality Assurance"], "management_skills": ["Process Improvement", "Training Development", "Team Leadership"]}'),
('Funke Adeyemi', 7, 125, 'Service Coordinator', '2024-10-01', 3581.24, '{"email": "funke.adeyemi695@company.com", "phone": "+2348063648391"}', '{"service_skills": ["Phone Etiquette"], "soft_skills": ["Problem Solving"]}'),
('Deborah Oladipo', 7, 124, 'Service Coordinator', '2025-04-10', 4736.0, '{"email": "deborah.oladipo363@company.com", "phone": "+2348074380134"}', '{"service_skills": ["Phone Etiquette"], "soft_skills": ["Empathy", "Patience", "Communication"]}'),
('Zainab Uche', 7, 125, 'Client Success Agent', '2018-02-09', 1670.69, '{"email": "zainab.uche171@company.com", "phone": "+2348059842196"}', '{"service_skills": ["Ticket Management", "Phone Etiquette"], "soft_skills": ["Communication", "Empathy", "Patience"]}'),
('Zainab Oladipo', 7, 124, 'Customer Support', '2018-04-26', 2977.42, '{"email": "zainab.oladipo80@company.com", "phone": "+2348084448272"}', '{"service_skills": ["Product Knowledge"], "soft_skills": ["Communication", "Patience"]}'),
('Musa Oladipo', 7, 125, 'Helpdesk Technician', '2023-04-19', 3469.73, '{"email": "musa.oladipo132@company.com", "phone": "+2348070391359"}', '{"service_skills": ["Product Knowledge"], "soft_skills": ["Empathy", "Problem Solving", "Patience"]}'),
('Chioma Bello', 7, 125, 'Customer Support', '2023-02-17', 4700.57, '{"email": "chioma.bello980@company.com", "phone": "+2348064991519"}', '{"service_skills": ["Customer Retention"], "soft_skills": ["Empathy"]}'),
('Ngozi Ibrahim', 7, 125, 'Client Success Agent', '2022-12-24', 2989.24, '{"email": "ngozi.ibrahim468@company.com", "phone": "+2348039836303"}', '{"service_skills": ["Phone Etiquette", "Customer Retention"], "soft_skills": ["Problem Solving", "Empathy"]}'),
('Ebere Oladipo', 7, 125, 'Customer Support', '2021-05-22', 4790.17, '{"email": "ebere.oladipo496@company.com", "phone": "+2348066626463"}', '{"service_skills": ["Phone Etiquette", "Product Knowledge", "Customer Retention"], "soft_skills": ["Communication", "Problem Solving", "Empathy"]}'),
('Amara Onyema', 7, 125, 'Helpdesk Technician', '2025-02-07', 3282.39, '{"email": "amara.onyema882@company.com", "phone": "+2348062792544"}', '{"service_skills": ["Phone Etiquette", "Ticket Management", "Customer Retention"], "soft_skills": ["Communication"]}'),
('Ebere Onyema', 8, NULL, 'Sales Director', '2017-08-06', 7440.12, '{"email": "ebere.onyema123@company.com", "phone": "+2348027042521"}', '{"sales_skills": ["Key Account Management", "CRM Systems", "Sales Forecasting"], "soft_skills": ["Leadership", "Presentation", "Negotiation"]}'),
('Zainab Uche', 8, NULL, 'Sales Director', '2015-03-08', 8453.52, '{"email": "zainab.uche504@company.com", "phone": "+2348014902376"}', '{"sales_skills": ["Sales Forecasting", "Strategic Planning"], "soft_skills": ["Decision Making"]}'),
('Ngozi Sule', 8, 135, 'Sales Representative', '2023-11-22', 2573.25, '{"email": "ngozi.sule179@company.com", "phone": "+2348054695538"}', '{"sales_skills": ["Sales Presentations"], "soft_skills": ["Persuasion", "Communication", "Active Listening"]}'),
('Emeka Okoh', 8, 135, 'Sales Associate', '2019-07-30', 3762.75, '{"email": "emeka.okoh72@company.com", "phone": "+2348058544123"}', '{"sales_skills": ["Customer Engagement", "Sales Presentations", "Prospecting"], "soft_skills": ["Persuasion"]}'),
('Ifeoma Onyeama', 8, 136, 'Sales Associate', '2021-11-16', 2879.4, '{"email": "ifeoma.onyeama506@company.com", "phone": "+2348076848884"}', '{"sales_skills": ["Product Knowledge", "Prospecting"], "soft_skills": ["Resilience", "Communication", "Persuasion"]}'),
('Funke Akinwande', 8, 136, 'Business Development', '2025-03-24', 4792.49, '{"email": "funke.akinwande295@company.com", "phone": "+2348074824367"}', '{"sales_skills": ["Customer Engagement"], "soft_skills": ["Communication", "Persuasion", "Active Listening"]}'),
('Ifeoma Ogunleye', 8, 136, 'Business Development', '2023-10-01', 3582.6, '{"email": "ifeoma.ogunleye607@company.com", "phone": "+2348048965472"}', '{"sales_skills": ["Product Knowledge"], "soft_skills": ["Active Listening", "Communication", "Resilience"]}'),
('Fatima Adewale', 8, 136, 'Business Development', '2020-05-27', 3814.92, '{"email": "fatima.adewale138@company.com", "phone": "+2348068802047"}', '{"sales_skills": ["Customer Engagement", "Prospecting", "Sales Presentations"], "soft_skills": ["Persuasion", "Active Listening"]}'),
('Wale Umar', 8, 135, 'Sales Associate', '2021-01-26', 2427.18, '{"email": "wale.umar819@company.com", "phone": "+2348034698040"}', '{"sales_skills": ["Sales Presentations", "Prospecting"], "soft_skills": ["Persuasion"]}'),
('Kunle Okafor', 8, 135, 'Business Development', '2018-02-02', 2643.17, '{"email": "kunle.okafor383@company.com", "phone": "+2348068976251"}', '{"sales_skills": ["Product Knowledge", "Sales Presentations", "Prospecting"], "soft_skills": ["Active Listening"]}'),
('Kunle Alade', 8, 136, 'Account Executive', '2024-01-19', 2329.11, '{"email": "kunle.alade5@company.com", "phone": "+2348074582056"}', '{"sales_skills": ["Product Knowledge", "Sales Presentations", "Customer Engagement"], "soft_skills": ["Active Listening"]}'),
('Chiamaka Okafor', 9, NULL, 'CTO', '2017-12-30', 5800.0, '{"email": "chiamaka.okafor97@company.com", "phone": "+2348026134018"}', '{"technical_skills": ["Security", "Cloud Infrastructure", "DevOps"], "management_skills": ["Project Management", "Team Leadership", "Vendor Management"]}'),
('Chiamaka Okoh', 9, NULL, 'Systems Architect', '2020-04-23', 9308.39, '{"email": "chiamaka.okoh457@company.com", "phone": "+2348086571481"}', '{"technical_skills": ["DevOps", "Security", "System Architecture"], "management_skills": ["Project Management", "Budgeting"]}'),
('Fatima Umar', 9, 146, 'System Admin', '2021-03-09', 3877.53, '{"email": "fatima.umar372@company.com", "phone": "+2348057954342"}', '{"technical_skills": ["Troubleshooting", "Programming", "Networking"], "certifications": ["AWS Certified", "Cisco Certified"]}'),
('Yusuf Eze', 9, 147, 'Data Analyst', '2025-01-15', 2390.45, '{"email": "yusuf.eze278@company.com", "phone": "+2348020443997"}', '{"technical_skills": ["Networking", "Programming"], "certifications": ["AWS Certified", "CompTIA"]}'),
('Kunle Mohammed', 9, 146, 'Software Engineer', '2020-05-15', 4775.1, '{"email": "kunle.mohammed976@company.com", "phone": "+2348088710255"}', '{"technical_skills": ["Database Management", "Programming", "Troubleshooting"], "certifications": ["Microsoft Certified", "CompTIA"]}'),
('Okonkwo Okoro', 9, 146, 'System Admin', '2019-10-26', 3650.53, '{"email": "okonkwo.okoro103@company.com", "phone": "+2348003268058"}', '{"technical_skills": ["Database Management", "Programming"], "certifications": ["Cisco Certified"]}'),
('Ifeoma Onyia', 9, 146, 'System Admin', '2021-12-09', 2102.17, '{"email": "ifeoma.onyia311@company.com", "phone": "+2348044739383"}', '{"technical_skills": ["Troubleshooting"], "certifications": ["AWS Certified"]}'),
('Ngozi Ogbonna', 9, 147, 'Network Engineer', '2020-03-18', 2803.65, '{"email": "ngozi.ogbonna912@company.com", "phone": "+2348097566857"}', '{"technical_skills": ["Networking", "Troubleshooting"], "certifications": ["Microsoft Certified"]}'),
('Abdul Adewale', 9, 147, 'Software Engineer', '2020-10-25', 3772.34, '{"email": "abdul.adewale384@company.com", "phone": "+2348093797390"}', '{"technical_skills": ["Troubleshooting"], "certifications": ["Microsoft Certified"]}'),
('Amara Aliyu', 9, 147, 'IT Support', '2024-04-01', 2381.25, '{"email": "amara.aliyu140@company.com", "phone": "+2348040615121"}', '{"technical_skills": ["Networking", "Troubleshooting"], "certifications": ["CompTIA", "Cisco Certified"]}'),
('Amara Bello', 9, 147, 'IT Support', '2020-02-03', 2158.55, '{"email": "amara.bello662@company.com", "phone": "+2348059255876"}', '{"technical_skills": ["Troubleshooting"], "certifications": ["Microsoft Certified", "CompTIA"]}'),
('Wale Onyeama', 10, NULL, 'Digital Marketing Lead', '2017-02-23', 8882.18, '{"email": "wale.onyeama409@company.com", "phone": "+2348080981529"}', '{"marketing_skills": ["Market Research", "Digital Marketing", "Campaign Management"], "analytical_skills": ["ROI Analysis", "Customer Segmentation"]}'),
('Sani Okoh', 10, NULL, 'Brand Manager', '2020-08-25', 8275.65, '{"email": "sani.okoh692@company.com", "phone": "+2348032693967"}', '{"marketing_skills": ["Market Research", "Campaign Management", "Brand Strategy"], "analytical_skills": ["Budget Management"]}'),
('Chukwu Onyia', 10, 157, 'SEO Analyst', '2018-12-25', 3604.86, '{"email": "chukwu.onyia445@company.com", "phone": "+2348084805517"}', '{"marketing_skills": ["Content Creation", "Social Media", "Email Marketing"], "creative_skills": ["Copywriting", "UX/UI", "Graphic Design"]}'),
('Okonkwo Uche', 10, 158, 'Marketing Specialist', '2021-02-21', 4657.63, '{"email": "okonkwo.uche336@company.com", "phone": "+2348015534921"}', '{"marketing_skills": ["SEO/SEM", "Social Media", "Email Marketing"], "creative_skills": ["Video Production", "Copywriting", "Graphic Design"]}'),
('Adanna Okoro', 10, 157, 'Content Creator', '2023-05-15', 4015.25, '{"email": "adanna.okoro102@company.com", "phone": "+2348042713506"}', '{"marketing_skills": ["Social Media", "Email Marketing", "Content Creation"], "creative_skills": ["Video Production", "UX/UI"]}'),
('Musa Aliyu', 10, 157, 'SEO Analyst', '2021-05-11', 2142.36, '{"email": "musa.aliyu399@company.com", "phone": "+2348021943382"}', '{"marketing_skills": ["SEO/SEM", "Email Marketing"], "creative_skills": ["Video Production", "UX/UI"]}'),
('Sani Bakare', 10, 157, 'Social Media Manager', '2023-12-14', 3961.88, '{"email": "sani.bakare622@company.com", "phone": "+2348024598804"}', '{"marketing_skills": ["Email Marketing", "Content Creation", "Social Media"], "creative_skills": ["Video Production", "Copywriting"]}'),
('Okonkwo Balogun', 10, 157, 'Social Media Manager', '2022-12-17', 2074.34, '{"email": "okonkwo.balogun855@company.com", "phone": "+2348089677805"}', '{"marketing_skills": ["Content Creation", "Social Media"], "creative_skills": ["Graphic Design"]}'),
('Musa Okonkwo', 10, 158, 'Social Media Manager', '2022-06-08', 3077.34, '{"email": "musa.okonkwo960@company.com", "phone": "+2348018553625"}', '{"marketing_skills": ["Email Marketing"], "creative_skills": ["Graphic Design"]}'),
('Chinedu Adewale', 10, 158, 'Content Creator', '2024-05-27', 2573.21, '{"email": "chinedu.adewale646@company.com", "phone": "+2348062045543"}', '{"marketing_skills": ["Social Media", "Content Creation"], "creative_skills": ["UX/UI", "Graphic Design"]}'),
('Chiamaka Sule', 10, 157, 'Social Media Manager', '2025-05-09', 3296.83, '{"email": "chiamaka.sule563@company.com", "phone": "+2348024451194"}', '{"marketing_skills": ["Email Marketing", "Content Creation"], "creative_skills": ["Graphic Design"]}'),
('Aisha Ibrahim', 11, NULL, 'CFO', '2017-07-04', 9099.88, '{"email": "aisha.ibrahim52@company.com", "phone": "+2348002343594"}', '{"finance_skills": ["Financial Planning"], "certifications": ["ACCA", "CFA", "CPA"]}'),
('Tunde Akinwande', 11, 168, 'Auditor', '2021-10-25', 2218.66, '{"email": "tunde.akinwande838@company.com", "phone": "+2348086596742"}', '{"finance_skills": ["Tax Preparation", "Financial Reporting"], "software_skills": ["Excel", "SAP"]}'),
('Adanna Aliyu', 11, 168, 'Accountant', '2022-07-03', 2303.77, '{"email": "adanna.aliyu509@company.com", "phone": "+2348085160740"}', '{"finance_skills": ["Payroll Processing"], "software_skills": ["QuickBooks"]}'),
('Ebere Nwosu', 11, 168, 'Payroll Specialist', '2019-10-30', 3993.81, '{"email": "ebere.nwosu188@company.com", "phone": "+2348014782421"}', '{"finance_skills": ["Tax Preparation", "Bookkeeping", "Financial Reporting"], "software_skills": ["QuickBooks", "Oracle Financials"]}'),
('Abdul Okonkwo', 11, 168, 'Financial Analyst', '2023-10-30', 2064.24, '{"email": "abdul.okonkwo999@company.com", "phone": "+2348098674446"}', '{"finance_skills": ["Financial Reporting"], "software_skills": ["SAP", "QuickBooks"]}'),
('Fatima Alade', 12, NULL, 'Operations Manager', '2017-01-02', 4718.85, '{"email": "fatima.alade119@company.com", "phone": "+2348017000505"}', '{"operations_skills": ["Logistics", "Supply Chain Management"], "management_skills": ["Vendor Negotiation", "Strategic Planning", "Team Leadership"]}'),
('Chukwu Aliyu', 12, 173, 'Operations Coordinator', '2021-03-11', 2120.71, '{"email": "chukwu.aliyu128@company.com", "phone": "+2348031090301"}', '{"operations_skills": ["Order Fulfillment", "Facility Management", "Documentation"], "technical_skills": ["ERP Systems", "Safety Compliance", "Six Sigma"]}'),
('Chiamaka Onyia', 12, 173, 'Operations Coordinator', '2023-03-02', 3164.88, '{"email": "chiamaka.onyia310@company.com", "phone": "+2348040125126"}', '{"operations_skills": ["Order Fulfillment", "Documentation", "Facility Management"], "technical_skills": ["Warehouse Management", "Six Sigma"]}'),
('Chiamaka Ibrahim', 12, 173, 'Facilities Manager', '2022-01-16', 3510.6, '{"email": "chiamaka.ibrahim507@company.com", "phone": "+2348043022796"}', '{"operations_skills": ["Documentation"], "technical_skills": ["ERP Systems", "Six Sigma"]}'),
('Emeka Ibrahim', 12, 173, 'Operations Coordinator', '2020-05-31', 3460.85, '{"email": "emeka.ibrahim606@company.com", "phone": "+2348017970526"}', '{"operations_skills": ["Documentation"], "technical_skills": ["Six Sigma"]}'),
('Musa Akinwande', 13, NULL, 'HR Manager', '2016-06-28', 5856.73, '{"email": "musa.akinwande333@company.com", "phone": "+2348047819566"}', '{"hr_skills": ["Talent Acquisition", "Performance Management", "Employee Relations"], "certifications": ["PHR", "SHRM-CP", "HRCI"]}'),
('Yusuf Mohammed', 13, 178, 'Training Coordinator', '2019-08-12', 1709.44, '{"email": "yusuf.mohammed957@company.com", "phone": "+2348029197765"}', '{"hr_skills": ["HR Administration", "Recruitment", "Onboarding"], "soft_skills": ["Conflict Resolution", "Empathy", "Discretion"]}'),
('Musa Onyeka', 13, 178, 'HR Associate', '2023-01-04', 2066.35, '{"email": "musa.onyeka276@company.com", "phone": "+2348084509010"}', '{"hr_skills": ["Recruitment", "Onboarding"], "soft_skills": ["Conflict Resolution", "Communication"]}'),
('Tunde Okoh', 13, 178, 'Compensation Analyst', '2019-02-18', 3837.78, '{"email": "tunde.okoh385@company.com", "phone": "+2348019507260"}', '{"hr_skills": ["HR Administration", "Recruitment"], "soft_skills": ["Discretion", "Empathy"]}'),
('Aisha Onyeama', 13, 178, 'HR Associate', '2023-11-15', 4700.71, '{"email": "aisha.onyeama533@company.com", "phone": "+2348026618133"}', '{"hr_skills": ["HR Administration"], "soft_skills": ["Empathy", "Communication", "Conflict Resolution"]}'),
('Emeka Okonkwo', 14, NULL, 'Client Success Director', '2020-10-23', 3720.44, '{"email": "emeka.okonkwo940@company.com", "phone": "+2348092233288"}', '{"service_skills": ["Service Strategy", "Complaint Resolution", "Customer Experience"], "management_skills": ["Performance Metrics", "Process Improvement"]}'),
('Chukwu Onyema', 14, 183, 'Helpdesk Technician', '2019-02-20', 3796.13, '{"email": "chukwu.onyema103@company.com", "phone": "+2348062836523"}', '{"service_skills": ["Product Knowledge", "Customer Retention", "Ticket Management"], "soft_skills": ["Empathy"]}'),
('Chiamaka Okoro', 14, 183, 'Helpdesk Technician', '2022-08-25', 4591.26, '{"email": "chiamaka.okoro748@company.com", "phone": "+2348055910839"}', '{"service_skills": ["Ticket Management", "Phone Etiquette", "Product Knowledge"], "soft_skills": ["Patience", "Problem Solving", "Communication"]}'),
('Emeka Ogbonna', 14, 183, 'Helpdesk Technician', '2024-08-17', 4934.39, '{"email": "emeka.ogbonna223@company.com", "phone": "+2348086910634"}', '{"service_skills": ["Ticket Management"], "soft_skills": ["Communication", "Problem Solving"]}'),
('Funke Bakare', 14, 183, 'Customer Support', '2018-09-14', 4895.98, '{"email": "funke.bakare690@company.com", "phone": "+2348059525477"}', '{"service_skills": ["Phone Etiquette", "Product Knowledge"], "soft_skills": ["Communication", "Patience"]}'),
('Oluwaseun Adeleke', 15, NULL, 'Head of Sales', '2020-07-05', 9772.69, '{"email": "oluwaseun.adeleke372@company.com", "phone": "+2348012153502"}', '{"sales_skills": ["Strategic Planning", "Sales Forecasting", "CRM Systems"], "soft_skills": ["Presentation", "Negotiation"]}'),
('Zainab Ojo', 15, 188, 'Business Development', '2023-07-26', 4361.61, '{"email": "zainab.ojo32@company.com", "phone": "+2348006974070"}', '{"sales_skills": ["Sales Presentations", "Product Knowledge", "Prospecting"], "soft_skills": ["Communication", "Persuasion"]}'),
('Funke Onyeama', 15, 188, 'Business Development', '2020-07-05', 2244.34, '{"email": "funke.onyeama161@company.com", "phone": "+2348008247528"}', '{"sales_skills": ["Prospecting"], "soft_skills": ["Active Listening", "Persuasion", "Resilience"]}'),
('Ngozi Okafor', 15, 188, 'Sales Associate', '2024-09-02', 4967.51, '{"email": "ngozi.okafor200@company.com", "phone": "+2348013436923"}', '{"sales_skills": ["Product Knowledge"], "soft_skills": ["Active Listening", "Resilience", "Communication"]}'),
('Abdul Aliyu', 15, 188, 'Business Development', '2022-07-05', 4700.37, '{"email": "abdul.aliyu732@company.com", "phone": "+2348083685488"}', '{"sales_skills": ["Sales Presentations"], "soft_skills": ["Active Listening", "Resilience"]}');



 assignnment find employess whose salary is above the average salary for their department 

select employee_id, name, salary from employees e
where salary > (
	select avg(salary) from employees
)



 asssignment retrieve the customer details for all the customer id returned  in the query above 


select name, email from customers c
where customer_id in ( 
	select customer_id
	from orders o
	group by customer_id
	having count(*) >= 2
);

 find orders where the total amount is greater than the average order total for that customer 

select count(order_id) as total_order from orders; 

select o.customer_id, o.order_id, o.total_amount from orders o
where total_amount > (
	select	avg(total_amount)
	from orders o1
	where o1.customer_id = o.customer_id
);

and that customer's total spending is above the global average customer spending 







1. Find employees whose salary is above the average salary for their department

select employee_id, name, salary from employees e
where salary > (
	select avg(salary) from employees
)


2. Retrieve the customer details for all the customer ids returned in the query above.

select name, email from customers c
where customer_id in ( 
	select customer_id
	from orders o
	group by customer_id
	having count(*) >= 2
);

3. Also, find orders where the total amount is greater than the average order total for that customer,
   and that customer's total spending is above the global average customer spending.
   
select o.customer_id, o.order_id, o.total_amount from orders o
where total_amount > (
	select	avg(total_amount)
	from orders o1
	where o1.customer_id = o.customer_id
);
# Out:
#   Cell In[3], line 273
#     );
#     ^
# SyntaxError: unmatched ')'

# %% [markdown]
# ![my first image](ALTSCHOOL.pgn)

# %% [markdown]
# ![my picture](ALTSCHOOL.jpg)
#
# ![my picture](ALTSCHOOL2.jpg)
#
# ![my picture](ALTSCHOOL3.jpg)
#
# ![my picture](ALTSCHOOL4.jpg)
#
# ![my picture](ALTSCHOOL5.jpg)
#
# ![my picture](ALTSCHOOL6.jpg)
